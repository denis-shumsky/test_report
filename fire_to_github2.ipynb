# %% [markdown]
# Поправить:
# - сравнение оборудования, если печи на одном адресе, но в разные даты
# - если СИ на поверку в этом месяце - добавить полную дату

# %% [markdown]
# ## Данные для протокола

# %% [markdown]
# ### Тип протокола
#
# Варианты:
# - 'E'
# - 'EI'
# - 'EIW'
# - 'S'
#
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
test_type = 'EIW'

# %% [markdown]
# ### Предел огнестойкости (время проведения испытаний)
#
# Варианты:
# - 15
# - 30
# - 45
# - и т.д.
#
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
fire_limit = 60

# %% [markdown]
# ### Тип конструкции
#
# Варианты:
# - 'дверь 1пол'
# - 'дверь 2пол'
# - 'люк 1пол'
# - 'люк 2пол'
# - 'ворота'
# - 'ворота с калиткой'
# - 'окно'
#
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
construction_type = 'дверь 1пол'

# %% [markdown]
# ### Материал конструкции
#
# Задаём материал конструкции (значение вводится внутри кавычек). На выбор только три варианта:
# - 'м' - металл
# - 'д' - дерево
# - 'п' - пользователськие настройки

# %%
construction_material_val = 'м'

# %% [markdown]
# ### Наименования образца

# %% [markdown]
# #### Текстовая часть  для ПИ, в котором 2 образца.
#
# Расшифровка 25- и 25+:
# - со светопрозрачным заполнением площадью менее 25% от площади проёма в свету
# - со светопропускающими элементами площадью более 25% от площади проёма в свету
#
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇   <b> Заполняется в именительном падеже, единственном числе </b> ❗
# </div>

# %%
sample_name_text = 'Дверь   противопожарная алюминиевая светопрозрачная дымогазонепроницаемая серии ДПАГ   безимпостовая с автоматически выпадающим порогом однопольная со   светопропускающими элементами более 25% от площади дверного проема в свету,'

# %% [markdown]
# #### Кодовая часть  для ПИ, в котором 2 образца.
#
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇   <b> Заполняется в именительном падеже, единственном числе </b> ❗
# </div>

# %%
sample_name_code = 'типа ДПА-1-60'

# %% [markdown]
# #### Текстовая часть для ПИ по S на 4 образца.
#
# В ПИ по "S" 1 и 2 образцы - глухие двери, 3 и 4 - со светопрозрачным заполнением. Соответственно, поле заполняется для 3 и 4 образцов, начиная со слов "со светопрозрачным заполнением..."
#
# По умолчанию - пустая строка.
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
sample_name_text_S = ''

# %% [markdown]
# #### Кодовая часть для ПИ по S на 4 образца.
#
# В ПИ по "S" 1 и 2 образцы - глухие двери, 3 и 4 - со светопрозрачным заполнением.
#
# По умолчанию - пустая строка.
#
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
sample_name_code_S = ''

# %% [markdown]
# ### Заводские номера образцов
# Заполняется в зависимости от количества образцов.
#
# По умолчанию - пустая строка.
#
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
serial_number_1 = '354'
serial_number_2 = '355'
serial_number_3 = ''
serial_number_4 = ''

# %% [markdown]
# ### Характеристики образцов
# Характеристики образцов - 'Габаритные размеры...'
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
sample_characteristics = 'Габаритные размеры по высоте 2550 мм, по ширине 1100 мм. Дверь изготовлена из алюминиевых профилей системы «Fire-Classic» серии «FC60» (ТУ 25.11.23-008-40833158-2021 с Изменением №1), с заполнением полостей камер профилей огнестойким составом «СОТЕРМ-1М» (ТУ 1526-008-17797468-2005) и стекломагниевыми листами (ТУ 5742-001-99226620-2008), остекление из стекла многослойного огнестойкого с заполнением межстекольного пространства полимерной композицией марки PFG-60 общей толщиной 26 мм (ТУ 5923-005-38208660-13 изм.1)'

# %% [markdown]
# ### Описание образцов
#
# По умолчанию в данном разделе будут автоматически прописаны самые часто встречающиеся стандартные фразы:
#
# - для 1пол двери:
#
# 'Дверь представляет собой конструкцию, состоящую из коробки (рамы) с подвижно закрепленным на ней с помощью петель полотном, которое в закрытом положении фиксируется врезным замком и доводчиком'
#
# - для 2пол двери:
#
# 'Дверь представляет собой конструкцию, состоящую из коробки (рамы) с подвижно закрепленным на ней с помощью петель полотном, состоящим из двух створок, которое в закрытом положении фиксируется врезным замком, доводчиком, задвижками'
#
# - для 1пол люка:
#
# 'Люк представляет собой конструкцию, состоящую из коробки (рамы) с подвижно закрепленным на ней с помощью петель полотном, которое в закрытом положении фиксируется врезным замком и доводчиком'
#
# - для 2пол люка:
#
# 'Люк представляет собой конструкцию, состоящую из коробки (рамы) с подвижно закрепленным на ней с помощью петель полотном, состоящим из двух створок, которое в закрытом положении фиксируется врезным замком, доводчиком, задвижками'
#
# - для ворот:
#
# 'Ворота представляют собой конструкцию, состоящую из коробки (рамы) с подвижно закрепленным на ней с помощью петель полотном, состоящим из двух створок, которое в закрытом положении фиксируется врезным замком, доводчиком, задвижками'
#
# - для ворот с калиткой:
#
# 'Ворота представляют собой конструкцию, состоящую из коробки (рамы) с подвижно закрепленным на ней с помощью петель полотном, состоящим из двух створок, которое в закрытом положении фиксируется врезным замком, доводчиком, задвижками; в активную створку встроена калитка, которая в закрытом положении фиксируется врезным замком и доводчиком.'
#
# - для окна:
#
# Для окна данный раздел не заполняется и по умолчанию в ПИ на окна раздел будет пустым.
#
#
# <b> Если необходимо </b> вписать нестандартную фразу - вписываем её в ячейку ниже данного комментария внутри одинарных кавычек.
#
# Например: sample_description = 'Сюда вписываем нестандартное описание конструкции'.
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
sample_description = ''

# %% [markdown]
# ### Название ТУ
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
technical_specifications = 'ТУ 24.12.11-004-40823158-2021'

# %% [markdown]
# ### Организационно-правовая форма организации - изготовителя образцов
#
# Организационно-правовая форма организации - изготовителя образцов (ООО, АО, ЗАО и т.д.). Прописывается полность, (например - Общество с ограниченной ответственностью) в именительном падеже, ед. числе.
#
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
manufactur_type = 'Общество с ограниченной ответственностью'

# %% [markdown]
# ### Название организации - изготовителя образцов
#
# Название, заключённое в двойные кавычки, вписывается между одинарных кавычек кода (например: '«Рога и копыта»')
#
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
manufactur_name = '«Ламир»'

# %% [markdown]
# ### Адрес изготовителя
#
# Отдельно вписываются:
# - manufactur_address_part1 -  Место нахождения (адрес юридического лица):
# - manufactur_address_part2 - Адрес места осуществления деятельности по изготовлению продукции:
#
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
manufactur_address_part1 = '113341, РОССИЯ, город Москва, вн.тер.г. Муниципальный округ Южное Бутово, улица Адмирала Лазарева, дом 50' 
manufactur_address_part2 = '142430, РОССИЯ, Московская область, Домодедовский район, территория Клен-Ям, дом 2'

# %% [markdown]
# ### Код ТН ВЭД ЕАЭС
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
code = '7610 10 000 0'

# %% [markdown]
# ### Направление на испытания (НИ)
#
# Тлько номер. Без даты.
#
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
referral_for_testing = r'146-НИ/23'

# %% [markdown]
# ### Дата направления на испытания (НИ)
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
referral_for_testing_date = '12.04.2023'

# %% [markdown]
# ### № и дата акта отбора образцов (АО)
#
# Вписываем и номер и дату.
#
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
act_of_sampling = r'146-АО/23 от 11.04.2023'

# %% [markdown]
# ### Номера печей
#
# Заполняется в зависимости от количества образцов/печей.
#
# Указываем двузначное число в одинарных кавычках.
#
# По умолчанию - пустая строка (нет образца - нет печи).
#
# Печи на Ленина:
# - 22
# - 28
# - 57
# - 58
#
# Печи на Горноспасательной
# - 20
# - 54
# - 56
#
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
furnace1 = '57'
furnace2 = '56'
furnace3 = ''
furnace4 = ''

# %% [markdown]
# ### Даты проведения испытаний
#
# Заполняется в зависимости от количества образцов/испытаний в формате 'дд.мм.гггг'.
#
# Указываем только дату, к которой "привязана" печь. Для E, EI, EIW в ПИ автоматически пропишется временной интервал проведения испытаний.
#
# По умолчанию - пустая строка.
#
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
test_dates1 = '18.04.2023'
test_dates2 = '15.04.2023'
test_dates3 = ''
test_dates4 = ''

# %% [markdown]
# ### Задаём значения для графиков
#
# <b>graph_</b> - задаём значения для построения графиков (значения вводятся внутри кавычек). В скобках находятся четверо кавычек, внутри которых следующая информация:
# - тип графика (числа только от 1 до 4, согласно типам графика)
# - ТП на графике (любые числа в формате: '1' или '1,2,5' или '1-5', согласно ТП на данном графике)
# - ТП на стекле (любые числа в формате: '1' или '1,2,5' или '1-5', согласно ТП, размещённым на стекле)
# - подпись к графику (строка с названием графика)
#
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
# Измерения температуры на необогреваемой поверхности полотна.
# Измерения температуры на необогреваемой поверхности коробки.
# Измерения температуры на необогреваемой поверхности обрамления и стекла.
# Измерения плотности потока теплового излучения.
# Измерения температуры на необогреваемой поверхности глухой части и импоста.
# Измерения температуры на необогреваемой фрамуги.
# Измерения температуры на необогреваемой поверхности полотна ворот.
# Измерения температуры на необогреваемой поверхности полотна калитки.
# Измерения температуры на необогреваемой поверхности люка.
# Измерения температуры на необогреваемой поверхности вентиляционной решетки.
# Измерение температуры в уплотнениях корпуса клапана в проёме печи. (А1)
# Измерение температуры на необогреваемой наружной поверхности корпуса клапана. (А1)
# Измерение температуры на необогреваемой поверхности заслонки клапана. (А4)

# %%
# задаём значения для графиков (тип графика, ТП на графике, ТП на стекле, подпись к графику) 
graph_1 = ('1', '1-5', '0', 'Измерения температуры на необогреваемой поверхности полотна.')
graph_2 = ('3', '6-10', '0', 'Измерения температуры на необогреваемой поверхности коробки.')
graph_3 = ('4', '1', '0', 'Измерения плотности потока теплового излучения.')
graph_4 = ('0', '0-0', '0', 'chart_name')
graph_5 = ('0', '0-0', '0', 'chart_name')
graph_6 = ('0', '0-0', '0', 'chart_name')
graph_7 = ('0', '0-0', '0', 'chart_name')
graph_8 = ('0', '0-0', '0', 'chart_name')
graph_9 = ('0', '0-0', '0', 'chart_name')
graph_10 = ('0', '0-0', '0', 'chart_name')

# %% [markdown]
# ### Уточнение по остеклению (для таблицы - поведение образцов)
#
# наличие стекла (0 - нет, 1 - есть, 2 - несколько стекол на одном образце)
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
glazing = 1

# %% [markdown]
# ### Пользовательский график
#
# Задаём процентное соотношение по X и Y для каждого сегмента графика
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
# пользовательские настройки
segment1_user = (0.20, 0.20)
segment2_user = (0.20, 0.20)
segment3_user = (0.20, 0.20)
segment4_user = (0.20, 0.20)
segment5_user = (0.20, 0.20) 

# пользователський шаг делений по оси Х
x_axis_pitch_user = 0

# %% [markdown]
# ### Количество термопар
#
# Заполняется в зависимости от количества термопар на одном образце.
#
# Если 2 образца испытываются одновременно, то число образцов будет автоматически умножено на 2.
#
# Для ПИ по S - 1 штука.
#
#
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
thermoelectric_converter_val = 10

# %% [markdown]
# ### Порядок проведения испытаний
#
# По умолчанию прописаны стандартные формулировки, которые применяются в ПИ, для всех типов ПИ ('E', 'EI', 'EIW', 'S') и типов конструкций ('дверь 1пол', 'дверь 2пол', 'люк 1пол', 'люк 2пол', 'ворота', 'ворота с калиткой', 'окно').
#
# При формировании ПИ, в зависимости от типа конструкции, количества образцов и т.д. формулировка будет преобразовываться и корректно заполняться.
#
# Необходимо заполнить только 3 пункта:
# - gaps_closing - заполнение зазора
# - installing_samples - двери были установлены так, что огневое воздействие...
# - health_check - проверка работоспособности
#
# <b>Внимательно ознакомтесь с данными пунктами перед заполнением.</b> ❗

# %% [markdown]
# #### Информация по заполнению зазоров (gaps_closing)
#
# Варианты заполнения переменной gaps_closing:
# - 'г'
# - 'ц'
#
# Использованы 2 самые часто встречающиеся формулировки:
#
# - 'Зазор между строительным проемом и коробкой по всему периметру заполнялся минеральной ватой плотностью 50 кг/м3 и огнестойкой монтажной пеной Profflex Firestop 65 с последующим оштукатуриванием <b>штукатуркой гипсовой белой WHITE (ГОСТ Р 58279-2018)</b>'
#
# Соответственно - '<b>г</b>' (сокращение от слова гипс).
#
# - 'Зазор между строительным проемом и коробкой по всему периметру заполнялся минеральной ватой плотностью 50 кг/м3 и огнестойкой монтажной пеной Profflex Firestop 65 с последующим оштукатуриванием <b>цементно-песчаным раствором в соотношении 1:4</b>'
#
# Соответственно - '<b>ц</b>' (сокращение от слова цемент).
#
# <b> Если необходимо </b> вписать нестандартную фразу, то вместо вариантов 'г' или 'ц' - вписываем фразу в ячейку ниже данного комментария внутри одинарных кавычек.
#
# Например: gaps_closing = 'Сюда вписываем нестандартную информацию по заполнению зазоров'.
#
# <b>ВАЖНО!</b>
#
# Метры квадратные или кубические вписывются особым образом!
#
# Например:
# - вместо "...плотностью 50 кг/м3..."   прописываем   "...плотностью 50 кг/м\u00B3..."
# - вместо "...площадью 10 м2..."   прописываем   "...площадью 10 м\u00B2..."

# %%
# пример отображения текста
print('м2', 'м3')
print('м\u00B2', 'м\u00B3')
# Out:
# м2 м3
# м² м³

# %% [markdown]
# <div class="alert alert-success">
# <b> Обязательно к заполнению </b> 👇
# </div>

# %%
gaps_closing = 'г'

# %% [markdown]
# #### Зазоры между подвижными и неподвижными частями образцов
#
# По умолчанию табличка с зазорами заполняется значениями "2,0  2,5  3,0" мм, в случайном порядке.
#
# <b> Если необходимо </b> вписать определённый размер зазора, который будет отображаться во всей таблице - вписываем его в ячейку ниже данного комментария внутри одинарных кавычек, с разделителем - запятой, например: '4,0'
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
rd = ''

# %% [markdown]
# #### Огневое воздействие (installing_samples)
#
# По умолчанию В ПИ будет прописан один из следующих вариантов фразы (в зависимости от количества образцов, типа конструкции и т.д.):
#
# - ...были установлены так, чтобы огневое воздействие на образец №1 было со стороны расположения петель, а на образец №2 – со стороны противоположной расположению петель.
#
# - ...были установлены так, чтобы огневое воздействие на образец №1 было со стороны расположения петель, а на образец №2 - со стороны противоположной расположению петель. Образцы монтировались в одну ограждающую конструкцию и испытывались одновременно.
#
# - ...были установлены так, чтобы огневое воздействие на образцы №№1, 3 было со стороны расположения петель, а на образцы №№2, 4 – со стороны противоположной расположению петель.
#
# <b> Если необходимо </b> вписать нестандартную фразу - вписываем её в ячейку ниже данного комментария внутри одинарных кавычек.
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
installing_samples = ''

# %% [markdown]
# #### Проверка работоспособности (health_check)
#
# По умолчанию В ПИ будет прописан один из следующих вариантов фразы (в зависимости от типа ПИ, конструкции и т.д.):
#
# Для ПИ по EI
# - (1 пол) Проверку работоспособности дверей проводили открыванием полотна на расстояние 300 мм и возвращением в закрытое состояние устройством закрывания.
# - (2 пол) Проверку работоспособности дверей проводили открыванием полотна на расстояние 300 мм и возвращением в закрытое состояние активной створки устройством закрывания, пассивной створки - вручную.
# - (плюс вариант для ворот с калиткой) Проверку работоспособности ворот проводили открыванием створок ворот на расстояние 300 мм и возвращением створок в закрытое состояние вручную. Проверку работоспособности калитки проводили открыванием полотна калитки на расстояние 300 мм и возвращением в закрытое состояние устройством закрывания
#
#
# Для ПИ по EIW
# - Проверку работоспособности дверей проводили десятикратным циклом открывания и закрывания.
#
# Для ПИ по S
# - Наработка эксплуатационного износа дверей проводилась путём пятидесятикратного цикла открывания и закрывания с углом открывания полотна не менее 90°.
#
# Двери тут - для примера. В зависимости от конструкции - в ПИ будет подставленно то, что необходимо (люки, ворота). Обращаем внимание/проверяем только саму формулировку!
#
# <b> Если необходимо </b> вписать нестандартную фразу - вписываем её в ячейку ниже данного комментария внутри одинарных кавычек.
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
health_check_var = ''

# %% [markdown]
# ### Год написания протокола
#
# По умолчанию - 23 (то есть 2023 год). Когда наступит следующий год, надо будет заменить 23 на 24.
# Данная информация отражается в шифре протокола, в колонтитуле и в самом низу первого листа протокола.
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
year = 23

# %% [markdown]
# ### Подписывает протокол
#
# <b> Если необходимо </b> вписать кого-то конкретного - вписываем в ячейку ниже данного комментария внутри одинарных кавычек.
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
test_engineer = 'П.В. Петров'

# %% [markdown]
# ### Путь к папке с шаблоном ПИ
#
# Задаём путь к директории с файлом шаблоном ПИ
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
path = r'D:\Денис\ПОЖАРка'

# %% [markdown]
# ### Путь к папке с файлами ИО и СИ
#
# Задаём путь к директории с excel файлами
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
path1 = r'D:\Денис\ПОЖАРка\Метрология'

# %% [markdown]
# ### Путь к папке со схемой размещения термопар на образцах
#
# Задаём путь к директории с папками по испытаниям.
#
# Файл в папке называем тип конструкции + "схема".
# Например "дверь 1пол схема".
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
path2 = r'D:\Денис\ПОЖАРка\Протоколы'

# %% [markdown]
# ### Путь к папке с данными о погоде
#
# Задаём путь к директории с excel файлом (формат файла должен быть Excel, а не Excel 97-2003).
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
path_w = r'D:\Денис\ПОЖАРка'

# %% [markdown]
# ### Путь для сохранения временных файлов/графиков
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
charts_path = r'D:\Денис\ПОЖАРка'

# %% [markdown]
# ### Путь к картинке-формуле для ПИ по S
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
formula_path = r'D:\Денис\ПОЖАРка'

# %% [markdown]
# ### Путь к PDF файлу чертежу
#
# Задаём путь к директории с папками по испытаниям.
#
# Файл в папке называем тип конструкции + "чертеж".
# Например "дверь 1пол чертеж".
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
path_pdf = r'D:\Денис\ПОЖАРка\Протоколы'

# %% [markdown]
# ### Путь к jpg файлу фото
#
# Задаём путь к директории с папками по испытаниям.
#
# Файл в папке называем тип конструкции + "фото".
# Например "дверь 1пол фото".
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
path_foto = r'D:\Денис\ПОЖАРка\Протоколы'

# %% [markdown]
# ### Путь к PDF файлу АО
#
# Задаём путь к директории с папками по испытаниям.
#
# Файл в папке называем номер АО + "АО".
# Например "146 АО".
#
# <div class="alert alert-warning">
# <b> Заполняется опционально </b> 👀
# </div>

# %%
path_act_of_sampling = r'D:\Денис\ПОЖАРка\Протоколы'

# %% [markdown]
# ## Данные испытательной лаборатории
#
# По умолчанию всё заполнено для АПБ, в том виде, который есть на момент написания кода.
#
# Необходимые правки вносятся по мере каких-либо изменений.

# %% [markdown]
# ### Титульный лист "УТВЕРЖДАЮ"
# По умолчанию - "Руководитель ИЛ".
#
# <b> Если необходимо </b> вписать кого-то другого - вписываем в ячейку ниже данного комментария внутри одинарных кавычек.
#
# <div class="alert alert-danger">
# <b> Без реальной необходимости - не заменяем </b> ❌
# </div>

# %%
approve = 'Руководитель ИЛ'

# %% [markdown]
# ### ФИО утверждающего ПИ
# По умолчанию указан руководитель ИЛ
#
# <b> Если необходимо </b> вписать кого-то другого - вписываем в ячейку ниже данного комментария внутри одинарных кавычек.
#
# <div class="alert alert-danger">
# <b> Без реальной необходимости - не заменяем </b> ❌
# </div>

# %%
approve_name = 'И.И. Иванов'

# %% [markdown]
# ### Наименование организации
# По умолчанию - "ООО «Пожарная Лаборатория»".
#
# <b> Если необходимо </b> вписать что-то другое - вписываем в ячейку ниже данного комментария внутри одинарных кавычек.
#
# <div class="alert alert-danger">
# <b> Без реальной необходимости - не заменяем </b> ❌
# </div>

# %%
testing_laboratory = 'ООО «Пожарная Лаборатория»'

# %% [markdown]
# ### Шифр ПИ
# По умолчанию - "№ ХХХ-С/ТР-".
#
# <b> Если необходимо </b> вписать что-то другое - вписываем в ячейку ниже данного комментария внутри одинарных кавычек.
#
# <div class="alert alert-danger">
# <b> Без реальной необходимости - не заменяем </b> ❌
# </div>

# %%
protocol_code =  '№ ХХХ-С/ТР-'

# %% [markdown]
# ### Заголовок ПИ с информацией об ИЛ (состоит из 4 части)
# Поделён на 4 части из-за разного форматирования (шрифты и т.д.) для удобства заполнения и, при необходимости, замены.
#
# <div class="alert alert-danger">
# <b> Без реальной необходимости - не заменяем </b> ❌
# </div>

# %%
protocol_header_part_1 = 'Общество с ограниченной ответственностью \n\
«Пожарная Лаборатория» \n\
(ООО «Пожарная Лаборатория»)'

protocol_header_part_2 = 'Юридический адрес: 102036, Россия, город Москва, улица \n\
зелёная, дом 3, строение 4, ком. 38'

protocol_header_part_3 = 'Испытательная лаборатория Общества с ограниченной ответственностью \n\
«Пожарная Лаборатория» (ИЛ ООО «Пожарная Лаборатория»)'

protocol_header_part_4 = 'Адреса мест осуществления деятельности: \n\
201480, Россия, Московская обл., г. Чехов, мкр. Западный, ул. Гооворова, д. 3, \n\
автогараж (81:66:028802:210); \n\
101550, Россия, Ростовская обл., г. Батайск, мкр. Восточный, ул. Левитана, д. 4, \n\
нежилое здание (склад металлический) (31:66:789204:86); \n\
333678, Россия, Новгородская обл., Новый р-н, г. Новочеркаск, ул. Орлова, дом 5, \n\
пристроенное нежилое здание – пристройка к цеху № 7 (91:33:058707:698), 3 этаж (комнаты №№ 14, 19, 22), \n\
5 этаж (комнаты №№ 2, 5) \n\
Телефон: +71231234567, адрес электронной почты: gwerwqrqr@mail.ru \n\
Уникальный номер записи об аккредитации в реестре аккредитованных лиц: РРРР.RU.СС28'

# %% [markdown]
# ### Контактные данные заказчика (2 лист ПИ)
#
# <b> Если необходимо </b> вписать что-то другое - вписываем в ячейку ниже данного комментария внутри одинарных кавычек.
#
# <div class="alert alert-danger">
# <b> Без реальной необходимости - не заменяем </b> ❌
# </div>

# %%
contact_details = 'Место нахождения (адрес юридического лица): 102036, РОССИЯ, \
город Москва, улица зелёная, дом 3, строение 4, комната 38. \
Адрес места осуществления деятельности: 333678, РОССИЯ, Новгородская область, \
Новый район, город Новочеркаск, улица Орлова, дом 5, пристройка к цеху №7 \
(Лит. Ж), эт.3, ком. №№ 1, 3, 9, 12; 333678, РОССИЯ, город Москва, \
улица Зелёная, дом 2, стр. 3, комната 4, этаж 3, помещение №1. \
Телефон: +71231234567, +71231234567. Электронная почта: gwerwqrqr@mail.ru. \
Уникальный номер записи об аккредитации в реестре аккредитованных лиц: № РРРР.RU.СС28'

# %% [markdown]
# ## Установка необходимых библиотек, импорт модулей

# %%
# устанавливаем библиотеку python-docx
# pip install python-docx

# устанавливаем библиотеку pymorphy2 - морфологический анализатор русских текстов
# pip install pymorphy2

# устанавливаем библиотеку docxtpl
# pip install docxtpl

# %%
import pandas as pd
import numpy as np
import datetime
import random
import math
import re
import os
import docx
from docx import Document
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.enum.table import WD_ALIGN_VERTICAL
from docx.shared import Mm, Cm, Pt, Inches
from docxtpl import DocxTemplate
from openpyxl.styles import Color, PatternFill
from openpyxl import load_workbook
from pdf2image import convert_from_path
import pymorphy2
from pymorphy2.tokenizers import simple_word_tokenize
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline, BSpline
from scipy.ndimage import uniform_filter1d
from detect_delimiter import detect
import dateutil.parser as dparser

from docx.oxml import OxmlElement
from docx.oxml.ns import qn

# %% [markdown]
# ## Предобработка внесённых данных

# %% [markdown]
# ### Наименование образца

# %% [markdown]
# #### Функция для склонения текста в нужные падежные формы

# %%
def text_change(text, new_case, new_number):
    # создаём объект класса MorphAnalyzer
    morph = pymorphy2.MorphAnalyzer()

    # создаём пустой список для результатов анализа слов
    result_word_parsing = []

    # проходим по всему тексту и складываем результаты анализа в созданный выше список
    for word in simple_word_tokenize(text):
        # производим разбор каждого слова
        word_info = morph.parse(word)[0]
        # указываем, что необходимо вывести после разбора каждого слова
        result_word_parsing.append(
            {
                'word': word,
                'POS': word_info.tag.POS,
                'case': word_info.tag.case,
                'number': word_info.tag.number            
            })

    # создаём пустой список для слов
    new_text = []

    # проходим по результату грамматического разбора обрабатываемого текста
    for i in range(len(result_word_parsing)):

        # проверяем слова на соответствие определённым грамматическим признакам
        if (result_word_parsing[i]['POS'] == 'NOUN') and \
        (result_word_parsing[i]['case'] == 'nomn' or result_word_parsing[i]['case'] == 'accs'):

            # получаем слово, которое необходимо преобразовать
            changeable_word = result_word_parsing[i]['word']
            # разбираем слово на грамматические признаки
            changeable_word = morph.parse(result_word_parsing[i]['word'])[0]
            # преобразовываем слово необходимым образом
            changeable_word = changeable_word.inflect({new_case, new_number}).word
            # добавляем слово в список
            new_text.append(changeable_word)

        # проверяем слова на соответствие определённым грамматическим признакам
        elif (result_word_parsing[i]['POS'] == 'ADJF') and \
        (result_word_parsing[i]['case'] == 'nomn'):

            # получаем слово, которое необходимо преобразовать
            changeable_word = result_word_parsing[i]['word']
            # разбираем слово на грамматические признаки
            changeable_word = morph.parse(result_word_parsing[i]['word'])[0]
            # преобразовываем слово необходимым образом
            changeable_word = changeable_word.inflect({new_case, new_number}).word
            # добавляем слово в список
            new_text.append(changeable_word)

        # также добавляем слова, которые не изменились в процессе обработки     
        else:
            new_text.append(result_word_parsing[i]['word'])   

    # соединим список в одну строку, уберём лишние пробелы перед запятой
    new_text = ' '.join(new_text).replace(' ,', ',')        

    # вернём получившийся результат
    return new_text

# %% [markdown]
# на вход принимает:
# - изменяемый текст (text) в им.п., ед.ч.
# - падеж, который хотим получить (new_case)
# - число, которое хотим получить (new_number)

# %% [markdown]
# #### Формирование наименования образца в различных формах

# %% [markdown]
# ##### Убираем лишние пробелы в текстовой и кодовой частях наименования образца

# %%
# убираем лишние пробелы в текстовой части наименования образца
sample_name_text = " ".join(sample_name_text.split())

# убираем лишние пробелы в кодовой части наименования образца
sample_name_code = " ".join(sample_name_code.split())

# для 3 и 4 образцов
if sample_name_text_S != '':
    
    # убираем лишние пробелы в текстовой части наименования образца
    sample_name_text_S = " ".join(sample_name_text_S.split())

    # убираем лишние пробелы в кодовой части наименования образца
    sample_name_code_S = " ".join(sample_name_code_S.split())

# %% [markdown]
# ##### Полное наименование образца в именительном падеже, множ. числе

# %%
# преобразуем наименование образца в именительный падеж, множ. число
sample_name_text_nomn_plur = text_change(sample_name_text, 'nomn', 'plur').capitalize() # добавим заглавную букву 

# полное наименование образца в именительном падеже, множ. числе
full_sample_name_nomn_plur = sample_name_text_nomn_plur + ', ' + sample_name_code

# в случае люков - "стальной" и "глухой" никак не хотят склоняться
# чтобы не переписывать функцию для склонения из-за одного слова, добавим "костыль" для люка
if construction_type == 'люк 1пол' or construction_type == 'люк 2пол':
    if 'стальной' in full_sample_name_nomn_plur:
        full_sample_name_nomn_plur = full_sample_name_nomn_plur.replace('стальной', 'стальные')
if construction_type == 'люк 1пол' or construction_type == 'люк 2пол':
    if 'глухой' in full_sample_name_nomn_plur:
        full_sample_name_nomn_plur = full_sample_name_nomn_plur.replace('глухой', 'глухие')

# %% [markdown]
# ##### Полное наименование образца в родительном падеже, множ. числе

# %%
# преобразуем наименование образца в родительный падеж, множ. число
sample_name_text_gent_plur = text_change(sample_name_text, 'gent', 'plur')

# полное наименование образца в родительном падеже, множ. числе
full_sample_name_gent_plur = sample_name_text_gent_plur + ', ' + sample_name_code


# в случае ворот - "противопожарные" никак не хотят склоняться
# чтобы не переписывать функцию для склонения из-за одного слова, добавим "костыль" для ворот
if construction_type == 'ворота' or construction_type == 'ворота с калиткой':
    if 'противопожарные' in full_sample_name_gent_plur:
        full_sample_name_gent_plur = full_sample_name_gent_plur.replace('противопожарные', 'противопожарных')
        

# в случае люков - "стальной" и "глухой" никак не хотят склоняться
# чтобы не переписывать функцию для склонения из-за одного слова, добавим "костыль" для люка
if construction_type == 'люк 1пол' or construction_type == 'люк 2пол':
    if 'стальной' in full_sample_name_gent_plur:
        full_sample_name_gent_plur = full_sample_name_gent_plur.replace('стальной', 'стальных')
if construction_type == 'люк 1пол' or construction_type == 'люк 2пол':
    if 'глухой' in full_sample_name_gent_plur:
        full_sample_name_gent_plur = full_sample_name_gent_plur.replace('глухой', 'глухих')

# %% [markdown]
# #### 4 образца в ПИ (для ПИ по S на 4 образца)

# %%
# собираем формулировку для S - союз "и", текст и код и добавляем это в ПИ, если у нас 4 образца по S
full_sample_name_S = ''

if test_type == 'S' and serial_number_3 != '':
    full_sample_name_S = ' и ' + sample_name_text_S + ', ' + sample_name_code_S

# %% [markdown]
# ### Нумерация образцов

# %%
# Для наименования образца(ов) испытаний

# со строчной первой буквой и с зав.№
sample_num_1 = 'образец №1 зав. №'
sample_num_2 = 'образец №2 зав. №'
sample_num_3 = 'образец №3 зав. №'
sample_num_4 = 'образец №4 зав. №'

# %%
# Для всех ПИ, кроме ПИ по S на 4 образца
full_sample_code = sample_num_1 + serial_number_1 + ', ' + sample_num_2 + serial_number_2

# Для ПИ по S на 4 образца

full_sample_code_S = ''

if test_type == 'S' and serial_number_3 != '':
    full_sample_code_S = ' (' + sample_num_3 + serial_number_3 + ', ' + sample_num_4 + serial_number_4 + ')'

# %%
# Для всего документа 

# со строчной первой буквой
sample_1 = 'образец №1'
sample_2 = 'образец №2'
sample_3 = 'образец №3'
sample_4 = 'образец №4'

# с заглавной первой буквой
sample_1_с = 'Образец №1'
sample_2_с = 'Образец №2'
sample_3_с = 'Образец №3'
sample_4_с = 'Образец №4'

# %% [markdown]
# ### Характеристики образца

# %%
if sample_description != '':
    sample_description = sample_description
    
elif construction_type == 'дверь 1пол':
    sample_description = 'Дверь представляет собой конструкцию, состоящую из коробки (рамы) \
с подвижно закрепленным на ней с помощью петель полотном, \
которое в закрытом положении фиксируется врезным замком и доводчиком.'
    
elif construction_type == 'дверь 2пол':
    sample_description = 'Дверь представляет собой конструкцию, состоящую из коробки (рамы) \
с подвижно закрепленным на ней с помощью петель полотном, состоящим из двух створок, \
которое в закрытом положении фиксируется врезным замком, доводчиком, задвижками.'
    
elif construction_type == 'люк 1пол':
    sample_description = 'Люк представляет собой конструкцию, состоящую из коробки (рамы) \
с подвижно закрепленным на ней с помощью петель полотном, \
которое в закрытом положении фиксируется врезным замком и доводчиком.'
    
elif construction_type == 'люк 2пол':
    sample_description = 'Люк представляет собой конструкцию, состоящую из коробки (рамы) \
с подвижно закрепленным на ней с помощью петель полотном, состоящим из двух створок, \
которое в закрытом положении фиксируется врезным замком, доводчиком, задвижками.'
    
elif construction_type == 'ворота':
    sample_description = 'Ворота представляют собой конструкцию, состоящую из коробки (рамы) \
с подвижно закрепленным на ней с помощью петель полотном, состоящим из двух створок, \
которое в закрытом положении фиксируется врезным замком, доводчиком, задвижками.'
    
elif construction_type == 'ворота с калиткой':
    sample_description = 'Ворота представляют собой конструкцию, состоящую из коробки (рамы) \
с подвижно закрепленным на ней с помощью петель полотном, состоящим из двух створок, \
которое в закрытом положении фиксируется врезным замком, доводчиком, задвижками; \
в активную створку встроена калитка, которая в закрытом положении фиксируется врезным замком и доводчиком.'
    
elif construction_type == 'окно':
    sample_description = ''

# %% [markdown]
# ### Изготовитель образцов

# %%
if manufactur_type == 'Индивидуальный предприниматель':
    
    # полное наименование изготовителя в иминительном падеже
    manufactur_nomn = manufactur_type + ' ' + manufactur_name
    
    # преобразуем наименование изготовителя образцов в творительный падеж, ед. число (ИП)
    manufactur_type_ablt = text_change(manufactur_type, 'ablt', 'sing').capitalize() # добавим заглавную букву
    
    # преобразуем наименование изготовителя образцов в творительный падеж, ед. число (ФИО)
    manufactur_name_ablt = text_change(manufactur_name, 'ablt', 'sing').title() # добавим заглавную букву

    # полное наименование изготовителя в творительном падеже
    manufactur_ablt = manufactur_type_ablt + ' ' + manufactur_name_ablt
    
elif  manufactur_type != 'Индивидуальный предприниматель':   
    
    # полное наименование изготовителя в иминительном падеже
    manufactur_nomn = manufactur_type + ' ' + manufactur_name
    
    # преобразуем наименование изготовителя образцов в творительный падеж, ед. число
    manufactur_ablt = text_change(manufactur_type, 'ablt', 'sing').capitalize() # добавим заглавную букву 

    # полное наименование изготовителя в творительном падеже
    manufactur_ablt = manufactur_ablt + ' ' + manufactur_name

# %% [markdown]
# ### Характеристика заказываемой услуги

# %%
# заполнение раздела ПИ исходя из типа протокола

# E 
if test_type == 'E':
    characteristics_ordered_service = 'Проведение испытаний для определения предела огнестойкости представленных образцов \
по параметру E (потеря целостности)'
    
 # EI
elif test_type == 'EI':
    characteristics_ordered_service = 'Проведение испытаний для определения предела огнестойкости представленных образцов \
по параметрам E (потеря целостности), I (потеря теплоизолирующей способности)'

# EIW
elif test_type == 'EIW':
    characteristics_ordered_service = 'Проведение испытаний для определения предела огнестойкости представленных образцов \
по параметрам E (потеря целостности), I, W (потеря теплоизолирующей способности)'

# S
elif test_type == 'S':
    characteristics_ordered_service = 'Проведение испытаний для определения предела огнестойкости представленных образцов \
по параметру S (потеря дымогазонепроницаемости)'

# %% [markdown]
# ### Идентификация применяемого метода
#
# Прмеры записи степеней: 10 в пятой степени - '10\u2075'; метр кубический - 'м\u00B3' (см. последнюю строчку следующей ячейки)

# %%
# заполнение раздела ПИ исходя из типа протокола

# E
if test_type == 'E':
    used_method = 'Испытания проводились по ГОСТ Р 53308-2009 «Конструкции строительные. \
Светопрозрачные ограждающие конструкции и заполнения проёмов. Метод испытаний на огнестойкость». \
При испытании учитывалось предельное состояние конструкции - потеря целостности (Е), которая характеризуется:	 \n\
	- появлением устойчивого пламени на необогреваемой поверхности образца длительностью 10 секунд и более; \n\
	- образованием в конструкции образца сквозных отверстий (щелей) с размерами, позволяющими щупу диаметром (6±1) мм \
проникать и перемещаться вдоль отверстия (щели) на расстояние не менее 150 мм, или щупу диаметром (25±1) мм \
беспрепятственно проникать в сквозные отверстия.'
    
# EI
elif test_type == 'EI':
    used_method = 'Испытания проводились по ГОСТ Р 53307-2009 «Конструкции строительные. Противопожарные двери и ворота. \
Метод испытаний на огнестойкость». При испытании учитывались следующие предельные состояния конструкции:	 \n\
	а) потеря целостности (Е), которая характеризуется:	 \n\
	- появлением устойчивого пламени на необогреваемой поверхности образца длительностью 10 секунд и более; \n\
	- воспламенением или возникновением тления со свечением ватного тампона в результате воздействия огня \
    или горячих газов, проникающих через трещины, щели, отверстия, притворы;	 \n\
	- образованием в конструкции образца сквозных отверстий (щелей) с размерами, позволяющими щупу диаметром (6±2) мм \
проникать и перемещаться вдоль отверстия (щели) на расстояние не менее 150 мм, или щупу диаметром (25±2) мм \
беспрепятственно проникать в сквозные отверстия;	 \n\
	- выпадением полотна образца из коробки или же самой коробки из стандартной ограждающей конструкции.	 \n\
	б) потеря теплоизолирующей способности (I), которая характеризуется повышением температуры на необогреваемой \
поверхности полотна в среднем более чем на 140°С, или в любой контролируемой точке этой поверхности на 180°С \
в сравнении с температурой конструкции до испытания, или достижением температуры 300°С на коробке образца \
независимо от температуры конструкции до испытания.'    

# EIW
elif test_type == 'EIW':
    used_method = 'Испытания проводились в соответствии с требованиями ГОСТ Р 53308-2009 «Конструкции строительные. \
Светопрозрачные ограждающие конструкции и заполнения проёмов. Метод испытаний на огнестойкость». \
При испытании учитывались следующие предельные состояния конструкции:	 \n\
	а) потеря целостности (Е), которая характеризуется:	 \n\
	- появлением устойчивого пламени на необогреваемой поверхности образца длительностью 10 секунд и более; \n\
	- воспламенением или возникновением тления со свечением ватного тампона в результате воздействия огня \
    или горячих газов, проникающих через трещины, щели, отверстия и т.п.;	 \n\
	- образованием в конструкции образца сквозных отверстий (щелей) с размерами, позволяющими щупу диаметром (6±1) мм \
    проникать и перемещаться вдоль отверстия (щели) на расстояние не менее 150 мм, или щупу диаметром (25±1) мм \
    беспрепятственно проникать в сквозные отверстия.	 \n\
	б) потеря теплоизолирующей способности (I), которая характеризуется:	 \n\
	- повышением температуры на необогреваемой поверхности конструкции в среднем более чем на 140°С \
или в любой контролируемой точке этой поверхности более чем на 180°С в сравнении с температурой конструкции \
до испытания;	 \n\
	- достижением температуры 300°С (независимо от начальной температуры конструкции до испытания) \
на необогреваемой поверхности коробки конструкции;	 \n\
	в) потеря теплоизолирующей способности (W), которая характеризуется достижением допустимой величины плотности потока \
теплового излучения, равной 3,5 кВт/м\u00B2, измеренной на расстоянии 0,5м от необогреваемой поверхности конструкции.'
    
# S
elif test_type == 'S':
    used_method = 'Испытания проводились по ГОСТ Р 53303-2009 «Конструкции строительные. Противопожарные двери и ворота. \
Метод испытаний на дымогазопроницаемость». Потеря дымогазонепроницаемости (S) определяется временем от начала нагрева \
и нагружения избыточным давлением испытываемой конструкции до момента уменьшения сопротивления дымогазопроницанию \
этой конструкции ниже минимально допустимого значения. Удельное сопротивление дымогазопроницанию конструкций дверей \
различных типоразмеров не должно быть менее 1,96·10\u2075 м\u00B3/кг.'

# %% [markdown]
# ### Место и дата(ы) осуществления лабораторной деятельности

# %% [markdown]
# ####  Место проведения испытания

# %%
# списки печей по адресам
lenina = ['22', '28', '57', '58']
gornaya = ['20', '54', '56']

# %%
# адреса расположения печей

furnace_address_lenina = '11111, РОССИЯ, Московская область, город Чехов, микрорайон Западный, \
улица Львова, дом 1, нежилое здание (склад металлический) (21:22:022204:20)'

furnace_address_gornaya = '11111, РОССИЯ, Московская область, город Чехов, микрорайон Восточный, \
улица Говорова, дом 6, автогараж (21:36:333102:444)'

# %%
# определяем адрес 1 печи
if furnace1 in lenina:
    furnace_address1 = furnace_address_lenina
else:
    furnace_address1 = furnace_address_gornaya
    
# определяем адрес 2 печи
if furnace2 in lenina:
    furnace_address2 = furnace_address_lenina
else:
    furnace_address2 = furnace_address_gornaya
    
# определяем адрес 3 печи (для ПИ по S на 4 образца)
if furnace3 != 0 and furnace3 in lenina:
    furnace_address3 = furnace_address_lenina
elif furnace3 != 0 and furnace3 not in lenina: 
    furnace_address3 = furnace_address_gornaya
elif furnace3 == 0: 
    furnace_address3 = ''

# определяем адрес 4 печи (для ПИ по S на 4 образца)
if furnace4 != 0 and furnace4 in lenina:
    furnace_address4 = furnace_address_lenina
elif furnace4 != 0 and furnace4 not in lenina: 
    furnace_address4 = furnace_address_gornaya
elif furnace4 == 0: 
    furnace_address4 = ''

# %% [markdown]
# ####  Даты проведения испытания

# %%
# переводим даты из типа "строка" к типу "дата" Для всех ПИ, кроме ПИ по S
if test_type != 'S':
    test_dates1_date = datetime.datetime.strptime(test_dates1, '%d.%m.%Y').date()
    test_dates2_date = datetime.datetime.strptime(test_dates2, '%d.%m.%Y').date()

# %%
# найдём даты начала испытаний для ПИ по E, EI, EIW (период проведения испытаний 2 дня)
if test_type != 'S':
    delta_test_dates1_date = (test_dates1_date - datetime.timedelta(days=1))
    test_period1 = delta_test_dates1_date.strftime('%d.%m.%Y') + '-' + test_dates1_date.strftime('%d.%m.%Y')
    delta_test_dates2_date = (test_dates2_date - datetime.timedelta(days=1)) 
    test_period2 = delta_test_dates2_date.strftime('%d.%m.%Y') + '-' + test_dates2_date.strftime('%d.%m.%Y')

# %% [markdown]
# #### Соберём вместе дату и место проведения испытаний

# %%
# Для ПИ по S на 2 образца
if test_type == 'S' and test_dates3 == '':
    place_and_date_test_1 = sample_1_с + ': ' + furnace_address1 + '; ' + test_dates1 + ' г.	\n	  '
    place_and_date_test_2 = sample_2_с + ': ' + furnace_address2 + '; ' + test_dates2 + ' г.'
    place_and_date_test_3 = ''
    place_and_date_test_4 = ''

# Для ПИ по S на 4 образца
elif test_dates3 != '':
    place_and_date_test_1 = sample_1_с + ': ' + furnace_address1 + '; ' + test_dates1 + ' г.	\n	  '
    place_and_date_test_2 = sample_2_с + ': ' + furnace_address2 + '; ' + test_dates2 + ' г.	\n	  '
    place_and_date_test_3 = sample_3_с + ': ' + furnace_address3 + '; ' + test_dates3 + ' г.	\n	  '
    place_and_date_test_4 = sample_4_с + ': ' + furnace_address4 + '; ' + test_dates4 + ' г.'
    
# если два образца в одной печи одновременно
elif furnace1 == furnace2 and test_dates1 == test_dates2:
    place_and_date_test_1 = 'Образцы №№ 1, 2: ' + furnace_address1 + '; ' + test_period1 + ' г.'
    place_and_date_test_2 = ''
    place_and_date_test_3 = ''
    place_and_date_test_4 = ''

# Для ПИ по E, EI, EIW
else:
    place_and_date_test_1 = sample_1_с + ': ' + furnace_address1 + '; ' + test_period1 + ' г.	\n	  '
    place_and_date_test_2 = sample_2_с + ': ' + furnace_address2 + '; ' + test_period2 + ' г.'
    place_and_date_test_3 = ''
    place_and_date_test_4 = ''

# %% [markdown]
# ### Сведения об отборе образцов (ветвление)

# %%
# заполнение раздела исходя из типа протокола
if test_type == 'EIW' or test_type == 'E':
    see_app = '(см. приложение 1).'
else: 
    see_app = ''

# %% [markdown]
# ### Порядок проведения испытаний (ветвление)
#
# Для начала зададим все формулировки по всем типам ПИ, чтобы потом вносить в них изменения.

# %%
#E
if test_type == 'E':
    test_procedure_1 = 'Перед монтажом образцы находились 72 часа в помещении, в котором в дальнейшем испытывались. '
    test_procedure_2 = 'Контроль внешнего вида образцов, проверка габаритных размеров. '
    test_procedure_3 = 'Монтаж образцов проводился в проём из железобетонных блоков толщиной 250 мм согласно инструкции по монтажу изготовителя. '
    test_procedure_6 = 'Контроль качества монтажа образцов. '
    test_procedure_8 = ''
    test_procedure_9 = ''
    test_procedure_10 = 'Печные термопары устанавливались так, чтобы их горячие спаи были на удалении 900 мм от стены огневой камеры и на расстоянии 100 мм от обогреваемой поверхности образца. '
    test_procedure_11 = ''
    test_procedure_12 = 'Начало испытаний соответствовало моменту включения форсунок печи. '
    test_procedure_13 = ''
    test_procedure_14 = 'Температурный режим в печи соответствовал ГОСТ 30247.0-94 п. 6. '
    test_procedure_15 = 'В процессе испытаний регистрировались: температура и давление в печи, поведение образцов, время наступления предельного состояния. '

# %%
#EI
if test_type == 'EI':
    test_procedure_1 = 'Перед монтажом образцы находились 72 часа в помещении, в котором в дальнейшем испытывались. '
    test_procedure_2 = 'Контроль внешнего вида образцов, проверка габаритных размеров, запоров. '
    test_procedure_3 = 'Монтаж образцов проводился в проём из железобетонных блоков толщиной 250 мм согласно инструкции по монтажу изготовителя. '
    test_procedure_6 = 'Контроль качества монтажа образцов и их работоспособности. Замеры зазоров между подвижными и неподвижными частями конструкции образцов (см. табл. 1). Все размеры соответствовали сборочному чертежу. '
    test_procedure_8 = 'Двери открывались и закрывались плавно, без рывков и заеданий. '
    test_procedure_9 = 'Установка термопар на необогреваемой поверхности дверей осуществлялась по ГОСТ Р 53307-2009 (см. рис. 1). '
    test_procedure_10 = 'Печные термопары устанавливались так, чтобы их горячие спаи были на удалении 900 мм от стены огневой камеры и на расстоянии 100 мм от обогреваемой поверхности образца. '
    test_procedure_11 = ''
    test_procedure_12 = 'Начало испытаний соответствовало моменту включения форсунок печи. '
    test_procedure_13 = ''
    test_procedure_14 = 'Температурный режим в печи соответствовал ГОСТ 30247.0-94 п. 6. '
    test_procedure_15 = 'В процессе испытаний регистрировались: температура и давление в печи, температура на необогреваемой поверхности образцов, поведение образцов. '

# %%
#EIW
if test_type == 'EIW':
    test_procedure_1 = 'Перед монтажом образцы находились 72 часа в помещении, в котором в дальнейшем испытывались. '
    test_procedure_2 = 'Контроль внешнего вида образцов, проверка габаритных размеров, запоров. '
    test_procedure_3 = 'Монтаж образцов проводился в проём из железобетонных блоков толщиной 250 мм согласно инструкции по монтажу изготовителя. '
    test_procedure_6 = 'Контроль качества монтажа образцов и их работоспособности. '
    test_procedure_8 = 'Двери открывались и закрывались плавно, без рывков и заеданий. '
    test_procedure_9 = 'Установка термопар на необогреваемой поверхности дверей осуществлялась в соответствии с ГОСТ Р 53308-2009 (см. рис. 1). Установка датчика плотности потока теплового излучения в геометрическом центре двери на расстоянии 500 мм от поверхности. '
    test_procedure_10 = 'Печные термопары устанавливались так, чтобы их горячие спаи были на удалении 900 мм от стены огневой камеры и на расстоянии 100 мм от обогреваемой поверхности образца. '
    test_procedure_11 = ''
    test_procedure_12 = 'Начало испытаний соответствовало моменту включения форсунок печи. '
    test_procedure_13 = ''
    test_procedure_14 = 'Температурный режим в печи соответствовал ГОСТ 30247.0-94 п. 6. '
    test_procedure_15 = 'В процессе испытаний регистрировались: температура и давление в печи, температура на необогреваемой поверхности образцов, значение плотности потока теплового излучения, поведение образцов. '

# %%
#S
if test_type == 'S':
    test_procedure_1 = ''
    test_procedure_2 = 'Контроль внешнего вида образцов, проверка габаритных размеров, запоров. '
    test_procedure_3 = 'Монтаж образцов проводился в проём из железобетонных блоков толщиной 250 мм согласно инструкции по монтажу изготовителя. '
    test_procedure_6 = ''
    test_procedure_8 = 'Двери открывались и закрывались плавно, без рывков и заеданий. '
    test_procedure_9 = ''
    test_procedure_10 = 'Печные термопары устанавливались так, чтобы их горячие спаи были на удалении 900 мм от стены огневой камеры и на расстоянии 100 мм от обогреваемой поверхности образца. '
    test_procedure_11 = 'Монтаж пневмокамеры и стенда для определения расходных характеристик. 	\n	Проверка плотности вентсистемы испытательного стенда. Образец блокировался газонепроницаемым материалом и на нём создавалась разность давлений 70 Па. При проверке расход воздуха через неплотности вентсистемы не превышал 0,01 кг/с. '
    test_procedure_12 = '	\n	Начало испытаний соответствовало моменту включения форсунок печи'
    test_procedure_13 = ', непосредственно перед которым на образцах устанавливался перепад давлений (70±7) Па. '
    test_procedure_14 = 'Температурный режим в печи соответствовал ГОСТ 30247.0-94 п. 6. '
    test_procedure_15 = ''

# %%
# Тип конструкции 'дверь 1пол' или 'дверь 2пол'
if construction_type == 'дверь 1пол' or construction_type == 'дверь 2пол':
    test_procedure_8 = test_procedure_8.replace('', '')
    test_procedure_9 = test_procedure_9.replace('', '')

# Тип конструкции 'люк 1пол' или 'люк 2пол'
elif construction_type == 'люк 1пол' or construction_type == 'люк 2пол':
    test_procedure_8 = test_procedure_8.replace('Двери', 'Люки')
    test_procedure_9 = test_procedure_9.replace('дверей', 'люков').replace('двери', 'люка')    

# Тип конструкции 'ворота'
elif construction_type == 'ворота':
    test_procedure_8 = test_procedure_8.replace('Двери', 'Ворота')
    test_procedure_9 = test_procedure_9.replace('дверей', 'ворот').replace('двери', 'ворот')

# Тип конструкции 'ворота с калиткой'
elif construction_type == 'ворота с калиткой':
    test_procedure_8 = test_procedure_8.replace('Двери', 'Ворота и калитка')
    test_procedure_9 = test_procedure_9.replace('дверей', 'ворот').replace('двери', 'ворот')

# %%
# исключение для ворот с калиткой
if construction_type == 'ворота с калиткой':
    test_procedure_6 = test_procedure_6.replace('см. табл. 1', 'см. табл. 1а, 1б')

# %% [markdown]
# #### Заделка зазоров (gaps_closing)

# %%
if gaps_closing == 'г':
    gaps_closing = 'Зазор между строительным проемом и коробкой по всему периметру заполнялся минеральной ватой плотностью 50 кг/м\u00B3 и огнестойкой монтажной пеной Profflex Firestop 65 с последующим оштукатуриванием штукатуркой гипсовой белой WHITE (ГОСТ Р 58279-2018). '
elif gaps_closing == 'ц':
    gaps_closing = 'Зазор между строительным проемом и коробкой по всему периметру заполнялся минеральной ватой плотностью 50 кг/м\u00B3 и огнестойкой монтажной пеной Profflex Firestop 65 с последующим оштукатуриванием цементно-песчаным раствором в соотношении 1:4. ' 
else:
    gaps_closing = gaps_closing

# %% [markdown]
# #### Огневое воздействие (installing_samples)

# %%
# Распишем варианты текста

installing_samples_var_1 = 'Двери были установлены так, чтобы огневое воздействие на образец №1 было со стороны расположения петель, а на образец №2 – со стороны противоположной расположению петель. '
installing_samples_var_2 = 'Двери были установлены так, чтобы огневое воздействие на образец №1 было со стороны расположения петель, а на образец №2 - со стороны противоположной расположению петель. Образцы монтировались в одну ограждающую конструкцию и испытывались одновременно. '
installing_samples_var_3 = 'Двери были установлены так, чтобы огневое воздействие на образцы №№1, 3 было со стороны расположения петель, а на образцы №№2, 4 – со стороны противоположной расположению петель. '

# %%
# E (оставляем пустую строчку)
if test_type == 'E':
    installing_samples = installing_samples
    
# S (2 образца)
elif test_type == 'S' and test_dates3 == '':
    installing_samples = installing_samples_var_1
    
# S (4 образца)
elif test_type == 'S' and test_dates3 != '':
    installing_samples = installing_samples_var_3
    
# EI, EIW (2 образца в одной конструкции)
elif test_dates1 == test_dates2 and furnace1 == furnace2:
    installing_samples = installing_samples_var_2

# свой вариант    
elif installing_samples != '':
    installing_samples = installing_samples
    
# EI, EIW (2 образца)    
else:
    installing_samples = installing_samples_var_1

# %%
# Тип конструкции 'дверь 1пол' или 'дверь 2пол'
if construction_type == 'дверь 1пол' or construction_type == 'дверь 2пол':
    installing_samples = installing_samples.replace('', '')

# Тип конструкции 'люк 1пол' или 'люк 2пол'
elif construction_type == 'люк 1пол' or construction_type == 'люк 2пол':
    installing_samples = installing_samples.replace('Двери', 'Люки')   

# Тип конструкции 'ворота' или 'ворота с калиткой'
elif construction_type == 'ворота' or construction_type == 'ворота с калиткой':
    installing_samples = installing_samples.replace('Двери', 'Ворота')

# %% [markdown]
# #### Проверка работоспособности (health_check)

# %%
# Распишем варианты текста

# Для ПИ по EI
health_check_var_1 = 'Проверку работоспособности дверей проводили открыванием полотна на расстояние 300 мм и возвращением в закрытое состояние устройством закрывания. '
health_check_var_2 = 'Проверку работоспособности дверей проводили открыванием полотна на расстояние 300 мм и возвращением в закрытое состояние активной створки устройством закрывания, пассивной створки - вручную. '

# исключение для ворот с калиткой
health_check_var_3 = 'Проверку работоспособности ворот проводили открыванием створок ворот на расстояние 300 мм и возвращением створок в закрытое состояние вручную. Проверку работоспособности калитки проводили открыванием полотна калитки на расстояние 300 мм и возвращением в закрытое состояние устройством закрывания. '

# Для ПИ по EIW
health_check_var_4 = 'Проверку работоспособности дверей проводили десятикратным циклом открывания и закрывания. '

# Для для ПИ на S
health_check_var_5 = 'Наработка эксплуатационного износа дверей проводилась путём пятидесятикратного цикла открывания и закрывания с углом открывания полотна не менее 90°. '

# %%
# E
if test_type == 'E':
    health_check = ''
    
# EI 1 пол    
elif (test_type == 'EI') & (construction_type == 'дверь 1пол' or construction_type == 'люк 1пол'):
    health_check = health_check_var_1
    
# EI 2 пол
elif (test_type == 'EI') & (construction_type == 'дверь 2пол' or construction_type == 'люк 2пол' or construction_type == 'ворота'):
    health_check = health_check_var_2
    
# EI исключение для ворот с калиткой
elif construction_type == 'ворота с калиткой':
    health_check = health_check_var_3
    
# EIW
elif test_type == 'EIW':
    health_check = health_check_var_4

# S
elif test_type == 'S':
    health_check = health_check_var_5

# %%
# Тип конструкции 'дверь 1пол' или 'дверь 2пол'
if construction_type == 'дверь 1пол' or construction_type == 'дверь 2пол':
    health_check = health_check.replace('', '')

# Тип конструкции 'люк 1пол' или 'люк 2пол'
elif construction_type == 'люк 1пол' or construction_type == 'люк 2пол':
    health_check = health_check.replace('дверей', 'люков')   

# Тип конструкции 'ворота'
elif construction_type == 'ворота':
    health_check = health_check.replace('дверей', 'ворот')

# свой вариант
elif health_check_var != '':
    health_check = health_check_var
    
# Тип конструкции 'ворота с калиткой'
elif construction_type == 'ворота с калиткой':
    health_check = health_check_var_3
    
# Тип конструкции 'окно'
elif construction_type == 'окно':
    health_check = ''

# %% [markdown]
# #### Собираем всю конструкцию (test_procedure)

# %%
if test_type == 'E':
    test_procedure = \
    test_procedure_1 + '	\n	' + \
    test_procedure_2 + '	\n	' + \
    test_procedure_3 + \
    gaps_closing + \
    installing_samples + '\n	' + \
    test_procedure_6 + \
    health_check + \
    test_procedure_8 + '	\n	' + \
    test_procedure_9 + \
    test_procedure_10 + '	\n	' + \
    test_procedure_11 + \
    test_procedure_12 + \
    test_procedure_13 + \
    test_procedure_14 + '	\n	' + \
    test_procedure_15

# %%
if test_type == 'EI':
    test_procedure = \
    test_procedure_1 + '	\n	' + \
    test_procedure_2 + '	\n	' + \
    test_procedure_3 + \
    gaps_closing + \
    installing_samples + '\n	' + \
    test_procedure_6 + \
    health_check + \
    test_procedure_8 + '	\n	' + \
    test_procedure_9 + \
    test_procedure_10 + '	\n	' + \
    test_procedure_11 + \
    test_procedure_12 + \
    test_procedure_13 + \
    test_procedure_14 + '	\n	' + \
    test_procedure_15

# %%
if test_type == 'EIW':
    test_procedure = \
    test_procedure_1 + '	\n	' + \
    test_procedure_2 + '	\n	' + \
    test_procedure_3 + \
    gaps_closing + \
    installing_samples + '\n	' + \
    test_procedure_6 + \
    health_check + \
    test_procedure_8 + '	' + \
    test_procedure_9 + \
    test_procedure_10 + '	\n	' + \
    test_procedure_11 + \
    test_procedure_12 + \
    test_procedure_13 + \
    test_procedure_14 + '	\n	' + \
    test_procedure_15

# %%
if test_type == 'S':
    test_procedure = \
    test_procedure_2 + '	\n	' + \
    test_procedure_3 + \
    gaps_closing + \
    installing_samples + '\n	' + \
    health_check + \
    test_procedure_8 + \
    '	' + test_procedure_10 + '	\n	' + \
    test_procedure_11 + \
    test_procedure_12 + \
    test_procedure_13 + \
    test_procedure_14

# %% [markdown]
# ## Работа с файлом шаблоном протокола

# %% [markdown]
# ### Открываем файл

# %%
# путь к файлу шаблону
path = rf'{path}'.replace('\\', '/')

# имя файла шаблона, который располагается в выше указанной папке
template_name = '/template'

# расширение файла шаблона
extension = '.docx'

# открываем шаблон протокола
template = docx.Document(path+template_name+extension)

# %% [markdown]
# ### Заполнение титульного листа и вводной части протокола

# %%
# Автозамена вводных данных

# переопределяем файл для работы с модулем DocxTemplate (автозаполнение render(context))
template = DocxTemplate(path+template_name+extension)

# %%
# определяем словарь переменных контекста,  
# которые определены в шаблоне документа DOCX
# заполняем шаблон данными
context = {
    'approve' : approve, # утверждает ПИ (должность)
    'approve_name' : approve_name, # утверждает ПИ (ФИО)
    'testing_laboratory' : testing_laboratory, # наименование ИЛ
    'protocol_code' : protocol_code, # шифр ПИ 
    'protocol_header_part_1' : protocol_header_part_1, # шапка титульного (инфориация по ИЛ)
    'protocol_header_part_2' : protocol_header_part_2, # шапка титульного (инфориация по ИЛ)
    'protocol_header_part_3' : protocol_header_part_3, # шапка титульного (инфориация по ИЛ)
    'protocol_header_part_4' : protocol_header_part_4, # шапка титульного (инфориация по ИЛ)
    'contact_details' : contact_details, # наименование и контактные данные заказчика (информация по ОС)
    'full_sample_name_nomn_plur' : full_sample_name_nomn_plur, # полное название образца Им.п.множ.ч.
    'full_sample_name_gent_plur' : full_sample_name_gent_plur, # полное название образца Род.п.множ.ч.
    'full_sample_name_S' : full_sample_name_S, # доп. название образца для ПИ по S на 4 образца
    'technical_specifications' : technical_specifications, # ТУ
    'code' : code, # код ТН ВЭД ЕАЭС 
    'sample_characteristics' : sample_characteristics, # характеристики образца (габариты и т.д.)
    'sample_description' : sample_description, # описание образца (описание конструкции)
    'referral_for_testing' : referral_for_testing, # направление на испытания  
    'referral_for_testing_date' : referral_for_testing_date, # дата направления на испытания
    'manufactur_nomn' : manufactur_nomn, # наименование изготовителя Им.п.
    'manufactur_ablt' : manufactur_ablt, # наименование изготовителя Тв.п.
    'manufactur_address_part1' : manufactur_address_part1, # Место нахождения изготовителя
    'manufactur_address_part2' : manufactur_address_part2, # Адрес места осуществления деятельности изготовителя
    'act_of_sampling' : act_of_sampling, # акт отбора образцов (вместе с датой)
    'full_sample_code' : full_sample_code, # обр. №...зав.№...
    'full_sample_code_S' : full_sample_code_S, # обр. №...зав.№... для ПИ по S
    'sample_1' : sample_1, # "образец № 1"
    'sample_2' : sample_2, # "образец № 2"
    'sample_3' : sample_3, # "образец № 3"
    'sample_4' : sample_4, # "образец № 4"
    'sample_1_с' : sample_1_с, # "Образец № 1" 
    'sample_2_с' : sample_2_с, # "Образец № 2"
    'sample_3_с' : sample_3_с, # "Образец № 3"
    'sample_4_с' : sample_4_с, # "Образец № 4"
    'characteristics_ordered_service' : characteristics_ordered_service, # характеристика заказываемой услуги
    'place_and_date_test_1' : place_and_date_test_1, #
    'place_and_date_test_2' : place_and_date_test_2, #
    'place_and_date_test_3' : place_and_date_test_3, #
    'place_and_date_test_4' : place_and_date_test_4, #
    'see_app' : see_app, # "см. акт отбора"
    'used_method' : used_method, # идентификация применяемого метода
    'year' : year, # год написания ПИ
    'test_procedure' : test_procedure # Порядок проведения испытаний
        }

# подставляем контекст в шаблон
template.render(context)

# %% [markdown]
# ### Схема размещения термопар на образцах

# %%
# добавим "drawing_num" для нумерации рисунков в ПИ
drawing_num = 1

# %%
# путь к изображению
path2 = rf'{path2}\{referral_for_testing.split("-")[0]}'.replace('\\', '/')
# имя файла - схемы, который располагается в выше указанной папке
doc_name_jpg = f'/{construction_type} схема'
# расширение файла схемы
extension_jpg = '.jpg'

# %%
if test_type in ['EI', 'EIW']:
    # добавим схему

    # добавляем пустой абзац
    scheme = template.add_paragraph()
    # добавляем пустой прогон
    run = scheme.add_run()
    # теперь в прогон вставляем изображение
    run.add_picture(path2+doc_name_jpg+extension_jpg, width=Cm(17))
    # выравниваем изображение посередине страницы
    scheme.alignment =  WD_ALIGN_PARAGRAPH.CENTER    
 
    # добавим подпись к схеме

    # добавим параграф
    scheme = template.add_paragraph(f'Рисунок {drawing_num}. Схема размещения термопар на образцах.')
    # выравниваем текст по середине
    scheme.alignment = WD_ALIGN_PARAGRAPH.CENTER
    # название шрифта по умолчанию
    scheme.style.font.name = 'Times New Roman'
    # размер шрифта по умолчанию
    scheme.style.font.size = Pt(10)
    
    # если в ПИ нет схемы размещения, то дальнейшая нумерация рисунков начнётся с единицы.
    # если есть схема - с двойки
    drawing_num += 1
    
    #добавим пустой абзац между разделами
    p = template.add_paragraph()

# %% [markdown]
# ### Зазоры между подвижными и неподвижными частями образцов

# %%
# добавим "table_num" для нумерации таблиц в ПИ
table_num = 1

# %%
# стиль ко всему документу

# стиль 
style = template.styles['Normal']
# шрифт
style.font.name = 'Times New Roman'
# высота шрифта
style.font.size = Pt(10)
# отступ над строкой
style.paragraph_format.space_before = Cm(0)
# отстут после строки
style.paragraph_format.space_after = Cm(0)

# %%
# если заданы конкретные цифры по зазору
if rd != '':
    rd = [(rd + ' ')*2+rd]
else:
    # данные для заполнения таблицы для 1 пол образцов (+ для калитки ворот)
    rd = ['2,0 2,0 2,0', '2,5 2,5 2,5', '3,0 3,0 3,0']

# %%
# данные для всей таблички для 1 пол образцов (+ для калитки ворот)
data = [
    ['', 'Горизонтальный\nнижний', 'Горизонтальный\nверхний', 'Вертикальный\nлевый', 'Вертикальный\nправый'],
    ['Образец №1', random.choice(rd), random.choice(rd), random.choice(rd), random.choice(rd)], 
    ['Образец №2', random.choice(rd), random.choice(rd), random.choice(rd), random.choice(rd)]
]

df1 = pd.DataFrame(data, columns=['', '', '', '', ''])

# %%
# данные для всей таблички для 2 пол образцов
data = [
    ['', 'Горизонтальный\nнижний', 'Горизонтальный\nверхний', 'Вертикальный\nлевый', 'Вертикальный\nправый', 'Между\nстворками'],
    ['Образец №1', random.choice(rd), random.choice(rd), random.choice(rd), random.choice(rd), random.choice(rd)],
    ['Образец №2', random.choice(rd), random.choice(rd), random.choice(rd), random.choice(rd), random.choice(rd)]
]

df2 = pd.DataFrame(data, columns=['', '', '', '', '', ''])

# %%
# надпись перед таблицей

if construction_type in ['дверь 1пол', 'люк 1пол'] and test_type == 'EI':
    # добавляем абзац с текстом
    p = template.add_paragraph(f'Таблица {table_num}. Результаты измерений зазоров между подвижными и неподвижными частями образцов.')
    # убираем интервал после текста
    p.paragraph_format.space_after = Pt(0)
    # добавляем отступ слева (в данном случае он равен 2 см)
    p.paragraph_format.left_indent = Cm(2)
    # если в ПИ нет таблиц, то дальнейшая нумерация начнётся с единицы, если есть - с двойки
    table_num += 1
    
elif construction_type in ['дверь 2пол', 'люк 2пол', 'ворота'] and test_type == 'EI':
    # добавляем абзац с текстом
    p = template.add_paragraph(f'Таблица {table_num}. Результаты измерений зазоров между подвижными и неподвижными частями образцов.')
    # убираем интервал после текста
    p.paragraph_format.space_after = Pt(0)
    # добавляем отступ слева (в данном случае он равен 0.5 см)
    p.paragraph_format.left_indent = Cm(0.5)
    # если в ПИ нет таблиц, то дальнейшая нумерация начнётся с единицы, если есть - с двойки
    table_num += 1
    
elif construction_type == 'ворота с калиткой' and test_type == 'EI':
    # добавляем абзац с текстом
    p = template.add_paragraph(f'Таблица {table_num}а. Результаты измерений зазоров между подвижными и неподвижными частями ворот.')
    # убираем интервал после текста
    p.paragraph_format.space_after = Pt(0)
    # добавляем отступ слева (в данном случае он равен 0.5 см)
    p.paragraph_format.left_indent = Cm(0.5) 
    # если в ПИ нет таблиц, то дальнейшая нумерация начнётся с единицы, если есть - с двойки
    table_num += 1

# %%
# выбор данных для заполнения таблички
if construction_type in ['дверь 1пол', 'люк 1пол']:
    df = df1
elif construction_type in ['дверь 2пол', 'люк 2пол', 'ворота', 'ворота с калиткой']:
    df = df2

# %%
# создаём табличку из df
if construction_type != 'окно' and test_type == 'EI':

    # добавляем переменную, которой передаём количество строк (shape[0]+1) и столбцов (shape[1]) таблицы
    table = template.add_table(df.shape[0]+1, df.shape[1], style='Table Grid')

    # выравниваем таблицу по центру страницы
    table.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # добавляем строку - заголовок
    for j in range(df.shape[-1]):
        table.cell(0,j).text = df.columns[j]

    # добавляем остальную часть данных
    for i in range(df.shape[0]):
        for j in range(df.shape[-1]):
            table.cell(i+1,j).text = str(df.values[i,j])

# %%
# зададим ширину столбцам (указываем ширину ячеек - 3 и ед. измерения - см)

# ширина столбца (числовое значение) (если дробное, то записывается через точку, например 3.5)
column_width = 3
# единица измерения ширина столбца (Pt, Inches, Cm и т.д.)
unit_measurement = Cm

if construction_type != 'окно' and test_type == 'EI':

    # функция для задания ширины ячейки таблицы
    def set_col_widths(table_name, column_width, unit_measurement):
        for row in table_name.rows:
            for cell in row.cells:
                cell.width = unit_measurement(column_width)

    set_col_widths(table, column_width, unit_measurement)

# %%
if construction_type in ['дверь 1пол', 'люк 1пол'] and test_type == 'EI':
    # "сшиваем" ячейки в необходимых местах для формирования определённого вида таблицы
    table.cell(0, 0).merge(table.cell(1, 0))
    table.cell(0, 1).merge(table.cell(0, 4))
    
elif construction_type in ['дверь 2пол', 'люк 2пол', 'ворота', 'ворота с калиткой'] and test_type == 'EI':
    # "сшиваем" ячейки в необходимых местах для формирования определённого вида таблицы
    table.cell(0, 0).merge(table.cell(1, 0))
    table.cell(0, 1).merge(table.cell(0, 5))

# %%
if construction_type != 'окно' and test_type == 'EI':

    # добавляем необходимый текст в нужную ячейку
    table.cell(0, 2).text = 'Размеры зазоров, мм'

    # выравниваем текст в ячейках по центру
    for i in range(len(table.rows)):
        for j in range(len(table.columns)):
            cell = table.rows[i].cells[j]
            cell_paragraph = cell.paragraphs[0]
            cell_paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER

# %%
# для ворот с калиткой необходимо добавить вторую таблицу

#добавим пустой абзац между таблицами для ворот с калиткой
if construction_type == 'ворота с калиткой' and test_type == 'EI':
    p = template.add_paragraph()

# %%
if construction_type == 'ворота с калиткой' and test_type == 'EI':
    # надпись перед таблицей

    # добавляем абзац с текстом
    p = template.add_paragraph('Таблица 1б. Результаты измерений зазоров между полотном калитки и ворот.')
    # убираем интервал после текста
    p.paragraph_format.space_after = Pt(0)
    # добавляем отступ слева (в данном случае он равен 2 см)
    p.paragraph_format.left_indent = Cm(2)

    # табличка для калитки
    df = df1

    # добавляем переменную, которой передаём количество строк (shape[0]+1) и столбцов (shape[1]) таблицы
    table = template.add_table(df.shape[0]+1, df.shape[1], style='Table Grid')

    # выравниваем таблицу по центру страницы
    table.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # добавляем строку - заголовок
    for j in range(df.shape[-1]):
        table.cell(0,j).text = df.columns[j]

    # добавляем остальную часть данных
    for i in range(df.shape[0]):
        for j in range(df.shape[-1]):
            table.cell(i+1,j).text = str(df.values[i,j])


    # зададим ширину столбцам (указываем ширину ячеек - 3 и ед. измерения - см)
    # ширина столбца (числовое значение) (если дробное, то записывается через точку, например 3.5)
    column_width = 3
    # единица измерения ширина столбца (Pt, Inches, Cm и т.д.)
    unit_measurement = Cm


    # функция для определения ширины ячейки таблицы
    def set_col_widths(table_name, column_width, unit_measurement):
        for row in table_name.rows:
            for cell in row.cells:
                cell.width = unit_measurement(column_width)
    set_col_widths(table, column_width, unit_measurement)

    # "сшиваем" ячейки в необходимых местах для формирования определённого вида таблицы
    table.cell(0, 0).merge(table.cell(1, 0))
    table.cell(0, 1).merge(table.cell(0, 4))

    # добавляем необходимый текст в нужную ячейку
    table.cell(0, 2).text = 'Размеры зазоров, мм'


    # выравниваем текст в ячейках по центру
    for i in range(len(table.rows)):
        for j in range(len(table.columns)):
            cell = table.rows[i].cells[j]
            cell_paragraph = cell.paragraphs[0]
            cell_paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER

# %%
#добавим пустой абзац между разделами
if test_type == 'EI':
    p = template.add_paragraph()

# %% [markdown]
# ### Перечень ИО и СИ

# %%
#добавим название раздела
p = template.add_paragraph()
p.alignment = WD_ALIGN_PARAGRAPH.CENTER
run = p.add_run('9. Перечень испытательного оборудования и средств измерения, использованных при испытаниях')
run.font.bold = True

# %%
# исправим в Pandas предупреждение: SettingWithCopyWarning
pd.options.mode.chained_assignment = None

# %% [markdown]
# #### Функция по добавлению текста перед таблицей

# %%
# функция по добавлению текста перед таблицей (номер таблицы, текст/образец)
def add_name_table_func(table_num, text1, text2):
    table_num = table_num
    #добавим пустой абзац
    p = template.add_paragraph()
    # добавляем абзац с текстом
    p = template.add_paragraph(f'Таблица {table_num}. {text1}. {text2}.')
    # убираем интервал после текста
    p.paragraph_format.space_after = Pt(0)
    # добавляем отступ слева (в данном случае он равен 0.8 см)
    p.paragraph_format.left_indent = Cm(0.8)

# %% [markdown]
# #### Функция по выбору необходимого ексель файла по дате испытаний

# %%
# функция по выбору необходимого ексель файла по дате испытаний
def excel_file_func(test_dates, path):
    # путь к excel файлам
    path = rf'{path1}'.replace('\\', '/')

    # изменение текущего каталога на необходимый
    os.chdir(path)

    # выведем все файлы из каталога
    filenames_list = []
    for dirpath, dirnames, filenames in os.walk("."):
        # перебрать файлы
        for filename in filenames:
            filenames_list.append(os.path.join(dirpath, filename))

    # список дат из названий файлов директории
    filenames_date_list = []
    for i in filenames_list:
        filenames_date_list.append(dparser.parse(i,fuzzy=True, dayfirst=True).date())

    # обязательно сортируем спсиок
    filenames_date_list.sort()

    # дата испытаний (из строки в формат datetime.date)
    test_dates = datetime.datetime.strptime(test_dates, '%d.%m.%Y').date()

    # поиск даты равной дате испытаний или меньшей ближайшей
    filenames_date = filenames_date_list[np.searchsorted(filenames_date_list, test_dates, side='right')-1]

    # переведём дату к строке для её поиска в названиях файлов
    filenames_date = filenames_date.strftime('%d.%m.%Y')

    # выведем полное название файла
    res = [i for i in filenames_list if filenames_date in i]
    res = ''.join(res)

    # полный путь к excel файлу
    path_ex = rf'{path}'.replace('\\', '/')

    # имя excel файла, который располагается в выше указанной папке
    doc_name_ex = res.replace('.\\', '/')

    # читаем файл и преобразовываем его в df
    excel_file = pd.ExcelFile(path_ex+doc_name_ex)
    
    return excel_file

# %% [markdown]
# #### Функция для формирования таблицы ИО в зависимости от типа испытания

# %%
# функция для формирования таблицы ИО в зависимости от типа испытания
def io_table_func(excel_file, test_type):
    # загрузим необходимый лист в виде df
    df1 = excel_file.parse('ИО')

    # для удобства переведём значения в колонке 'Инвентарный номер' к типу str
    df1['Инвентарный номер'] = df1['Инвентарный номер'].astype(str)

    if test_type == 'E' or test_type == 'S':
        # выведем таблицу с необходимой печью + необходимым доп.ИО
        test_equipment_table = df1[((df1['Инвентарный номер'].str.contains(furnace)) & 
                                    (df1['Инвентарный номер'].str.len() <= 3))]   
        
    elif test_type == 'EI' or test_type == 'EIW': 
        # столбец "место установки"
        location_mi_col = 'место установки'
        # выведем таблицу с необходимой печью + необходимым доп.ИО
        test_equipment_table1 = df1[((df1['Инвентарный номер'].str.contains(furnace)) & 
                                    (df1['Инвентарный номер'].str.len() <= 3))]
        
        if furnace in lenina:
            # и если в столбце "место установки" есть "Л" - "Ленина"
            if any(df1[location_mi_col].str.contains('Л')):
                # выберем строчку с прибором по адресу "Л" - "Ленина"
                test_equipment_table2 = df1[(df1['Испытательное оборудование'].str.contains('ШС-40')) & (df1[location_mi_col] == 'Л')].head(1)

            # если в столбце "место установки" нет "Л" - "Ленина", берём прибор с "Г" - "Горная"
            elif any(df1[location_mi_col].str.contains('Г')):
                # выберем строчку с прибором по адресу "Г" - "Горная"
                test_equipment_table2 = df1[(df1['Испытательное оборудование'].str.contains('ШС-40')) & (df1[location_mi_col] == 'Г')].head(1)

        elif furnace in gornaya:
            # и если в столбце "место установки" есть "Г" - "Горная"
            if any(df1[location_mi_col].str.contains('Г')):
                # выберем строчку с прибором по адресу "Г" - "Горная"
                test_equipment_table2 = df1[(df1['Испытательное оборудование'].str.contains('ШС-40')) & (df1[location_mi_col] == 'Г')].head(1)

            # если в столбце "место установки" нет "Г" - "Горная", берём прибор с "Л" - "Ленина"
            elif any(df1[location_mi_col].str.contains('Л')):
                # выберем строчку с прибором по адресу "Л" - "Ленина"
                test_equipment_table2 = df1[(df1['Испытательное оборудование'].str.contains('ШС-40')) & (df1[location_mi_col] == 'Л')].head(1)

        # сшиваем 2 подтаблички в одну таблицу
        test_equipment_table = pd.concat([test_equipment_table1, test_equipment_table2])
        
    # удалим "лишнее" из столбца "Номер протокола аттестации" 
    test_equipment_table['Номер протокола аттестации'] = test_equipment_table['Номер протокола аттестации'].str.replace('№ ','')

    # добавим 'протокол № ' к колонке 'Номер протокола аттестации'
    test_equipment_table['Номер протокола аттестации'] = 'протокол № ' + test_equipment_table['Номер протокола аттестации'].map(str)

    # добавим "зав. № " к колонке "Заводской номер"
    test_equipment_table['Заводской номер'] = 'зав. № ' + test_equipment_table['Заводской номер']

    # уберём из колонки "Заводской номер" значения с "б/н" 
    test_equipment_table['Заводской номер'] = test_equipment_table['Заводской номер'].replace('зав. № б/н', '')

    # скорректируем столбец "Испытательное оборудование". добавим "зав. №" + столбец "Заводской номер"
    test_equipment_table['Испытательное оборудование'] = test_equipment_table['Испытательное оборудование'] + ' ' + \
    test_equipment_table['Заводской номер']

    # переведём колонки "Дата аттестации" и "Дата очередной аттестации" к типу datetime
    test_equipment_table[['Дата аттестации', 'Дата очередной аттестации']] = \
    test_equipment_table[['Дата аттестации', 'Дата очередной аттестации']].apply(pd.to_datetime)

    # приведём даты к нужному виду
    test_equipment_table['Дата аттестации'] = test_equipment_table['Дата аттестации'].dt.strftime('%d.%m.%Y')
    test_equipment_table['Дата очередной аттестации'] = test_equipment_table['Дата очередной аттестации'].dt.strftime('%d.%m.%Y')

    # объединим необходимые столбцы и создадим из них новый
    test_equipment_table['Документ аттестации оборудования'] = test_equipment_table['Номер протокола аттестации'] + ' от ' + \
    test_equipment_table['Дата аттестации']

    # удалим лишние столбцы
    test_equipment_table = test_equipment_table.drop(['Номер протокола аттестации', 
                                                      'Заводской номер', 
                                                      'Дата аттестации',
                                                      'Unnamed: 0',
                                                      'Инвентарный номер бухгалтерии',
                                                      'место установки',
                                                      'Unnamed: 9'], 
                                                     axis=1).reset_index(drop=True)

    # расставим колонки в необходимом порядке
    test_equipment_table = test_equipment_table[['Испытательное оборудование', 
                                                 'Инвентарный номер', 
                                                 'Документ аттестации оборудования', 
                                                 'Дата очередной аттестации']]

    # переименуем колонки
    test_equipment_table.rename(columns = {'Испытательное оборудование':'Наименование испытательного оборудования', 
                                           'Дата очередной аттестации':'Срок действия'}, inplace = True)

    # создадим и заполним таблицу в Word

    # добавляем переменную, которой передаём количество строк (shape[0]+1) и столбцов (shape[1]) таблицы
    table = template.add_table(test_equipment_table.shape[0]+1, test_equipment_table.shape[1], style='Table Grid')

    # выравниваем таблицу по центру страницы
    table.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # добавляем строку - заголовок
    for j in range(test_equipment_table.shape[-1]):    
        table.cell(0,j).text = test_equipment_table.columns[j]

    # добавляем остальную часть данных
    for i in range(test_equipment_table.shape[0]):
        for j in range(test_equipment_table.shape[-1]):
            table.cell(i+1,j).text = str(test_equipment_table.values[i,j])    

    # зададим ширину столбцам
    def set_col_widths(table):
        widths = (Cm(9.35), Cm(3.10), Cm(3.30), Cm(2.03))
        for row in table.rows:
            for idx, width in enumerate(widths):
                row.cells[idx].width = width
    set_col_widths(table)

    # выравниваем текст во всех колонках,кроме первой по центру
    for i in range(len(table.rows)):
        for j in range(1,(len(table.columns))):
            cell = table.rows[i].cells[j]
            cell_paragraph = cell.paragraphs[0]
            cell_paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # выравниваем текст 0 ячейки по центру
    cell = table.rows[0].cells[0]
    cell_paragraph = cell.paragraphs[0]
    cell_paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # выравниваем текст в необходимых ячейках по центру (по высоте)
    def vertical_center(row_idx, col_idx):
        table.cell(row_idx, col_idx).vertical_alignment = WD_ALIGN_VERTICAL.CENTER
    vertical_center(0,0)
    vertical_center(0,1)
    vertical_center(0,3)    

    # сделаем строку/заголовок жирным шрифтом
    def make_rows_bold(*rows):
        for row in rows:
            for cell in row.cells:
                for paragraph in cell.paragraphs:
                    for run in paragraph.runs:
                        run.font.bold = True

    make_rows_bold(table.rows[0])

# %% [markdown]
# #### Функция для формирования таблицы СИ в зависимости от типа испытания

# %%
# Функция для формирования таблицы СИ в зависимости от типа испытания
def ci_table_func(excel_file, test_type):

    
# 1 функция для удаление строк по цветам ячеек эксель

    # функция предобработки (удаление строк по цветам ячеек эксель)
    # для удобства заменим measuring_instruments на аббревиатуру "mi"
    def mi_color_func(excel_file, sheet_name):
        # выведем excel_file с листом
        df = excel_file.parse(sheet_name)

        # получим список цветов ячеек листа
        # загрузка файла
        workbook = load_workbook(excel_file)
        # выбор листа
        worksheet = workbook[sheet_name]

        # пустой список, для цветов
        all_colors = []
        # получим цвета ячеек (начиная со строки с оборудованием до конца таблицы) с запасом/поправкой на специфику таблицы
        for i in range(21,(df.shape[0]+20)):
            all_colors.append(worksheet[f'C{i}'].fill.start_color.index)

        # список в df
        df_all_colors = pd.DataFrame(all_colors, columns = ['cell_color'])
        # заменим индексы с поправкой на специфику таблицы
        df_all_colors.index += 19

        # объединим 2 таблицы (все СИ и цвета ячеек)
        df = df.join(df_all_colors)
        # уберём лишние строки (по цветам)
        df = df.query('cell_color==0 | cell_color=="00000000" | cell_color==6')

        return df

    
# 2 Вызов функция для удаление строк по цветам ячеек эксель, получение df 

    # функция(имя файла, имя листа) - предобработка найденного файла 
    df = mi_color_func(excel_file, 'СИ')

    
# 3 Предобработка полученного df

    # переименуем столбцы
    df.columns = ['№',
                  'Наименование средств измерений', 
                  'Модель', 
                  'Пределы измерений', 
                  'Класс точности, погрешность (цена деления)', 
                  'Кол-во', 
                  'Инв. №', 
                  'Заводской номер', 
                  'Дата поверки', 
                  'Дата очер. поверки', 
                  'Условия эксплуатации: t,°C', 
                  'Условия эксплуатации: атмосферное давление, кПа', 
                  'Условия эксплуатации: относитель-ная влажность воздуха, не более %', 
                  'Условия эксплуатации: напряжение электросети, В', 
                  'Условия эксплуатации: частота питающей сети, Гц', 
                  'Место установки / хранения', 'Комментарий', 'Цвет']

    # удалим все строки, где заводской номер содержит NaN
    df = df.dropna(subset=['Заводской номер'])

    # удалим лишние (для ПИ) колонки
    df = df.drop(['№', 'Кол-во', 'Инв. №', 'Дата поверки', 'Условия эксплуатации: t,°C', \
                  'Условия эксплуатации: атмосферное давление, кПа', \
                  'Условия эксплуатации: относитель-ная влажность воздуха, не более %', \
                  'Условия эксплуатации: напряжение электросети, В', \
                  'Условия эксплуатации: частота питающей сети, Гц', 'Цвет', 'Комментарий'], axis=1).reset_index(drop=True)

    # преобразуем данные о дате и времени
    df['Дата очер. поверки'] = pd.to_datetime(df['Дата очер. поверки'])

    # уберём лишние пробелы в конце каждого названия СИ
    for i in range(len(df['Наименование средств измерений'])):
        df['Наименование средств измерений'][i] = df['Наименование средств измерений'][i].rstrip()

    # приведём даты к нужному виду
    df['Дата очер. поверки'] = df['Дата очер. поверки'].dt.strftime('%m.%Y')


# 4 Функция для формирования строк таблицы СИ, исходя из названия СИ и места нахождения СИ    
    
    # функция для формирования строк таблицы СИ
    def mi_add_func(name_mi_val, df, mi_table):
        # столбец "Место установки / хранения"
        location_mi_col = 'Место установки / хранения'
        # столбец "Наименование средств измерений"
        name_mi_col = 'Наименование средств измерений'
        # создадим табличку/фильтр по наименованию СИ
        rslt_df = df[df[name_mi_col] == name_mi_val]

        # если печь находится по адресу "Ленина"
        if furnace in lenina:

            # и если в столбце "место установки" есть "Л" - "Ленина"
            if any(rslt_df[location_mi_col].str.contains('Л')):
                # выберем строчку с прибором по адресу "Л" - "Ленина"
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')].head(1)
                mi_table = pd.concat([mi_table, rslt_df])

            # если в столбце "место установки" нет "Л" - "Ленина", берём прибор с "Г" - "Горная"
            elif any(rslt_df[location_mi_col].str.contains('Г')):
                # выберем строчку с прибором по адресу "Г" - "Горная"
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')].tail(1)
                mi_table = pd.concat([mi_table, rslt_df])            

            # если в столбце "место установки" нет "Л" - "Ленина" и "Г" - "Горная", берём прибор с "О" - "Орджоникидзе"
            elif any(rslt_df[location_mi_col].str.contains('О')):
                # выберем строчку с прибором по адресу "О" - "Орджоникидзе"
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')].head(1)
                mi_table = pd.concat([mi_table, rslt_df])

        # если печь находится по адресу "Горная"
        elif furnace in gornaya:

            # и если в столбце "место установки" есть "Г" - "Горная"
            if any(rslt_df[location_mi_col].str.contains('Г')):
                # выберем строчку с прибором по адресу "Г" - "Горная"
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')].head(1)
                mi_table = pd.concat([mi_table, rslt_df])

            # если в столбце "место установки" нет "Г" - "Горная", берём прибор с "Л" - "Ленина"
            elif any(rslt_df[location_mi_col].str.contains('Л')):
                # выберем строчку с прибором по адресу "Л" - "Ленина"
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')].tail(1)
                mi_table = pd.concat([mi_table, rslt_df])            

            # если в столбце "место установки" нет "Л" - "Ленина" и "Г" - "Горная", берём прибор с "О" - "Орджоникидзе"
            elif any(rslt_df[location_mi_col].str.contains('О')):
                # выберем строчку с прибором по адресу "О" - "Орджоникидзе"
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')].head(1)
                mi_table = pd.concat([mi_table, rslt_df])            

        # если печь не задана (furnace = '')        
        else:
            pass

        # возвращает получившуюся таблицу
        return mi_table

    
# 5 Создание таблицы СИ для заполнения     

    # создаём пустую таблицу для СИ
    mi_table = df.head(0)


# 6 Заполнение таблицы в зависимости от типа испытаний    
    
# 6.1 

    # если тип испытаний 'E'
    if test_type == 'E':

        # СИ для испытаний по 'E'
        mi_list_E = ['Прибор электроизмерительный цифровой (мультиметр)',
                     'Секундомер электронный',
                     'Прибор комбинированный',
                     'Измеритель-регулятор универсальный 8-канальный',
                     'Датчик температуры  на основе преобразователя термоэлектрического',  # 6 штук
                     'Рулетка измерительная металлическая',
                     'Штангенциркуль',
                     'Дифференциальный манометр цифровой']

        # собираем табличку (т.к. у некоторого оборудования есть своя специфика, не будем собирать всё через цикл)
        
# 6.1.0        
        mi_table = mi_add_func(mi_list_E[0], df, mi_table) # Прибор электроизмерительный цифровой (мультиметр)

# 6.1.1
        mi_table = mi_add_func(mi_list_E[1], df, mi_table) # Секундомер электронный
    
# 6.1.2
        mi_table = mi_add_func(mi_list_E[2], df, mi_table) # Прибор комбинированный
    
# 6.1.3
        mi_table = mi_add_func(mi_list_E[3], df, mi_table) # Измеритель-регулятор универсальный 8-канальный
    
# 6.1.4
        # для 'Датчиков температуры' (mi_list_E[4]) напишем свой вариант отбора СИ, из-за его специфики
        # не будем выбирать head(1) или tail(1), получим полную таблицу 
        name_mi_val = mi_list_E[4] # Датчик температуры  на основе преобразователя термоэлектрического
        location_mi_col = 'Место установки / хранения'
        name_mi_col = 'Наименование средств измерений'
        rslt_df = df[df[name_mi_col] == name_mi_val]

        if furnace in lenina:
            
            if any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]
            elif any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        elif furnace in gornaya:
            
            if any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]        
            elif any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        else:
            pass

        # цикл для вывода необходимого количества строк и значений в колонке 'Заводской номер'
        
        n = 0  # количество значений в ячейке
        x = 6  # необходимо получить "x" значений в сумме
        r = 1  # количество взятых для рассмотрения строк (минимум 1 строка)

        for i in range(len(rslt_df)):
            # получаем количество значений "n" в ячейке
            n = len(rslt_df['Заводской номер'].values[i].split('\n'))

            # если "n" равно "x"
            if n == x:
                # обновлённое количество значений "n"
                n = x
                # прервём цикл
                break

            # если "n" больше "x"
            elif n > x:   
                # заменим исходное количество значений "n" в ячейке на "x" значений
                new_value = '\n'.join(rslt_df['Заводской номер'].values[i].split('\n')[0:x])
                # заменим старое значение ячейки df на новое
                rslt_df = rslt_df.replace([(rslt_df['Заводской номер'].values[i])],new_value)
                # обновлённое количество значений "n"
                n = x    
                # прервём цикл
                break

            # если "n" меньше "x"
            elif n < x:
                # оставим то количество значений "n", что есть в ячейке
                n = len(rslt_df['Заводской номер'].values[i].split('\n'))

            # обновлённое количество значений "x"
            x = x-n
            # обновлённое количество значений "r"
            r = r+1 

        # добавим строки к общей таблице СИ
        mi_table = pd.concat([mi_table, rslt_df.head(r)]) # Датчик температуры  на основе преобразователя термоэлектрического
        
        # продолжаем собирать табличку
        
# 6.1.5
        mi_table = mi_add_func(mi_list_E[5], df, mi_table) # Рулетка измерительная металлическая
    
# 6.1.6
        mi_table = mi_add_func(mi_list_E[6], df, mi_table) # Штангенциркуль
    
# 6.1.7
        mi_table = mi_add_func(mi_list_E[7], df, mi_table) # Дифференциальный манометр цифровой

# 6.2 

    # если тип испытаний 'EI'
    elif test_type == 'EI':
        
        # СИ для испытаний по 'EI'
        mi_list_EI = ['Прибор электроизмерительный цифровой (мультиметр)',
                     'Секундомер электронный',
                     'Прибор комбинированный',
                     'Измеритель-регулятор универсальный 8-канальный', # ((ТП+6) / 8) штук            
                     'Датчик температуры  на основе преобразователя термоэлектрического', # 6 штук
                     'Преобразователь термоэлектрический', # ТП - заданное количество штук
                     'Рулетка измерительная металлическая',
                     'Штангенциркуль',
                     'Измеритель комбинированный',
                     'Весы лабораторные',
                     'Гиря', # 2 разных гири
                     'Инфракрасный пирометр',
                     'Дифференциальный манометр цифровой']


        # собираем табличку (т.к. у некоторого оборудования есть своя специфика, не будем собирать всё через цикл)
        
# 6.2.0        
        mi_table = mi_add_func(mi_list_EI[0], df, mi_table) # Прибор электроизмерительный цифровой (мультиметр)
        
# 6.2.1 
        mi_table = mi_add_func(mi_list_EI[1], df, mi_table) # Секундомер электронный
        
# 6.2.2 
        mi_table = mi_add_func(mi_list_EI[2], df, mi_table) # Прибор комбинированный
        
# 6.2.3
        # для "Измеритель-регулятор универсальный 8-канальный" (mi_list_EI[3] напишем свой вариант отбора СИ, из-за его специфики
        # не будем выбирать head(1) или tail(1), получим полную таблицу 
        name_mi_val = mi_list_EI[3] # Измеритель-регулятор универсальный 8-канальный
        location_mi_col = 'Место установки / хранения'
        name_mi_col = 'Наименование средств измерений'
        rslt_df = df[df[name_mi_col] == name_mi_val]

        if furnace in lenina:

            if any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]
            elif any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        elif furnace in gornaya:

            if any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]        
            elif any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        else:
            pass

        # нам надо получить "Измеритель-регулятор универсальный 8-канальный" в количестве:
        # math.ceil((thermoelectric_converter_val+6)/8)
        # выводим необходимые строки
        rslt_df = rslt_df.head(math.ceil((thermoelectric_converter_val+6)/8))

        # создаём пустой список для заводских номеров
        s = []
        # создаём пустой список для дат
        r = []

        # заполним списки значениями
        for i in range(len(rslt_df)):
            s.append(rslt_df['Заводской номер'].values[i])
            r.append(rslt_df['Дата очер. поверки'].values[i])

        # "сошьём" все значения в одну строку
        s = '\n'.join(s)
        r = '\n'.join(r)

        # заменим старое значение ячейки на новое
        rslt_df = rslt_df.replace([[(rslt_df['Заводской номер'].values[0])], [(rslt_df['Дата очер. поверки'].values[0])]],[s, r])

        # выведем получившуюся строку
        rslt_df = rslt_df.head(1)

        # добавим строки к общей таблице СИ
        mi_table = pd.concat([mi_table, rslt_df]) # Измеритель-регулятор универсальный 8-канальный
        
# 6.2.4 
        # для 'Датчиков температуры' (mi_list_EI[4]) напишем свой вариант отбора СИ, из-за его специфики
        # не будем выбирать head(1) или tail(1), получим полную таблицу 
        name_mi_val = mi_list_EI[4] # Датчик температуры  на основе преобразователя термоэлектрического
        location_mi_col = 'Место установки / хранения'
        name_mi_col = 'Наименование средств измерений'
        rslt_df = df[df[name_mi_col] == name_mi_val]

        if furnace in lenina:

            if any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]
            elif any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        elif furnace in gornaya:

            if any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]        
            elif any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        else:
            pass

        # цикл для вывода необходимого количества строк и значений в колонке 'Заводской номер'

        n = 0  # количество значений в ячейке
        x = 6  # необходимо получить "x" значений в сумме
        r = 1  # количество взятых для рассмотрения строк (минимум 1 строка)

        for i in range(len(rslt_df)):
            # получаем количество значений "n" в ячейке
            n = len(rslt_df['Заводской номер'].values[i].split('\n'))

            # если "n" равно "x"
            if n == x:
                # обновлённое количество значений "n"
                n = x
                # прервём цикл
                break

            # если "n" больше "x"
            elif n > x:   
                # заменим исходное количество значений "n" в ячейке на "x" значений
                new_value = '\n'.join(rslt_df['Заводской номер'].values[i].split('\n')[0:x])
                # заменим старое значение ячейки df на новое
                rslt_df = rslt_df.replace([(rslt_df['Заводской номер'].values[i])],new_value)
                # обновлённое количество значений "n"
                n = x
                # прервём цикл
                break

            # если "n" меньше "x"
            elif n < x:
                # оставим то количество значений "n", что есть в ячейке
                n = len(rslt_df['Заводской номер'].values[i].split('\n'))

            # обновлённое количество значений "x"
            x = x-n
            # обновлённое количество значений "r"
            r = r+1

        # добавим строки к общей таблице СИ
        mi_table = pd.concat([mi_table, rslt_df.head(r)]) # Датчик температуры  на основе преобразователя термоэлектрического
        
# 6.2.5
        # для 'Преобразователь термоэлектрический' (mi_list_EI[5]) напишем свой вариант отбора СИ, из-за его специфики
        # не будем выбирать head(1) или tail(1), получим полную таблицу 
        name_mi_val = mi_list_EI[5] # Преобразователь термоэлектрический
        location_mi_col = 'Место установки / хранения'
        name_mi_col = 'Наименование средств измерений'
        rslt_df = df[df[name_mi_col] == name_mi_val]

        if furnace in lenina:

            if any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]
            elif any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        elif furnace in gornaya:

            if any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]        
            elif any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        else:
            pass

        # используем библиотеку detect_delimiter для работы над разделителями
        # случаи с разделителем ' , ' не будем рассматривать
        # если разделитель ' - ', то Paython определяет его как пробел ' '
        # если в ячейке одно значение, то Paython выводит 'None'

        # переформатируем ячейки, в которых перечень заводских номеров выглядит как от 1 до 20 - "1 - 20"
        for i in range(len(rslt_df['Заводской номер'])):

            # найдём тип разделителя в ячейке
            if detect(rslt_df['Заводской номер'].values[i]) == ' ':
                # разделим строку типа "51212212001 - 51212212020" по разделителю на 2 значения (разделитель - пробел, тире, пробел)
                s = rslt_df['Заводской номер'].values[i].split(' - ')
                # добавим 1 для вхождения последнего значения в список
                new_value = list(range((int(s[0])), (int(s[1])+1)))
                new_value = str(new_value).strip('[]')
                # "сошьём" все значения в одну строку
                new_value = new_value.replace(', ', '\n') 
                # заменим старое значение ячейки на новое
                rslt_df = rslt_df.replace([(rslt_df['Заводской номер'].values[i])],new_value)

            # найдём тип разделителя в ячейке
            elif detect(rslt_df['Заводской номер'].values[i]) == '-':
                # разделим строку типа "51212212001-51212212020" по разделителю на 2 значения (разделитель - тире)
                s = rslt_df['Заводской номер'].values[i].split('-')
                # добавим 1 для вхождения последнего значения в список
                new_value = list(range((int(s[0])), (int(s[1])+1)))
                new_value = str(new_value).strip('[]')
                # "сошьём" все значения в одну строку
                new_value = new_value.replace(', ', '\n') 
                # заменим старое значение ячейки на новое
                rslt_df = rslt_df.replace([(rslt_df['Заводской номер'].values[i])],new_value)  

        # сравним, равно ли значение в следующей ячейке предыдущему + 1
        for i in range(len(rslt_df['Заводской номер'])-1):
            # последнее значение из текущего списка
            a = rslt_df['Заводской номер'].values[i].split('\n')[len(rslt_df['Заводской номер'].values[i].split('\n'))-1]
            # первое значение из следующего списка
            b = rslt_df['Заводской номер'].values[i+1].split('\n')[0]

            # сравним значения
            if int(a)+1 == int(b):
                # если, после сравнения, на выходе True, объединим ячейки (добавляем значения из 0 ячейки в 1)
                rslt_df['Заводской номер'].values[i+1] = (rslt_df['Заводской номер'].values[i] + 
                                                          '\n' + 
                                                          rslt_df['Заводской номер'].values[i+1])
                # заменим старое значение ячейки df на новое (NaN)
                rslt_df = rslt_df.replace([(rslt_df['Заводской номер'].values[i])], np.NaN)

            # если, после сравнения, на выходе False - ничего не делаем
            else:
                pass

        # удалим все строки, где заводской номер содержит NaN
        rslt_df = rslt_df.dropna(subset=['Заводской номер'])    

        # цикл для вывода необходимого количества строк и значений в колонке 'Заводской номер'

        n = 0  # количество значений в ячейке
        x = thermoelectric_converter_val # необходимо получить "x" значений в сумме
        r = 1  # количество взятых для рассмотрения строк (минимум 1 строка)

        for i in range(len(rslt_df)):
            # получаем количество значений "n" в ячейке
            n = len(rslt_df['Заводской номер'].values[i].split('\n'))

            # если "n" равно "x"
            if n == x:
                # обновлённое количество значений "n"
                n = x
                # прервём цикл
                break

            # если "n" больше "x"
            elif n > x:   
                # заменим исходное количество значений "n" в ячейке на "x" значений
                new_value = '\n'.join(rslt_df['Заводской номер'].values[i].split('\n')[0:x])
                # заменим старое значение ячейки df на новое
                rslt_df = rslt_df.replace([(rslt_df['Заводской номер'].values[i])],new_value)
                # обновлённое количество значений "n"
                n = x
                # прервём цикл
                break

            # если "n" меньше "x"
            elif n < x:
                # оставим то количество значений "n", что есть в ячейке
                n = len(rslt_df['Заводской номер'].values[i].split('\n'))

            # обновлённое количество значений "x"
            x = x-n
            # обновлённое количество значений "r"
            r = r+1   

        for i in range(len(rslt_df.head(r))):
            # если в строке больше 1 значения
            if len(rslt_df['Заводской номер'].values[i].split('\n')) > 1:
                # заменим старое значение ячейки df на новое в виде "1-20"
                rslt_df = (rslt_df.replace([(rslt_df['Заводской номер'].values[i])],
                                           (((rslt_df['Заводской номер'].values[i]).split('\n')[0]) + 
                                            ' - ' + 
                                            ((rslt_df['Заводской номер'].values[i]).split('\n')[-1]))))
            else:
                pass     

        # добавим строки к общей таблице СИ
        mi_table = pd.concat([mi_table, rslt_df.head(r)]) # Преобразователь термоэлектрический

        # продолжаем собирать табличку
        
# 6.2.6        
        mi_table = mi_add_func(mi_list_EI[6], df, mi_table) # Рулетка измерительная металлическая
        
# 6.2.7 
        mi_table = mi_add_func(mi_list_EI[7], df, mi_table) # Штангенциркуль
        
# 6.2.8 
        mi_table = mi_add_func(mi_list_EI[8], df, mi_table) # Измеритель комбинированный
        
# 6.2.9 
        mi_table = mi_add_func(mi_list_EI[9], df, mi_table) # Весы лабораторные
        
# 6.2.10 
        # необходимо 2 разные гири
        name_mi_val = mi_list_EI[10] # Гиря
        location_mi_col = 'Место установки / хранения'
        name_mi_col = 'Наименование средств измерений'
        rslt_df = df[df[name_mi_col] == name_mi_val]

        if furnace in lenina:

            if any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]
            elif any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        elif furnace in gornaya:

            if any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]        
            elif any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]           
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        else:
            pass    

        # избавимся от неподходящих гирь
        rslt_df = rslt_df.loc[rslt_df['Пределы измерений'] != '2000 г']
        rslt_df = rslt_df.loc[rslt_df['Пределы измерений'] != '1000 г']    

        # добавим строки к общей таблице СИ
        mi_table = pd.concat([mi_table, rslt_df]) # Гиря (2 штуки)    

        # продолжаем собирать табличку
        
# 6.2.11 
        mi_table = mi_add_func(mi_list_EI[11], df, mi_table) # Инфракрасный пирометр
        
# 6.2.12 
        mi_table = mi_add_func(mi_list_EI[12], df, mi_table) # Дифференциальный манометр цифровой   

# 6.3 

    # если тип испытаний 'EIW'
    elif test_type == 'EIW':

        # СИ для испытаний по 'EIW'
        mi_list_EIW = ['Прибор электроизмерительный цифровой (мультиметр)',
                     'Секундомер электронный',
                     'Прибор комбинированный',
                     'Измеритель-регулятор универсальный 8-канальный', # ((ТП+6) / 8) штук            
                     'Датчик температуры  на основе преобразователя термоэлектрического', # 6 штук
                     'Преобразователь термоэлектрический', # ТП - заданное количество штук
                     'Рулетка измерительная металлическая',
                     'Штангенциркуль',
                     'Измеритель комбинированный',
                     'Весы лабораторные',
                     'Гиря', # 2 разных гири
                     'Инфракрасный пирометр',
                     'Датчик плотности радиационного теплового потока',
                     'Модуль ввода аналоговый измерительный', 
                     'Дифференциальный манометр цифровой']

        # собираем табличку (т.к. у некоторого оборудования есть своя специфика, не будем собирать всё через цикл)
        
# 6.3.0 
        mi_table = mi_add_func(mi_list_EIW[0], df, mi_table) # Прибор электроизмерительный цифровой (мультиметр)
        
# 6.3.1 
        mi_table = mi_add_func(mi_list_EIW[1], df, mi_table) # Секундомер электронный
        
# 6.3.2 
        mi_table = mi_add_func(mi_list_EIW[2], df, mi_table) # Прибор комбинированный
        
# 6.3.3
        # для "Измеритель-регулятор универсальный 8-канальный" (mi_list_EIW[3] напишем свой вариант отбора СИ, из-за его специфики
        # не будем выбирать head(1) или tail(1), получим полную таблицу 
        name_mi_val = mi_list_EIW[3] # Измеритель-регулятор универсальный 8-канальный
        location_mi_col = 'Место установки / хранения'
        name_mi_col = 'Наименование средств измерений'
        rslt_df = df[df[name_mi_col] == name_mi_val]

        if furnace in lenina:

            if any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]
            elif any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        elif furnace in gornaya:

            if any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]        
            elif any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        else:
            pass

        # нам надо получить "Измеритель-регулятор универсальный 8-канальный" в количестве:
        # math.ceil((thermoelectric_converter_val+6)/8)
        # выводим необходимые строки
        rslt_df = rslt_df.head(math.ceil((thermoelectric_converter_val+6)/8))

        # создаём пустой список для заводских номеров
        s = []
        # создаём пустой список для дат
        r = []

        # заполним списки значениями
        for i in range(len(rslt_df)):
            s.append(rslt_df['Заводской номер'].values[i])
            r.append(rslt_df['Дата очер. поверки'].values[i])

        # "сошьём" все значения в одну строку
        s = '\n'.join(s)
        r = '\n'.join(r)

        # заменим старое значение ячейки на новое
        rslt_df = rslt_df.replace([[(rslt_df['Заводской номер'].values[0])], [(rslt_df['Дата очер. поверки'].values[0])]],[s, r])

        # выведем получившуюся строку
        rslt_df = rslt_df.head(1)

        # добавим строки к общей таблице СИ
        mi_table = pd.concat([mi_table, rslt_df]) # Измеритель-регулятор универсальный 8-канальный
        
# 6.3.4
        # для 'Датчиков температуры' (mi_list_EIW[4]) напишем свой вариант отбора СИ, из-за его специфики
        # не будем выбирать head(1) или tail(1), получим полную таблицу 
        name_mi_val = mi_list_EIW[4] # Датчик температуры  на основе преобразователя термоэлектрического
        location_mi_col = 'Место установки / хранения'
        name_mi_col = 'Наименование средств измерений'
        rslt_df = df[df[name_mi_col] == name_mi_val]

        if furnace in lenina:

            if any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]
            elif any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        elif furnace in gornaya:

            if any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]        
            elif any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        else:
            pass

        # цикл для вывода необходимого количества строк и значений в колонке 'Заводской номер'

        n = 0  # количество значений в ячейке
        x = 6  # необходимо получить "x" значений в сумме
        r = 1  # количество взятых для рассмотрения строк (минимум 1 строка)

        for i in range(len(rslt_df)):
            # получаем количество значений "n" в ячейке
            n = len(rslt_df['Заводской номер'].values[i].split('\n'))

            # если "n" равно "x"
            if n == x:
                # обновлённое количество значений "n"
                n = x
                # прервём цикл
                break

            # если "n" больше "x"
            elif n > x:   
                # заменим исходное количество значений "n" в ячейке на "x" значений
                new_value = '\n'.join(rslt_df['Заводской номер'].values[i].split('\n')[0:x])
                # заменим старое значение ячейки df на новое
                rslt_df = rslt_df.replace([(rslt_df['Заводской номер'].values[i])],new_value)
                # обновлённое количество значений "n"
                n = x
                # прервём цикл
                break

            # если "n" меньше "x"
            elif n < x:
                # оставим то количество значений "n", что есть в ячейке
                n = len(rslt_df['Заводской номер'].values[i].split('\n'))

            # обновлённое количество значений "x"
            x = x-n
            # обновлённое количество значений "r"
            r = r+1

        # добавим строки к общей таблице СИ
        mi_table = pd.concat([mi_table, rslt_df.head(r)]) # Датчик температуры  на основе преобразователя термоэлектрического
        
# 6.3.5
        # для 'Преобразователь термоэлектрический' (mi_list_EIW[5]) напишем свой вариант отбора СИ, из-за его специфики
        # не будем выбирать head(1) или tail(1), получим полную таблицу 
        name_mi_val = mi_list_EIW[5] # Преобразователь термоэлектрический
        location_mi_col = 'Место установки / хранения'
        name_mi_col = 'Наименование средств измерений'
        rslt_df = df[df[name_mi_col] == name_mi_val]

        if furnace in lenina:

            if any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]
            elif any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        elif furnace in gornaya:

            if any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]        
            elif any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        else:
            pass

        # используем библиотеку detect_delimiter для работы над разделителями
        # случаи с разделителем ' , ' не будем рассматривать
        # если разделитель ' - ', то Paython определяет его как пробел ' '
        # если в ячейке одно значение, то Paython выводит 'None'

        # переформатируем ячейки, в которых перечень заводских номеров выглядит как от 1 до 20 - "1 - 20"
        for i in range(len(rslt_df['Заводской номер'])):

            # найдём тип разделителя в ячейке
            if detect(rslt_df['Заводской номер'].values[i]) == ' ':
                # разделим строку типа "51212212001 - 51212212020" по разделителю на 2 значения (разделитель - пробел, тире, пробел)
                s = rslt_df['Заводской номер'].values[i].split(' - ')
                # добавим 1 для вхождения последнего значения в список
                new_value = list(range((int(s[0])), (int(s[1])+1)))
                new_value = str(new_value).strip('[]')
                # "сошьём" все значения в одну строку
                new_value = new_value.replace(', ', '\n') 
                # заменим старое значение ячейки на новое
                rslt_df = rslt_df.replace([(rslt_df['Заводской номер'].values[i])],new_value)

            # найдём тип разделителя в ячейке
            elif detect(rslt_df['Заводской номер'].values[i]) == '-':
                # разделим строку типа "51212212001-51212212020" по разделителю на 2 значения (разделитель - тире)
                s = rslt_df['Заводской номер'].values[i].split('-')
                # добавим 1 для вхождения последнего значения в список
                new_value = list(range((int(s[0])), (int(s[1])+1)))
                new_value = str(new_value).strip('[]')
                # "сошьём" все значения в одну строку
                new_value = new_value.replace(', ', '\n') 
                # заменим старое значение ячейки на новое
                rslt_df = rslt_df.replace([(rslt_df['Заводской номер'].values[i])],new_value)

        # сравним, равно ли значение в следующей ячейке предыдущему + 1
        for i in range(len(rslt_df['Заводской номер'])-1):
            # последнее значение из текущего списка
            a = rslt_df['Заводской номер'].values[i].split('\n')[len(rslt_df['Заводской номер'].values[i].split('\n'))-1]
            # первое значение из следующего списка
            b = rslt_df['Заводской номер'].values[i+1].split('\n')[0]

            # сравним значения
            if int(a)+1 == int(b):
                # если, после сравнения, на выходе True, объединим ячейки (добавляем значения из 0 ячейки в 1)
                rslt_df['Заводской номер'].values[i+1] = (rslt_df['Заводской номер'].values[i] + 
                                                          '\n' + 
                                                          rslt_df['Заводской номер'].values[i+1])
                # заменим старое значение ячейки df на новое (NaN)
                rslt_df = rslt_df.replace([(rslt_df['Заводской номер'].values[i])], np.NaN)

            # если, после сравнения, на выходе False - ничего не делаем
            else:
                pass

        # удалим все строки, где заводской номер содержит NaN
        rslt_df = rslt_df.dropna(subset=['Заводской номер'])

        # цикл для вывода необходимого количества строк и значений в колонке 'Заводской номер'

        n = 0  # количество значений в ячейке
        x = thermoelectric_converter_val # необходимо получить "x" значений в сумме
        r = 1  # количество взятых для рассмотрения строк (минимум 1 строка)

        for i in range(len(rslt_df)):
            # получаем количество значений "n" в ячейке
            n = len(rslt_df['Заводской номер'].values[i].split('\n'))

            # если "n" равно "x"
            if n == x:
                # обновлённое количество значений "n"
                n = x
                # прервём цикл
                break

            # если "n" больше "x"
            elif n > x:   
                # заменим исходное количество значений "n" в ячейке на "x" значений
                new_value = '\n'.join(rslt_df['Заводской номер'].values[i].split('\n')[0:x])
                # заменим старое значение ячейки df на новое
                rslt_df = rslt_df.replace([(rslt_df['Заводской номер'].values[i])],new_value)
                # обновлённое количество значений "n"
                n = x
                # прервём цикл
                break

            # если "n" меньше "x"
            elif n < x:
                # оставим то количество значений "n", что есть в ячейке
                n = len(rslt_df['Заводской номер'].values[i].split('\n'))

            # обновлённое количество значений "x"
            x = x-n
            # обновлённое количество значений "r"
            r = r+1

        for i in range(len(rslt_df.head(r))):
            # если в строке больше 1 значения
            if len(rslt_df['Заводской номер'].values[i].split('\n')) > 1:
                # заменим старое значение ячейки df на новое в виде "1-20"
                rslt_df = (rslt_df.replace([(rslt_df['Заводской номер'].values[i])],
                                           (((rslt_df['Заводской номер'].values[i]).split('\n')[0]) + 
                                            ' - ' + 
                                            ((rslt_df['Заводской номер'].values[i]).split('\n')[-1]))))
            else:
                pass

        # добавим строки к общей таблице СИ
        mi_table = pd.concat([mi_table, rslt_df.head(r)]) # Преобразователь термоэлектрический
        
        # продолжаем собирать табличку
        
# 6.3.6
        mi_table = mi_add_func(mi_list_EIW[6], df, mi_table) # Рулетка измерительная металлическая
        
# 6.3.7
        mi_table = mi_add_func(mi_list_EIW[7], df, mi_table) # Штангенциркуль
        
# 6.3.8
        mi_table = mi_add_func(mi_list_EIW[8], df, mi_table) # Измеритель комбинированный
        
# 6.3.9
        mi_table = mi_add_func(mi_list_EIW[9], df, mi_table) # Весы лабораторные
        
# 6.3.10
        # необходимо 2 разные гири
        name_mi_val = mi_list_EIW[10] # Гиря
        location_mi_col = 'Место установки / хранения'
        name_mi_col = 'Наименование средств измерений'
        rslt_df = df[df[name_mi_col] == name_mi_val]

        if furnace in lenina:

            if any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]
            elif any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        elif furnace in gornaya:

            if any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]        
            elif any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        else:
            pass

        # избавимся от неподходящих гирь
        rslt_df = rslt_df.loc[rslt_df['Пределы измерений'] != '2000 г']
        rslt_df = rslt_df.loc[rslt_df['Пределы измерений'] != '1000 г']

        # добавим строки к общей таблице СИ
        mi_table = pd.concat([mi_table, rslt_df]) # Гиря

        # продолжаем собирать табличку
        
# 6.3.11
        
        mi_table = mi_add_func(mi_list_EIW[11], df, mi_table) # Инфракрасный пирометр
        
# 6.3.12    
        # для 'Датчик плотности радиационного теплового потока' (mi_list_EIW[12]) напишем свой вариант отбора СИ
        
        name_mi_val = mi_list_EIW[12] # Датчик плотности радиационного теплового потока
        location_mi_col = 'Место установки / хранения'
        name_mi_col = 'Наименование средств измерений'
        rslt_df = df[df[name_mi_col] == name_mi_val]
        
        if furnace1 == furnace2 and test_dates1 == test_dates2: 

            if furnace in lenina:

                if any(rslt_df[location_mi_col].str.contains('Л')):
                    rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')].head(2)
                    mi_table = pd.concat([mi_table, rslt_df])
                elif any(rslt_df[location_mi_col].str.contains('Г')):
                    rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')].tail(2)            
                    mi_table = pd.concat([mi_table, rslt_df])
                elif any(rslt_df[location_mi_col].str.contains('О')):
                    rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')].head(2)
                    mi_table = pd.concat([mi_table, rslt_df])

            elif furnace in gornaya:

                if any(rslt_df[location_mi_col].str.contains('Г')):
                    rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')].head(2)        
                    mi_table = pd.concat([mi_table, rslt_df])
                elif any(rslt_df[location_mi_col].str.contains('Л')):
                    rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')].tail(2)            
                    mi_table = pd.concat([mi_table, rslt_df])
                elif any(rslt_df[location_mi_col].str.contains('О')):
                    rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')].head(2)
                    mi_table = pd.concat([mi_table, rslt_df])
    
        else:
            mi_table = mi_add_func(mi_list_EIW[12], df, mi_table) # Датчик плотности радиационного теплового потока
            
        # продолжаем собирать табличку  
        
# 6.3.13
        mi_table = mi_add_func(mi_list_EIW[13], df, mi_table) # Модуль ввода аналоговый измерительный
        
# 6.3.14
        mi_table = mi_add_func(mi_list_EIW[14], df, mi_table) # Дифференциальный манометр цифровой

# 6.4 

    # если тип испытаний 'S'
    elif test_type == 'S':

        # СИ для испытаний по 'S'
        mi_list_S = ['Прибор электроизмерительный цифровой (мультиметр)',
                     'Секундомер электронный',
                     'Прибор комбинированный',
                     'Измеритель-регулятор универсальный 8-канальный',             
                     'Датчик температуры  на основе преобразователя термоэлектрического', # 6 штук
                     'Преобразователь термоэлектрический', 
                     'Рулетка измерительная металлическая',
                     'Штангенциркуль',
                     'Измеритель комбинированный',
                     'Дифференциальный манометр цифровой', # 2 штуки
                     'Трубка напорная']


        # собираем табличку (т.к. у некоторого оборудования есть своя специфика, не будем собирать всё через цикл)
        
# 6.4.0
        mi_table = mi_add_func(mi_list_S[0], df, mi_table) # Прибор электроизмерительный цифровой (мультиметр)
        
# 6.4.1
        mi_table = mi_add_func(mi_list_S[1], df, mi_table) # Секундомер электронный
        
# 6.4.2
        mi_table = mi_add_func(mi_list_S[2], df, mi_table) # Прибор комбинированный
        
# 6.4.3
        mi_table = mi_add_func(mi_list_S[3], df, mi_table) # Измеритель-регулятор универсальный 8-канальный
        
# 6.4.4
        # для 'Датчиков температуры' (mi_list_S[4]) напишем свой вариант отбора СИ, из-за его специфики
        # не будем выбирать head(1) или tail(1), получим полную таблицу 
        name_mi_val = mi_list_S[4] # Датчик температуры  на основе преобразователя термоэлектрического
        location_mi_col = 'Место установки / хранения'
        name_mi_col = 'Наименование средств измерений'
        rslt_df = df[df[name_mi_col] == name_mi_val]

        if furnace in lenina:

            if any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]
            elif any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        elif furnace in gornaya:

            if any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]        
            elif any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        else:
            pass

        # цикл для вывода необходимого количества строк и значений в колонке 'Заводской номер'

        n = 0  # количество значений в ячейке
        x = 6  # необходимо получить "x" значений в сумме
        r = 1  # количество взятых для рассмотрения строк (минимум 1 строка)

        for i in range(len(rslt_df)):
            # получаем количество значений "n" в ячейке
            n = len(rslt_df['Заводской номер'].values[i].split('\n'))

            # если "n" равно "x"
            if n == x:
                # обновлённое количество значений "n"
                n = x
                # прервём цикл
                break

            # если "n" больше "x"
            elif n > x:   
                # заменим исходное количество значений "n" в ячейке на "x" значений
                new_value = '\n'.join(rslt_df['Заводской номер'].values[i].split('\n')[0:x])
                # заменим старое значение ячейки df на новое
                rslt_df = rslt_df.replace([(rslt_df['Заводской номер'].values[i])],new_value)
                # обновлённое количество значений "n"
                n = x
                # прервём цикл
                break

            # если "n" меньше "x"
            elif n < x:
                # оставим то количество значений "n", что есть в ячейке
                n = len(rslt_df['Заводской номер'].values[i].split('\n'))

            # обновлённое количество значений "x"
            x = x-n
            # обновлённое количество значений "r"
            r = r+1

        # добавим строки к общей таблице СИ
        mi_table = pd.concat([mi_table, rslt_df.head(r)]) # Датчик температуры  на основе преобразователя термоэлектрического

        # продолжаем собирать табличку
        
# 6.4.5
        # для 'Преобразователь термоэлектрический' (mi_list_S[5]) напишем свой вариант отбора СИ, из-за его специфики
        # не будем выбирать head(1) или tail(1), получим полную таблицу 
        name_mi_val = mi_list_S[5] # Преобразователь термоэлектрический
        location_mi_col = 'Место установки / хранения'
        name_mi_col = 'Наименование средств измерений'
        rslt_df = df[df[name_mi_col] == name_mi_val]

        if furnace in lenina:

            if any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]
            elif any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        elif furnace in gornaya:

            if any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')]        
            elif any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')]            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')]

        else:
            pass

        # используем библиотеку detect_delimiter для работы над разделителями
        # случаи с разделителем ' , ' не будем рассматривать
        # если разделитель ' - ', то Paython определяет его как пробел ' '
        # если в ячейке одно значение, то Paython выводит 'None'

        # переформатируем ячейки, в которых перечень заводских номеров выглядит как от 1 до 20 - "1 - 20"
        for i in range(len(rslt_df['Заводской номер'])):

            # найдём тип разделителя в ячейке
            if detect(rslt_df['Заводской номер'].values[i]) == ' ':
                # разделим строку типа "51212212001 - 51212212020" по разделителю на 2 значения (разделитель - пробел, тире, пробел)
                s = rslt_df['Заводской номер'].values[i].split(' - ')
                # добавим 1 для вхождения последнего значения в список
                new_value = list(range((int(s[0])), (int(s[1])+1)))
                new_value = str(new_value).strip('[]')
                # "сошьём" все значения в одну строку
                new_value = new_value.replace(', ', '\n') 
                # заменим старое значение ячейки на новое
                rslt_df = rslt_df.replace([(rslt_df['Заводской номер'].values[i])],new_value)

            # найдём тип разделителя в ячейке
            elif detect(rslt_df['Заводской номер'].values[i]) == '-':
                # разделим строку типа "51212212001-51212212020" по разделителю на 2 значения (разделитель - тире)
                s = rslt_df['Заводской номер'].values[i].split('-')
                # добавим 1 для вхождения последнего значения в список
                new_value = list(range((int(s[0])), (int(s[1])+1)))
                new_value = str(new_value).strip('[]')
                # "сошьём" все значения в одну строку
                new_value = new_value.replace(', ', '\n') 
                # заменим старое значение ячейки на новое
                rslt_df = rslt_df.replace([(rslt_df['Заводской номер'].values[i])],new_value)  

        # сравним, равно ли значение в следующей ячейке предыдущему + 1
        for i in range(len(rslt_df['Заводской номер'])-1):
            # последнее значение из текущего списка
            a = rslt_df['Заводской номер'].values[i].split('\n')[len(rslt_df['Заводской номер'].values[i].split('\n'))-1]
            # первое значение из следующего списка
            b = rslt_df['Заводской номер'].values[i+1].split('\n')[0]

            # сравним значения
            if int(a)+1 == int(b):
                # если, после сравнения, на выходе True, объединим ячейки (добавляем значения из 0 ячейки в 1)
                rslt_df['Заводской номер'].values[i+1] = (rslt_df['Заводской номер'].values[i] + 
                                                          '\n' + 
                                                          rslt_df['Заводской номер'].values[i+1])
                # заменим старое значение ячейки df на новое (NaN)
                rslt_df = rslt_df.replace([(rslt_df['Заводской номер'].values[i])], np.NaN)

            # если, после сравнения, на выходе False - ничего не делаем
            else:
                pass

        # удалим все строки, где заводской номер содержит NaN
        rslt_df = rslt_df.dropna(subset=['Заводской номер'])

        # цикл для вывода необходимого количества строк и значений в колонке 'Заводской номер'

        n = 0  # количество значений в ячейке
        x = thermoelectric_converter_val # необходимо получить "x" значений в сумме
        r = 1  # количество взятых для рассмотрения строк (минимум 1 строка)

        for i in range(len(rslt_df)):
            # получаем количество значений "n" в ячейке
            n = len(rslt_df['Заводской номер'].values[i].split('\n'))

            # если "n" равно "x"
            if n == x:
                # обновлённое количество значений "n"
                n = x
                # прервём цикл
                break

            # если "n" больше "x"
            elif n > x:   
                # заменим исходное количество значений "n" в ячейке на "x" значений
                new_value = '\n'.join(rslt_df['Заводской номер'].values[i].split('\n')[0:x])
                # заменим старое значение ячейки df на новое
                rslt_df = rslt_df.replace([(rslt_df['Заводской номер'].values[i])],new_value)
                # обновлённое количество значений "n"
                n = x
                # прервём цикл
                break

            # если "n" меньше "x"
            elif n < x:
                # оставим то количество значений "n", что есть в ячейке
                n = len(rslt_df['Заводской номер'].values[i].split('\n'))

            # обновлённое количество значений "x"
            x = x-n
            # обновлённое количество значений "r"
            r = r+1

        for i in range(len(rslt_df.head(r))):
            # если в строке больше 1 значения
            if len(rslt_df['Заводской номер'].values[i].split('\n')) > 1:
                # заменим старое значение ячейки df на новое в виде "1-20"
                rslt_df = (rslt_df.replace([(rslt_df['Заводской номер'].values[i])],
                                           (((rslt_df['Заводской номер'].values[i]).split('\n')[0]) + 
                                            ' - ' + 
                                            ((rslt_df['Заводской номер'].values[i]).split('\n')[-1]))))
            else:
                pass

        # добавим строки к общей таблице СИ
        mi_table = pd.concat([mi_table, rslt_df.head(r)]) # Преобразователь термоэлектрический
        
# 6.4.6
        mi_table = mi_add_func(mi_list_S[6], df, mi_table) # Рулетка измерительная металлическая
        
# 6.4.7
        mi_table = mi_add_func(mi_list_S[7], df, mi_table) # Штангенциркуль
        
# 6.4.8
        mi_table = mi_add_func(mi_list_S[8], df, mi_table) # Измеритель комбинированный
        
# 6.4.9
        # для 'Дифференциальный манометр цифровой' (mi_list_S[9]) напишем свой вариант отбора СИ, из-за его специфики
        name_mi_val = mi_list_S[9] # Дифференциальный манометр цифровой
        location_mi_col = 'Место установки / хранения'
        name_mi_col = 'Наименование средств измерений'
        rslt_df = df[df[name_mi_col] == name_mi_val]

        # отбираем первый манометр
        if furnace in lenina:

            if any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df_1 = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')].head(1)
            elif any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df_1 = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')].tail(1)            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df_1 = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')].head(1)

        elif furnace in gornaya:

            if any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df_1 = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Г')].head(1)       
            elif any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df_1 = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'Л')].tail(1)            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df_1 = df.loc[(df[name_mi_col] == name_mi_val) & (df[location_mi_col] == 'О')].head(1)

        else:
            pass

        # убирает выбранный манометр их общего фильтр-списка rslt_df
        rslt_df = rslt_df.loc[rslt_df['Заводской номер'] != (rslt_df_1['Заводской номер'].values[0])]

        # отбираем второй манометр
        if furnace in lenina:

            if any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df_2 = rslt_df.loc[(rslt_df[name_mi_col] == name_mi_val) & (rslt_df[location_mi_col] == 'Л')].head(1)
            elif any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df_2 = rslt_df.loc[(rslt_df[name_mi_col] == name_mi_val) & (rslt_df[location_mi_col] == 'Г')].tail(1)            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df_2 = rslt_df.loc[(rslt_df[name_mi_col] == name_mi_val) & (rslt_df[location_mi_col] == 'О')].head(1)

        elif furnace in gornaya:

            if any(rslt_df[location_mi_col].str.contains('Г')):
                rslt_df_2 = rslt_df.loc[(rslt_df[name_mi_col] == name_mi_val) & (rslt_df[location_mi_col] == 'Г')].head(1)       
            elif any(rslt_df[location_mi_col].str.contains('Л')):
                rslt_df_2 = rslt_df.loc[(rslt_df[name_mi_col] == name_mi_val) & (rslt_df[location_mi_col] == 'Л')].tail(1)            
            elif any(rslt_df[location_mi_col].str.contains('О')):
                rslt_df_2 = rslt_df.loc[(rslt_df[name_mi_col] == name_mi_val) & (rslt_df[location_mi_col] == 'О')].head(1)

        else:
            pass

        # объединим манометры в один спсиок
        rslt_df = pd.concat([rslt_df_1, rslt_df_2])

        # создаём пустой список для заводских номеров
        s = []
        # создаём пустой список для дат
        r = []

        # заполним списки значениями
        for i in range(len(rslt_df)):
            s.append(rslt_df['Заводской номер'].values[i])
            r.append(rslt_df['Дата очер. поверки'].values[i])

        # "сошьём" все значения в одну строку
        s = '\n'.join(s)
        r = '\n'.join(r)

        # заменим старое значение ячейки на новое
        rslt_df = rslt_df.replace([[(rslt_df['Заводской номер'].values[0])], [(rslt_df['Дата очер. поверки'].values[0])]],[s, r])

        # оставим только необходимую строчку
        rslt_df = rslt_df.head(1)

        # добавим строки к общей таблице СИ
        mi_table = pd.concat([mi_table, rslt_df]) # Дифференциальный манометр цифровой
        
        # продолжаем собирать табличку
        
# 6.4.10        
        mi_table = mi_add_func(mi_list_S[10], df, mi_table) # Трубка напорная


# 7 Финальная обработка собранной таблицы

    # удалим лишние (для ПИ) колонки
    mi_table = mi_table.drop('Место установки / хранения', axis=1).reset_index(drop=True)

    # объединим необходимые столбцы
    mi_table['Наименование средств измерений'] = mi_table['Наименование средств измерений'] + ' ' + mi_table['Модель']

    # удалим лишние столбцы
    mi_table = mi_table.drop('Модель', axis=1).reset_index(drop=True)

    # расставим колонки в необходимом порядке
    mi_table = mi_table[['Наименование средств измерений', \
                         'Заводской номер', \
                         'Пределы измерений', \
                         'Класс точности, погрешность (цена деления)', \
                         'Дата очер. поверки']]

    # заменим название колонок, где это необходимо
    mi_table.rename(columns = {'Дата очер. поверки':'Дата очередной поверки'}, inplace = True )

        
    # заменим старое значение ячейки на новое (уберём лишние пробелы для выравнивания)
    if (mi_table['Наименование средств измерений'].eq('Прибор электроизмерительный цифровой (мультиметр) ИМС-Ф1.Щ1')).any():
        mi_table = (mi_table.replace((mi_table[mi_table['Наименование средств измерений'] == 
                                               'Прибор электроизмерительный цифровой (мультиметр) ИМС-Ф1.Щ1']
                                      ['Пределы измерений'].values[0]), 
                                     ('Переменное напряжение от 40 до 400 В\nЧастота от 43,00 до 63,00 Гц')))
       
    # заменим старое значение ячейки на новое (добавляем пустых абзацов для выравнивания)
    if (mi_table['Наименование средств измерений'].eq('Прибор электроизмерительный цифровой (мультиметр) ИМС-Ф1.Щ1')).any():
        mi_table = (mi_table.replace((mi_table[mi_table['Наименование средств измерений'] == 
                                               'Прибор электроизмерительный цифровой (мультиметр) ИМС-Ф1.Щ1']
                                      ['Класс точности, погрешность (цена деления)'].values[0]), 
                                     ('±0,5 %\n\n\n±0,5%\n')))

    # заменим старое значение ячейки на новое (уберём лишние пробелы для выравнивания)
    if (mi_table['Наименование средств измерений'].eq('Секундомер электронный «Интеграл С-01»')).any():
        mi_table = (mi_table.replace((mi_table[mi_table['Наименование средств измерений'] == 
                                               'Секундомер электронный «Интеграл С-01»']
                                      ['Класс точности, погрешность (цена деления)'].values[0]), 
                                     ('(9,6*10⁻\u2076 *Тх+0,01)с\n±1,0 с/сут')))    

    # заменим старое значение ячейки на новое (поменяем "минус" на "-" для выравнивания)
    if (mi_table['Наименование средств измерений'].eq('Прибор комбинированный  Testo 622')).any():
        mi_table = (mi_table.replace((mi_table[mi_table['Наименование средств измерений'] == 
                                               'Прибор комбинированный  Testo 622']
                                      ['Пределы измерений'].values[0]), 
                                     ('-10…+60 °С\n0…100 %\n300… 1200 гПа')))

    # заменим старое значение ячейки на новое (уберём лишние пробелы для выравнивания)
    if (mi_table['Наименование средств измерений'].eq('Весы лабораторные ВК-300')).any():
        mi_table = (mi_table.replace((mi_table[mi_table['Наименование средств измерений'] == 
                                               'Весы лабораторные ВК-300']
                                      ['Класс точности, погрешность (цена деления)'].values[0]), 
                                     ('0,1÷50 г-± 0,005 г\n50÷200 г-± 0,01 г\n200÷300 г-± 0,015 г')))    

    # заменим старое значение ячейки на новое (уберём лишние пробелы для выравнивания)
    if (mi_table['Наименование средств измерений'].eq('Измеритель комбинированный «TESTO 425»')).any():
        mi_table = (mi_table.replace((mi_table[mi_table['Наименование средств измерений'] == 
                                               'Измеритель комбинированный «TESTO 425»']
                                      ['Пределы измерений'].values[0]), 
                                     ('0,1÷20,0 м/с\n-20... +70 °C')))
       
    # заменим старое значение ячейки на новое (добавляем пустых абзацов для выравнивания)
    if (mi_table['Наименование средств измерений'].eq('Измеритель комбинированный «TESTO 425»')).any():
        mi_table = (mi_table.replace((mi_table[mi_table['Наименование средств измерений'] == 
                                               'Измеритель комбинированный «TESTO 425»']
                                      ['Класс точности, погрешность (цена деления)'].values[0]), 
                                     ('±(0,1+0,05V)\n±0,5 в диапазоне (0…50) ºC\n±0,7 в остальном диапазоне')))

    # заменим старое значение ячейки на новое (добавляем пустых абзацов для выравнивания)
    if (mi_table['Наименование средств измерений'].eq('Инфракрасный пирометр «Sight» модификации MS')).any():
        mi_table = (mi_table.replace((mi_table[mi_table['Наименование средств измерений'] == 
                                               'Инфракрасный пирометр «Sight» модификации MS']
                                      ['Класс точности, погрешность (цена деления)'].values[0]), 
                                     ('В диапазоне -32...0: ±(1+0,07*(tизм.)) °С\nВ диапазоне 0...100: ±1 °С\nВ диапазоне выше 100°С: ±1%')))
        
    # заменим старое значение ячейки на новое (добавляем пустых абзацов для выравнивания)
    if (mi_table['Наименование средств измерений'].eq('Дифференциальный манометр цифровой ДМЦ-01М')).any():
        mi_table = (mi_table.replace((mi_table[mi_table['Наименование средств измерений'] == 
                                               'Дифференциальный манометр цифровой ДМЦ-01М']
                                      ['Класс точности, погрешность (цена деления)'].values[0]), 
                                     ('0…100Па  ±1,5Па\n(100,1…2000)Па ±(1+0,005 P)\nР-измеренное значение')))  

    # заменим старое значение ячейки на новое (уберём лишние пробелы для выравнивания)
    if (mi_table['Наименование средств измерений'].eq('Датчик плотности радиационного теплового потока ДРТП-15/10')).any():
        mi_table = (mi_table.replace((mi_table[mi_table['Наименование средств измерений'] == 
                                               'Датчик плотности радиационного теплового потока ДРТП-15/10']
                                      ['Пределы измерений'].values[0]), 
                                     ('(1÷63) кВт/м\u00B2')))        
        
    # заменим старое значение ячейки на новое (уберём лишние пробелы для выравнивания)
    if (mi_table['Наименование средств измерений'].eq('Модуль ввода аналоговый измерительный МВ110-224.8А')).any():
        mi_table = (mi_table.replace((mi_table[mi_table['Наименование средств измерений'] == 
                                               'Модуль ввода аналоговый измерительный МВ110-224.8А']
                                      ['Пределы измерений'].values[0]), 
                                     ('0…5 мА\n-50…+50 мВ\n-200°С...+1360°С')))
        
    # заменим старое значение ячейки на новое (уберём лишние пробелы для выравнивания)
    if (mi_table['Наименование средств измерений'].eq('Модуль ввода аналоговый измерительный МВА8')).any():
        mi_table = (mi_table.replace((mi_table[mi_table['Наименование средств измерений'] == 
                                               'Модуль ввода аналоговый измерительный МВА8']
                                      ['Пределы измерений'].values[0]), 
                                     ('0…5 мА\n-50…+50 мВ\n-200°С...+1300°С')))
        
    return mi_table

# %%
# функция по созданию и добавлению таблицы в Word файл    
def add_mi_table_func():
    # добавляем переменную, которой передаём количество строк (shape[0]+1) и столбцов (shape[1]) таблицы
    table = template.add_table(mi_table.shape[0]+1, mi_table.shape[1], style='Table Grid')

    # выравниваем таблицу по центру страницы
    table.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # добавляем строку - заголовок
    for j in range(mi_table.shape[-1]):    
        table.cell(0,j).text = mi_table.columns[j]

    # добавляем остальную часть данных
    for i in range(mi_table.shape[0]):
        for j in range(mi_table.shape[-1]):
            table.cell(i+1,j).text = str(mi_table.values[i,j])    

    # зададим ширину столбцам
    def set_col_widths(table):
        widths = (Cm(5.53), Cm(3.38), Cm(3.1), Cm(3.80), Cm(2.03))
        for row in table.rows:
            for idx, width in enumerate(widths):
                row.cells[idx].width = width
    set_col_widths(table)

    # выравниваем текст во всех колонках,кроме первой по центру
    for i in range(len(table.rows)):
        for j in range(1,(len(table.columns))):
            cell = table.rows[i].cells[j]
            cell_paragraph = cell.paragraphs[0]
            cell_paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # выравниваем текст 0 ячейки по центру
    cell = table.rows[0].cells[0]
    cell_paragraph = cell.paragraphs[0]
    cell_paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # выравниваем текст в необходимых ячейках по центру (по высоте)
    def vertical_center(row_idx, col_idx):
        table.cell(row_idx, col_idx).vertical_alignment = WD_ALIGN_VERTICAL.CENTER
    vertical_center(0,0)
    vertical_center(0,1)
    vertical_center(0,2)
    vertical_center(0,3)
    vertical_center(0,4)

    # сделаем строку/заголовок жирным шрифтом
    def make_rows_bold(*rows):
        for row in rows:
            for cell in row.cells:
                for paragraph in cell.paragraphs:
                    for run in paragraph.runs:
                        run.font.bold = True

    make_rows_bold(table.rows[0])
    
    # функция по повторению заголовка таблицы при переходе таблицы на новую страницу
    def set_repeat_table_header(row):
        tr = row._tr
        trPr = tr.get_or_add_trPr()
        tblHeader = OxmlElement('w:tblHeader')
        tblHeader.set(qn('w:val'), "true")
        trPr.append(tblHeader)
        return row    

    set_repeat_table_header(table.rows[0])

# %%
#ci_table_func(excel_file, test_type)

# %% [markdown]
# #### ИО

# %%
# если 2 образца в одной печи одновременно
if furnace1 == furnace2 and test_dates1 == test_dates2:

    # задаём номер печи
    furnace = furnace1
    # задаём дату испытания
    test_dates = test_dates1

    # функция по добавлению текста перед таблицей (номер таблицы, текст/образец)
    add_name_table_func(table_num, 'Перечень оборудования', 'Образцы №№ 1, 2')

    # функция по выбору необходимого ексель файла по дате испытаний (дата испытаний, путь к папке с файлами)
    excel_file = excel_file_func(test_dates, path1)

    # функция для формирования таблицы ИО в зависимости от типа испытания (ексель файл, тип испытаний)
    io_table_func(excel_file, test_type)

    # продолжаем нумерацию таблиц
    table_num += 1
    
    
# если ПИ по S на 4 образца    
elif test_type == 'S' and test_dates3 != '':

    # первый/третий образцы

    # задаём номер печи
    furnace = furnace1
    # задаём дату испытания
    test_dates = test_dates1

    # функция по добавлению текста перед таблицей (номер таблицы, текст/образец)
    add_name_table_func(table_num, 'Перечень оборудования', 'Образцы №№ 1, 3')

    # функция по выбору необходимого ексель файла по дате испытаний (дата испытаний, путь к папке с файлами)
    excel_file = excel_file_func(test_dates, path1)

    # функция для формирования таблицы ИО в зависимости от типа испытания (ексель файл, тип испытаний)
    io_table_func(excel_file, test_type)

    # продолжаем нумерацию таблиц
    table_num += 1    


    # второй/четвёртый образцы

    # задаём номер печи
    furnace = furnace2
    # задаём дату испытания
    test_dates = test_dates2

    # функция по добавлению текста перед таблицей (номер таблицы, текст/образец)
    add_name_table_func(table_num, 'Перечень оборудования', 'Образцы №№ 2, 4')

    # функция по выбору необходимого ексель файла по дате испытаний (дата испытаний, путь к папке с файлами)
    excel_file = excel_file_func(test_dates, path1)

    # функция для формирования таблицы ИО в зависимости от типа испытания (ексель файл, тип испытаний)
    io_table_func(excel_file, test_type)

    # продолжаем нумерацию таблиц
    table_num += 1      
    

# если каждый образец по отдельности
else:

    # первый образец

    # задаём номер печи
    furnace = furnace1
    # задаём дату испытания
    test_dates = test_dates1

    # функция по добавлению текста перед таблицей (номер таблицы, текст/образец)
    add_name_table_func(table_num, 'Перечень оборудования', 'Образец №1')

    # функция по выбору необходимого ексель файла по дате испытаний (дата испытаний, путь к папке с файлами)
    excel_file = excel_file_func(test_dates, path1)

    # функция для формирования таблицы ИО в зависимости от типа испытания (ексель файл, тип испытаний)
    io_table_func(excel_file, test_type)

    # продолжаем нумерацию таблиц
    table_num += 1    


    # второй образец

    # задаём номер печи
    furnace = furnace2
    # задаём дату испытания
    test_dates = test_dates2

    # функция по добавлению текста перед таблицей (номер таблицы, текст/образец)
    add_name_table_func(table_num, 'Перечень оборудования', 'Образец №2')

    # функция по выбору необходимого ексель файла по дате испытаний (дата испытаний, путь к папке с файлами)
    excel_file = excel_file_func(test_dates, path1)

    # функция для формирования таблицы ИО в зависимости от типа испытания (ексель файл, тип испытаний)
    io_table_func(excel_file, test_type)

    # продолжаем нумерацию таблиц
    table_num += 1

# %% [markdown]
# #### СИ

# %%
# по новой


# если 2 образца в одной печи одновременно
if furnace1 == furnace2 and test_dates1 == test_dates2:
    
    # берём термопары на 2 образца
    thermoelectric_converter_val = thermoelectric_converter_val*2

    # задаём номер печи
    furnace = furnace1
    # задаём дату испытания
    test_dates = test_dates1

    # функция по добавлению текста перед таблицей (номер таблицы, текст/образец)
    add_name_table_func(table_num, 'Перечень средств измерения', 'Образцы №№ 1, 2')

    # функция по выбору необходимого ексель файла по дате испытаний (дата испытаний, путь к папке с файлами)
    excel_file = excel_file_func(test_dates, path1)

    # функция для формирования таблицы ИО в зависимости от типа испытания (ексель файл, тип испытаний)
    mi_table = ci_table_func(excel_file, test_type)
    
    # функция по созданию и добавлению таблицы в Word файл
    add_mi_table_func()

    # продолжаем нумерацию таблиц
    table_num += 1  
    
# если ПИ по S на 4 образца    
elif test_type == 'S' and test_dates3 != '':

    # первый/третий образцы

    # задаём номер печи
    furnace = furnace1
    # задаём дату испытания
    test_dates = test_dates1

    # функция по добавлению текста перед таблицей (номер таблицы, текст/образец)
    add_name_table_func(table_num, 'Перечень средств измерения', 'Образцы №№ 1, 3')

    # функция по выбору необходимого ексель файла по дате испытаний (дата испытаний, путь к папке с файлами)
    excel_file = excel_file_func(test_dates, path1)

    # функция для формирования таблицы ИО в зависимости от типа испытания (ексель файл, тип испытаний)
    mi_table = ci_table_func(excel_file, test_type)
    
    # функция по созданию и добавлению таблицы в Word файл
    add_mi_table_func()

    # продолжаем нумерацию таблиц
    table_num += 1    


    # второй/четвёртый образцы

    # задаём номер печи
    furnace = furnace2
    # задаём дату испытания
    test_dates = test_dates2

    # функция по добавлению текста перед таблицей (номер таблицы, текст/образец)
    add_name_table_func(table_num, 'Перечень средств измерения', 'Образцы №№ 2, 4')

    # функция по выбору необходимого ексель файла по дате испытаний (дата испытаний, путь к папке с файлами)
    excel_file = excel_file_func(test_dates, path1)

    # функция для формирования таблицы ИО в зависимости от типа испытания (ексель файл, тип испытаний)
    mi_table = ci_table_func(excel_file, test_type)
    
    # функция по созданию и добавлению таблицы в Word файл
    add_mi_table_func()

    # продолжаем нумерацию таблиц
    table_num += 1    
    
    
# если каждый образец по отдельности
else:
    
    # первый образец

    # задаём номер печи
    furnace = furnace1
    # задаём дату испытания
    test_dates = test_dates1

    # функция по добавлению текста перед таблицей (номер таблицы, текст/образец)
    add_name_table_func(table_num, 'Перечень средств измерения', 'Образец №1')

    # функция по выбору необходимого ексель файла по дате испытаний (дата испытаний, путь к папке с файлами)
    excel_file = excel_file_func(test_dates, path1)

    # функция для формирования таблицы ИО в зависимости от типа испытания (ексель файл, тип испытаний)
    mi_table = ci_table_func(excel_file, test_type)
    
    # функция по созданию и добавлению таблицы в Word файл
    add_mi_table_func()

    # продолжаем нумерацию таблиц
    table_num += 1


    # второй образец

    # задаём номер печи
    furnace = furnace2
    # задаём дату испытания
    test_dates = test_dates2

    # функция по добавлению текста перед таблицей (номер таблицы, текст/образец)
    add_name_table_func(table_num, 'Перечень средств измерения', 'Образец №2')

    # функция по выбору необходимого ексель файла по дате испытаний (дата испытаний, путь к папке с файлами)
    excel_file = excel_file_func(test_dates, path1)

    # функция для формирования таблицы ИО в зависимости от типа испытания (ексель файл, тип испытаний)
    mi_table = ci_table_func(excel_file, test_type)
    
    # функция по созданию и добавлению таблицы в Word файл
    add_mi_table_func()

    # продолжаем нумерацию таблиц
    table_num += 1

# %% [raw]
# # по старой
#
# # если 2 образца в одной печи одновременно
# if furnace1 == furnace2 and test_dates1 == test_dates2:
#
#     # берём термопары на 2 образца
#     thermoelectric_converter_val = thermoelectric_converter_val*2
#
#     # задаём номер печи
#     furnace = furnace1
#     # задаём дату испытания
#     test_dates = test_dates1
#
#     # функция по добавлению текста перед таблицей (номер таблицы, текст/образец)
#     add_name_table_func(table_num, 'Перечень средств измерения', 'Образцы №№ 1, 2')
#
#     # функция по выбору необходимого ексель файла по дате испытаний (дата испытаний, путь к папке с файлами)
#     excel_file = excel_file_func(test_dates, path1)
#
#     # функция для формирования таблицы ИО в зависимости от типа испытания (ексель файл, тип испытаний)
#     ci_table_func(excel_file, test_type)
#
#     # продолжаем нумерацию таблиц
#     table_num += 1
#
# # если ПИ по S на 4 образца
# elif test_type == 'S' and test_dates3 != '':
#
#     # первый/третий образцы
#
#     # задаём номер печи
#     furnace = furnace1
#     # задаём дату испытания
#     test_dates = test_dates1
#
#     # функция по добавлению текста перед таблицей (номер таблицы, текст/образец)
#     add_name_table_func(table_num, 'Перечень средств измерения', 'Образцы №№ 1, 3')
#
#     # функция по выбору необходимого ексель файла по дате испытаний (дата испытаний, путь к папке с файлами)
#     excel_file = excel_file_func(test_dates, path1)
#
#     # функция для формирования таблицы ИО в зависимости от типа испытания (ексель файл, тип испытаний)
#     ci_table_func(excel_file, test_type)
#
#     # продолжаем нумерацию таблиц
#     table_num += 1
#
#
#     # второй/четвёртый образцы
#
#     # задаём номер печи
#     furnace = furnace2
#     # задаём дату испытания
#     test_dates = test_dates2
#
#     # функция по добавлению текста перед таблицей (номер таблицы, текст/образец)
#     add_name_table_func(table_num, 'Перечень средств измерения', 'Образцы №№ 2, 4')
#
#     # функция по выбору необходимого ексель файла по дате испытаний (дата испытаний, путь к папке с файлами)
#     excel_file = excel_file_func(test_dates, path1)
#
#     # функция для формирования таблицы ИО в зависимости от типа испытания (ексель файл, тип испытаний)
#     ci_table_func(excel_file, test_type)
#
#     # продолжаем нумерацию таблиц
#     table_num += 1
#
#
# # если каждый образец по отдельности
# else:
#
#     # первый образец
#
#     # задаём номер печи
#     furnace = furnace1
#     # задаём дату испытания
#     test_dates = test_dates1
#
#     # функция по добавлению текста перед таблицей (номер таблицы, текст/образец)
#     add_name_table_func(table_num, 'Перечень средств измерения', 'Образец №1')
#
#     # функция по выбору необходимого ексель файла по дате испытаний (дата испытаний, путь к папке с файлами)
#     excel_file = excel_file_func(test_dates, path1)
#
#     # функция для формирования таблицы ИО в зависимости от типа испытания (ексель файл, тип испытаний)
#     ci_table_func(excel_file, test_type)
#
#     # продолжаем нумерацию таблиц
#     table_num += 1
#
#
#     # второй образец
#
#     # задаём номер печи
#     furnace = furnace2
#     # задаём дату испытания
#     test_dates = test_dates2
#
#     # функция по добавлению текста перед таблицей (номер таблицы, текст/образец)
#     add_name_table_func(table_num, 'Перечень средств измерения', 'Образец №2')
#
#     # функция по выбору необходимого ексель файла по дате испытаний (дата испытаний, путь к папке с файлами)
#     excel_file = excel_file_func(test_dates, path1)
#
#     # функция для формирования таблицы ИО в зависимости от типа испытания (ексель файл, тип испытаний)
#     ci_table_func(excel_file, test_type)
#
#     # продолжаем нумерацию таблиц
#     table_num += 1

# %% [markdown]
# ### Результаты испытаний (текстовик)

# %%
#добавим пустой абзац между разделами
p = template.add_paragraph()

# %%
#добавим название раздела
p = template.add_paragraph()
p.alignment = WD_ALIGN_PARAGRAPH.CENTER
run = p.add_run('10. Результаты испытаний')
run.font.bold = True

# %%
# считаем общее количество графиков

# печные графики
if furnace3 == '':
    # если 2 образца в одной печи одновременно
    if furnace1 == furnace2 and test_dates1 == test_dates2:
        graph_total = 1
    # если каждый образец испытывался отдельно    
    else:
        graph_total = 2
else:
    graph_total = 4

# остальные графики    
if graph_1[0] != '0':
    graph_total +=2
else:
    pass    
if graph_2[0] != '0':
    graph_total +=2
else:
    pass  
if graph_3[0] != '0':
    graph_total +=2
else:
    pass
if graph_4[0] != '0':
    graph_total +=2
else:
    pass     
if graph_5[0] != '0':
    graph_total +=2
else:
    pass
if graph_6[0] != '0':
    graph_total +=2
else:
    pass     
if graph_7[0] != '0':
    graph_total +=2
else:
    pass
if graph_8[0] != '0':
    graph_total +=2
else:
    pass     
if graph_9[0] != '0':
    graph_total +=2
else:
    pass
if graph_9[0] != '0':
    graph_total +=2
else:
    pass
if graph_10[0] != '0':
    graph_total +=2
else:
    pass

# %%
if test_type != 'S':
    # если 2 образца в одной печи одновременно
    if furnace1 == furnace2 and test_dates1 == test_dates2:
        a = 'печи'
        b = f'{drawing_num}-{graph_total+1}'
        c = f'таблице {table_num + 1}'
        if test_type == 'E' or test_type == 'EIW':
            d = ' Фото образца представлено в приложении 1.'
        else:
            d = ''
    # если каждый образец испытывался отдельно    
    else:
        a = 'печах'    
        b = f'{drawing_num}-{graph_total+1}'
        c = f'таблицах {table_num + 1}-{table_num + 2}'
        if test_type == 'E' or test_type == 'EIW':
            d = ' Фото образца представлено в приложении 1.'
        else:
            d = ''
else:
    if serial_number_4 != '':
        a = 'печах'
        b = f'{drawing_num}-4'
        c = f'таблицах {table_num + 1}-{table_num + 4}'
        d = ''
    else:
        a = 'печах'
        b = f'{drawing_num}-2'
        c = f'таблицах {table_num + 1}-{table_num + 2}'
        d = ''

# %%
# собираем текст
if test_type != 'S':
    temperature_measurement_results_text = f'	\n\
    	Результаты измерений температуры в {a} и на образцах представлены на рисунках {b}. \
Значения температуры в {a} на протяжении испытаний не превышали допустимых отклонений, определенных ГОСТ 30247.0-94. \
Результаты измерений избыточного давления в {a} представлены в {c}.{d}'
# в ПИ по S текст будет разбит на 2 части и к нему будет добавлена формула/картинка    
else:
    temperature_measurement_results_text = f'	\n\
    	Результаты измерений температуры в {a} представлены на рисунках {b}.	\n\
    	Приведённое удельное сопротивление дымогазопроницанию определялось по формуле:	\n\
    	'

# %%
# добавляем текст

#добавим содержание раздела
p = template.add_paragraph()
# отступ слева
p.paragraph_format.left_indent = Cm(0.25)
# отступ справа
p.paragraph_format.right_indent = Cm(0.25)
# красная строка
p.paragraph_format.first_line_indent = Cm(1.25)
# межстрочный интервал
p.paragraph_format.line_spacing = 1.0
# выравнивание текста по ширине
p.paragraph_format.alignment = WD_ALIGN_PARAGRAPH.JUSTIFY
# вставка текста 
run = p.add_run(temperature_measurement_results_text)

# %%
# добавляем картинку/формулу + вторую часть текста
if test_type == 'S':
    # добавляем пустой абзац
    p = template.add_paragraph()
    # добавляем пустой прогон
    run = p.add_run()
    # теперь в прогон вставляем график
    run.add_picture(formula_path+'/формула дымогазопроницания.png', width=Cm(3.13), height=Cm(0.98))
    # выравниваем картинку посередине страницы
    p.alignment =  WD_ALIGN_PARAGRAPH.CENTER 
    
    # добавляем вторую часть текста для ПИ по S
    temperature_measurement_results_text = f'	\n\
    	где F\u2202 — площадь проходного сечения двери, м\u00B2;	\n\
    	ΔР\u1D62  — разность давлений на образце в i-ом измерении, Па;	\n\
    	G\u1D62  — расход газов, проходящих через образец, в i-м измерении, кг/с;	\n\
    	ρ\u1D62 — плотность газов, фильтрующегося через неплотности образца в i-м измерении, кг/м\u00B3;	\n\
    	ρ\u2082\u2080 — плотность газов при температуре 293 К, кг/м\u00B3;	\n\
    	n – число измерений во время испытания.	\n\
    \n\
    	Расчетные данные и результаты измерений, полученные при испытаниях, приведены в {c}.\n\
    	В процессе испытаний было установлено, что фактическое сопротивление дымогазопроницанию испытываемых образцов превысило нормируемое минимально допустимое значение 1,96·10\u2075 м\u00B3/кг.'    
    
    #добавим содержание раздела
    p = template.add_paragraph()
    # отступ слева
    p.paragraph_format.left_indent = Cm(0.25)
    # отступ справа
    p.paragraph_format.right_indent = Cm(0.25)
    # красная строка
    p.paragraph_format.first_line_indent = Cm(1.25)
    # межстрочный интервал
    p.paragraph_format.line_spacing = 1.0
    # выравнивание текста по ширине
    p.paragraph_format.alignment = WD_ALIGN_PARAGRAPH.JUSTIFY
    # вставка текста 
    run = p.add_run(temperature_measurement_results_text)

# %% [markdown]
# ### Таблица погоды

# %%
#добавим пустой абзац между текстовиком и таблицей
p = template.add_paragraph()

# %%
# добавим название таблицы 

# добавляем абзац с текстом
p = template.add_paragraph(f'Таблица {table_num}. Условия проведения испытаний.')

# убираем интервал после текста
p.paragraph_format.space_after = Pt(0)

# добавляем отступ слева
# если 4 образца
if furnace3 != '':
    p.paragraph_format.left_indent = Cm(0.5)
    
# если 2 образца
elif furnace3 == '':
    p.paragraph_format.left_indent = Cm(3)

# %%
# продолжаем нумерацию таблиц
table_num += 1

# %%
# путь к excel файлу
path_w = rf'{path_w}'.replace('\\', '/')

# имя excel файла, который располагается в выше указанной папке
doc_name_w = '/_!00 Журнал окружающей среды'

# расширение excel файла
extension_w = '.xlsx'

# читаем файл и преобразовываем его в df
excel_file_w = pd.ExcelFile(path_w+doc_name_w+extension_w)

# загрузим необходимые листы в виде df
df_g = excel_file_w.parse('Горная')
df_l = excel_file_w.parse('Ленина')

# %%
# функция по созданию таблички погоды для одного образца (дата, печь)
def weather_table_func(test_dates, furnace):
    
    # если печь находится по адресу Ленина
    if furnace in lenina:

        # загрузим необходимые листы в виде df
        df_l = excel_file_w.parse('Ленина')

        # приведём даты в df к нужному виду
        df_l['дата'] = df_l['дата'].dt.strftime('%d.%m.%Y')   

        # фильтр df по дате
        df = df_l[df_l['дата'] == test_dates]

    # если печь находится по адресу горная    
    elif furnace in gornaya:

        # загрузим необходимые листы в виде df
        df_g = excel_file_w.parse('Горная')

        # приведём даты в df к нужному виду
        df_g['дата'] = df_g['дата'].dt.strftime('%d.%m.%Y')

        # фильтр df по дате
        df = df_g[df_g['дата'] == test_dates]

    return df

# %%
# первый образец
weather_table1 = weather_table_func(test_dates1, furnace1)

# второй образец
weather_table2 = weather_table_func(test_dates2, furnace2)

# %%
weather_table2
# Out:
#            дата  Т, грС  Влажность, %  Давление, кПа U сети,В Частота, Гц  \
# 832  15.04.2023    20.0          46.0          101.2      231          50
#
#      Скорость воздуха, м/с  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 832                    0.1         NaN         NaN         NaN          NaN
#
#      Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14
# 832          NaN          NaN          NaN         -0.1

# %%
weather_table1
# Out:
#            дата  Т, грС  Влажность, %  Давление, кПа U сети,В Частота, Гц  \
# 835  18.04.2023    21.0          51.0           99.9      231          50
#
#      Скорость воздуха, м/с  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 835                    0.1         NaN         NaN         NaN          NaN
#
#      Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14
# 835          NaN          NaN          NaN          0.0

# %%
# 3 и 4 образцы
if furnace3 != '':
    weather_table3 = weather_table_func(test_dates3, furnace3)
    weather_table4 = weather_table_func(test_dates4, furnace4)

# если печь не задана (furnace = '')        
else:
    pass

# %%
# 3 и 4 образцы
if furnace3 != '':
    # объединим таблицы в одну
    weather_table = pd.concat([weather_table1, weather_table2, weather_table3, weather_table4])

# если печь не задана (furnace = '')        
else:
    weather_table = pd.concat([weather_table1, weather_table2])

# %%
weather_table
# Out:
#            дата  Т, грС  Влажность, %  Давление, кПа U сети,В Частота, Гц  \
# 835  18.04.2023    21.0          51.0           99.9      231          50
# 832  15.04.2023    20.0          46.0          101.2      231          50
#
#      Скорость воздуха, м/с  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 835                    0.1         NaN         NaN         NaN          NaN
# 832                    0.1         NaN         NaN         NaN          NaN
#
#      Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14
# 835          NaN          NaN          NaN          0.0
# 832          NaN          NaN          NaN         -0.1

# %%
# удаляем пустые столбцы
weather_table = weather_table.dropna(axis=1)
weather_table
# Out:
#            дата  Т, грС  Влажность, %  Давление, кПа U сети,В Частота, Гц  \
# 835  18.04.2023    21.0          51.0           99.9      231          50
# 832  15.04.2023    20.0          46.0          101.2      231          50
#
#      Скорость воздуха, м/с  Unnamed: 14
# 835                    0.1          0.0
# 832                    0.1         -0.1

# %%
# удаляем столбец Unnamed: 14, если он есть
if 'Unnamed: 14' in weather_table.columns:
    weather_table.drop('Unnamed: 14', axis= 1 , inplace= True )
weather_table
# Out:
#            дата  Т, грС  Влажность, %  Давление, кПа U сети,В Частота, Гц  \
# 835  18.04.2023    21.0          51.0           99.9      231          50
# 832  15.04.2023    20.0          46.0          101.2      231          50
#
#      Скорость воздуха, м/с
# 835                    0.1
# 832                    0.1

# %%
weather_table['Давление, кПа'] = weather_table['Давление, кПа'].round(1)
weather_table
# Out:
#            дата  Т, грС  Влажность, %  Давление, кПа U сети,В Частота, Гц  \
# 835  18.04.2023    21.0          51.0           99.9      231          50
# 832  15.04.2023    20.0          46.0          101.2      231          50
#
#      Скорость воздуха, м/с
# 835                    0.1
# 832                    0.1

# %%
# заменим типы данных некоторых колонок
weather_table = weather_table.astype({'Т, грС':int, 'Влажность, %':int, 'U сети,В':int, 'Частота, Гц':int})

# переименуем столбцы
weather_table.columns = ['Дата(ы) проведения испытаний',
              'Температура окружающей среды, °C',
              'Относительная влажность воздуха, %',
              'Атмосферное давление, кПа',
              'Напряжение сети электропитания, В',
              'Частота переменного тока в сети электропитания, Гц',
              'Скорость движения воздуха, м/сек']

# поменяем порядок столбцов на необходимый
weather_table = weather_table[['Дата(ы) проведения испытаний',
         'Температура окружающей среды, °C',
         'Атмосферное давление, кПа',
         'Относительная влажность воздуха, %',
         'Скорость движения воздуха, м/сек',
         'Напряжение сети электропитания, В',
         'Частота переменного тока в сети электропитания, Гц']]

# транспонируем df
weather_table = weather_table.T

# переведём индексы в столбец
weather_table = weather_table.reset_index(level=0)

# 3 и 4 образцы
if furnace3 != '':
    # переименуем столбцы
    weather_table.columns = ['', 'Образец №1', 'Образец №2', 'Образец №3', 'Образец №4']

# если печь не задана (furnace = '')        
elif furnace3 == '':
    # переименуем столбцы
    weather_table.columns = ['', 'Образец №1', 'Образец №2']

# %%
# получим список из названий столбцов и вставим его первой строкой в df
weather_table.loc[-1] = list(weather_table.columns)
weather_table.index = weather_table.index + 1
weather_table = weather_table.sort_index()


# 3 и 4 образцы
if furnace3 != '':
    # создадим задел для вставки "глухие/с остеклением" для ПИ на 4 образца

    # получим список из названий столбцов и вставим его первой строкой в df
    weather_table.loc[-1] = list(weather_table.columns)
    weather_table.index = weather_table.index + 1
    weather_table = weather_table.sort_index()
    
    # сделаем строку/заготовку пустой
    weather_table.iloc[[1]] = weather_table.iloc[[1]].replace('Образец №1', '')
    weather_table.iloc[[1]] = weather_table.iloc[[1]].replace('Образец №2', '')
    weather_table.iloc[[1]] = weather_table.iloc[[1]].replace('Образец №3', '')
    weather_table.iloc[[1]] = weather_table.iloc[[1]].replace('Образец №4', '')

# %%
# сделаем названия столбцов пустыми. умножим '', на количество столбцов
weather_table.columns = [['',] * len(list(weather_table.columns))]

# %%
# добавляем переменную, которой передаём количество строк (shape[0]+1) и столбцов (shape[1]) таблицы
table = template.add_table(weather_table.shape[0]+1, weather_table.shape[1], style='Table Grid')

# выравниваем таблицу по центру страницы
table.alignment = WD_ALIGN_PARAGRAPH.CENTER

# добавляем строку - заголовок
for j in range(weather_table.shape[-1]):
    table.cell(0,j).text = weather_table.columns[j]

# добавляем остальную часть данных
for i in range(weather_table.shape[0]):
    for j in range(weather_table.shape[-1]):
        table.cell(i+1,j).text = str(weather_table.values[i,j])

# %%
# зададим ширину столбцам

# табличка для 2 образцов
if len(list(weather_table.columns)) == 3:
    def set_col_widths(table):
        widths = (Cm(8.56), Cm(2.4), Cm(2.4))
        for row in table.rows:
            for idx, width in enumerate(widths):
                row.cells[idx].width = width
    set_col_widths(table)

# табличка для 4 образцов    
elif  len(list(weather_table.columns)) == 5:
    def set_col_widths(table):
        widths = (Cm(8.56), Cm(2.4), Cm(2.4), Cm(2.4), Cm(2.4))
        for row in table.rows:
            for idx, width in enumerate(widths):
                row.cells[idx].width = width
    set_col_widths(table)

# %%
# выравниваем текст во всех колонках,кроме первой по центру
for i in range(len(table.rows)):
    for j in range(1,(len(table.columns))):
        cell = table.rows[i].cells[j]
        cell_paragraph = cell.paragraphs[0]
        cell_paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER

# %%
# выравниваем текст 0 ячейки по центру
cell = table.rows[0].cells[0]
cell_paragraph = cell.paragraphs[0]
cell_paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER

# %%
# обработка строки/заглушки
if furnace3 != '':

    # "сшиваем" ячейки в необходимых местах для формирования определённого вида таблицы
    a = table.cell(2, 1)
    b = table.cell(2, 2)
    A = a.merge(b)  
        
    c = table.cell(2, 3)
    d = table.cell(2, 4)
    B = c.merge(d) 

    # добавляем необходимый текст в нужную ячейку
    table.cell(2, 1).text = 'глухие'
    table.cell(2, 3).text = 'с остеклением'
    
    a = table.cell(0, 0)
    b = table.cell(2, 0)
    A = a.merge(b)

    c = table.cell(0, 1)
    d = table.cell(0, (len(list(weather_table.columns))-1))
    B = c.merge(d) 


elif furnace3 == '':
    # "сшиваем" ячейки в необходимых местах для формирования определённого вида таблицы
    a = table.cell(0, 0)
    b = table.cell(1, 0)
    A = a.merge(b)

    c = table.cell(0, 1)
    d = table.cell(0, (len(list(weather_table.columns))-1))
    B = c.merge(d)

# %%
# добавляем необходимый текст в нужную ячейку
table.cell(0, 2).text = 'Значение показателей'

# %%
# добавляем необходимый текст в нужную ячейку
table.cell(0, 0).text = 'Наименование условий при испытании'

# %%
# выравниваем текст во всех колонках,кроме первой по центру
for i in range(len(table.rows)):
    for j in range(1,(len(table.columns))):
        cell = table.rows[i].cells[j]
        cell_paragraph = cell.paragraphs[0]
        cell_paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER

# %%
# выравниваем текст в необходимых ячейках по центру (по высоте)
def vertical_center(row_idx, col_idx):
    table.cell(row_idx, col_idx).vertical_alignment = WD_ALIGN_VERTICAL.CENTER
vertical_center(0,0)

# %% [markdown]
# ### Таблица давления

# %%
# функция по созданию таблички с давлением
def pressure_table_func(fire_limit):
    
    #1 "рандомные" значения давления по заданному принципу
    # 1-3 мин =СЛУЧМЕЖДУ (8.0*10.0 ; 12.0*10.0) / 10
    result_1 = [round(random.uniform(8, 12), 1) for i in range(3)]
    # 4 мин =СЛУЧМЕЖДУ (8.0*10.0 ;  8.5*10.0) / 10
    result_2 = [round(random.uniform(8, 8.5), 1) for i in range(1)]
    # 5-9 мин =СЛУЧМЕЖДУ (8.0*10.0 ;  12.0*10.0) / 10
    result_3 = [round(random.uniform(8, 12), 1) for i in range(5)]
    # 10 - fire_limit мин =СЛУЧМЕЖДУ (9.0*10.0 ; 11.0*10.0) / 10
    result_4 = [round(random.uniform(9, 11), 1) for i in range(fire_limit - 9)]
    # список значений давления
    result_p = result_1 + result_2 + result_3 + result_4
    
    #2 делим все значения давления на три столбца
    # первая треть значений для заполнения первого столбца
    result_p1 = result_p[0:(int(fire_limit/3))]
    # вторая треть значений для заполнения второго столбца
    result_p2 = result_p[(int(fire_limit/3)):(int(fire_limit/3)*2)]
    # третья треть значений для заполнения третьего столбца
    result_p3 = result_p[(int(fire_limit/3)*2):(int(fire_limit))]
    
    #3 список минут
    result_m = [i for i in range(int(1), int(fire_limit) + 1)]

    #4 делим все значения из списка минут на три столбца
    # первая треть значений для заполнения первого столбца
    result_m1 = result_m[0:(int(fire_limit/3))]
    # вторая треть значений для заполнения второго столбца
    result_m2 = result_m[(int(fire_limit/3)):(int(fire_limit/3)*2)]
    # третья треть значений для заполнения третьего столбца
    result_m3 = result_m[(int(fire_limit/3)*2):(int(fire_limit))]

    #5 расставим столбцы по порядку
    column_1 = result_m1
    column_2 = result_p1
    column_3 = result_m2
    column_4 = result_p2
    column_5 = result_m3
    column_6 = result_p3

    #6 собираем df
    data = [column_1, column_2, column_3, column_4, column_5, column_6]
    columns = ['Время, мин', 'Давление, Па', 'Время, мин', 'Давление, Па', 'Время, мин', 'Давление, Па']
    df = pd.DataFrame(data, columns)
    # транспонируем df
    df = df.T
    # приведём столбцы с минутами к типу int
    df['Время, мин'] = df['Время, мин'].astype(int)
    
    # приведём столбцы к типу str
    df['Время, мин'] = df['Время, мин'].astype('string')    
    df['Давление, Па'] = df['Давление, Па'].astype('string') 
    
    return df

# %%
# функция для обрааботки таблицы
def table_processing_func(pressure_table):

    # добавляем переменную, которой передаём количество строк (shape[0]+1) и столбцов (shape[1]) таблицы
    table = template.add_table(pressure_table.shape[0]+1, pressure_table.shape[1], style='Table Grid')

    # выравниваем таблицу по центру страницы
    table.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # добавляем строку - заголовок
    for j in range(pressure_table.shape[-1]):
        table.cell(0,j).text = pressure_table.columns[j]

    # добавляем остальную часть данных
    for i in range(pressure_table.shape[0]):
        for j in range(pressure_table.shape[-1]):
            table.cell(i+1,j).text = str(pressure_table.values[i,j])

    # зададим ширину столбцам (указываем ширину ячеек - 2.55 и ед. измерения - см)

    # ширина столбца (числовое значение) (если дробное, то записывается через точку, например 3.5)
    column_width = 2.55
    # единица измерения ширина столбца (Pt, Inches, Cm и т.д.)
    unit_measurement = Cm

    # функция для задания ширины ячейки таблицы
    def set_col_widths(table_name, column_width, unit_measurement):
            for row in table_name.rows:
                for cell in row.cells:
                    cell.width = unit_measurement(column_width)

    set_col_widths(table, column_width, unit_measurement)

    # добавляем необходимый текст в нужную ячейку
    table.cell(0, 0).text = 'Время, мин'
    table.cell(0, 1).text = 'Давление, Па'
    table.cell(0, 2).text = 'Время, мин'
    table.cell(0, 3).text = 'Давление, Па'
    table.cell(0, 4).text = 'Время, мин'
    table.cell(0, 5).text = 'Давление, Па'        

    # выравниваем текст во всех колонках по центру
    for i in range(len(table.rows)):
        for j in range(0,(len(table.columns))):
            cell = table.rows[i].cells[j]
            cell_paragraph = cell.paragraphs[0]
            cell_paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # выравниваем текст во всех колонках по центру (по высоте)
    for i in range(len(table.rows)):
        for j in range(0,(len(table.columns))):
            cell = table.rows[i].cells[j]
            cell_paragraph = cell.paragraphs[0]
            cell_paragraph.vertical_alignment = WD_ALIGN_VERTICAL.CENTER

    # сделаем шрифт необходимых столбцов жирным шрифтом
    def make_rows_bold(*columns):
        for column in columns:
            for cell in column.cells:
                for paragraph in cell.paragraphs:
                    for run in paragraph.runs:
                        run.font.bold = True
    make_rows_bold(table.columns[0])
    make_rows_bold(table.columns[2])
    make_rows_bold(table.columns[4])

    # сделаем строку/заголовок жирным шрифтом
    def make_rows_bold(*rows):
        for row in rows:
            for cell in row.cells:
                for paragraph in cell.paragraphs:
                    for run in paragraph.runs:
                        run.font.bold = True
    make_rows_bold(table.rows[0])

# %%
# Для всех ПИ, кроме S
if test_type != 'S':
    #добавим пустой абзац между текстовиком и таблицей
    p = template.add_paragraph()
    
    # если 2 образца в одной печи одновременно - 1 таблица
    if furnace1 == furnace2 and test_dates1 == test_dates2:
        # добавим название таблицы
        # добавляем абзац с текстом
        p = template.add_paragraph(f'Таблица {table_num}. Давление в печи. Образцы №№ 1, 2.')
        # убираем интервал после текста
        p.paragraph_format.space_after = Pt(0)
        # добавляем отступ слева
        p.paragraph_format.left_indent = Cm(2.0)
        # продолжаем нумерацию таблиц
        table_num += 1        
        # функция по созданию таблички с давлением
        pressure_table = pressure_table_func(fire_limit)
        # преобразовываем и добавляем таблицу
        table_processing_func(pressure_table)    
        
    # если образцы в разных печах - 2 таблицы
    else:
        # добавим название таблицы
        # добавляем абзац с текстом
        p = template.add_paragraph(f'Таблица {table_num}. Давление в печи. Образец № 1.')
        # убираем интервал после текста
        p.paragraph_format.space_after = Pt(0)
        # добавляем отступ слева
        p.paragraph_format.left_indent = Cm(2.0)
        # продолжаем нумерацию таблиц
        table_num += 1        
        # функция по созданию таблички с давлением
        pressure_table1 = pressure_table_func(fire_limit)
        # преобразовываем и добавляем таблицу
        table_processing_func(pressure_table1)
        
        #добавим пустой абзац между таблицами
        p = template.add_paragraph()
        
        # добавим название таблицы
        # добавляем абзац с текстом
        p = template.add_paragraph(f'Таблица {table_num}. Давление в печи. Образец № 2.')
        # убираем интервал после текста
        p.paragraph_format.space_after = Pt(0)
        # добавляем отступ слева
        p.paragraph_format.left_indent = Cm(2.0)
        # продолжаем нумерацию таблиц
        table_num += 1        
        # функция по созданию таблички с давлением
        pressure_table2 = pressure_table_func(fire_limit) 
        # преобразовываем и добавляем таблицу
        table_processing_func(pressure_table2)
        
elif test_type == 'S':
    pass

# %% [markdown]
# ### Графики

# %%
#добавим пустой абзац перед графиками
p = template.add_paragraph()

# %%
# задаём количество печных графиков

# если 2 образца в одной печи одновременно - 1 график
if furnace1 == furnace2 and test_dates1 == test_dates2:
    furnace_total = 1
else:
    # если ПИ на S на 4 образца - 4 графика    
    if furnace3 != '':
        furnace_total = 4
    # в других случаях - 2 графика
    else:
        furnace_total = 2

# %%
# задаём начальную температуру испытаний (для каждого образца)

if furnace3 == '':
    # начальная температура для 1 образца
    t1 = int(weather_table.iloc[2][1])

    # начальная температура для 2 образца
    t2 = int(weather_table.iloc[2][2])
    
    # начальная температура для 3 образца
    t3 = 0

    # начальная температура для 4 образца
    t4 = 0
else:
    # начальная температура для 1 образца
    t1 = int(weather_table.iloc[3][1])

    # начальная температура для 2 образца
    t2 = int(weather_table.iloc[3][2])
    
    # начальная температура для 3 образца
    t3 = int(weather_table.iloc[3][3])

    # начальная температура для 4 образца
    t4 = int(weather_table.iloc[3][4])

# %%
# задаём процентное соотношение по X и Y для каждого сегмента графика

# металлические конструкции (и стекло)
segment1_m = (0.10, 0.02) # слипание ТП
segment2_m = (0.10, 0.05) # небольшой "расколбас"
segment3_m = (0.18, 0.35) # всплеск
segment4_m = (0.42, 0.13) # полочка
segment5_m = (0.00, 0.20) # прирост к концу испытания  

# деревянные конструкции
segment1_w = (0.20, 0.02) # слипание ТП
segment2_w = (0.20, 0.03) # небольшой "расколбас"
segment3_w = (0.20, 0.05) # прирост
segment4_w = (0.10, 0.05) # прирост
segment5_w = (0.00, 0.15) # прирост к концу испытания

# %%
# автоматический выбор шага по оси Х
if x_axis_pitch_user == 0:
    if fire_limit < 20:
        x_axis_pitch_user = 1
    elif fire_limit <= 60:
        x_axis_pitch_user = 5
    elif fire_limit <= 240:
        x_axis_pitch_user = 10 
else:
    x_axis_pitch_user = x_axis_pitch_user

# %% [markdown]
# #### Функция для построения печных графиков

# %%
# функция по созданию температурного графика печи 
def furnace_graph_func(): 

    # расчитаем данные на 240 возможных минут испытаний
    minutes = [i for i in range(0,(240 + 1))]


    # Tmean (Температура стандартного пожара)

    # формула для Tmean = 345 * LOG10(8 * минута_испытания + 1) + температура_окр._среды
    Tmean = [] # список значений Tmean
    for i in range(0,(240 + 1)):
        Tmean.append(345 * math.log10(8 * i + 1) + t0)


    # Tmax (Максимальный допуск температуры)

    # 0 - 10 мин - Формула Tmax = Tmean + 0.15 * Tmean
    Tmax_1_10 = [t0] # список Tmax за первые 10 минут
    for i in range(1, 11):
        Tmax_1_10.append(Tmean[i] + 0.15 * Tmean[i])    

    # 11 - 30 мин - Формула Tmax = Tmean + 0.1 * Tmean
    Tmax_11_30 = [] # список Tmax 11 - 30 минут
    for i in range(11, 31):
        Tmax_11_30.append(Tmean[i] + 0.1 * Tmean[i])    

    # 31 - до конца - Формула Tmax = Tmean + 0.05 * Tmean
    Tmax_31_240 = [] # список Tmax 31 - 240 минут
    for i in range(31, 241):
        Tmax_31_240.append(Tmean[i] + 0.05 * Tmean[i])

    # общий список значений Tmax
    Tmax = Tmax_1_10 + Tmax_11_30 + Tmax_31_240    


    # Tmin (Минимальный допуск температуры)

    # 0 - 10 мин - Формула Tmin = Tmean - 0.15 * Tmean
    Tmin_1_10 = [t0] # список Tmin за первые 10 минут
    for i in range(1, 11):
        Tmin_1_10.append(Tmean[i] - 0.15 * Tmean[i])    

    # 11 - 30 мин - Формула Tmin = Tmean - 0.1 * Tmean
    Tmin_11_30 = [] # список Tmin 11 - 30 минут
    for i in range(11, 31):
        Tmin_11_30.append(Tmean[i] - 0.1 * Tmean[i])    

    # 31 - до конца - Формула Tmin = Tmean - 0.05 * Tmean
    Tmin_31_240 = [] # список Tmin 31 - 240 минут
    for i in range(31, 241):
        Tmin_31_240.append(Tmean[i] - 0.05 * Tmean[i])    

    # общий список значений Tmin
    Tmin = Tmin_1_10 + Tmin_11_30 + Tmin_31_240 


    # Тchart (Среднее значение измеренной температуры в печи)

    # 0 - 10 мин - Формула Тchart =random((Tmean[i]-25), (Tmean[i]+25))
    Тchart_1_10 = [t0] # список Тchart за первые 10 минут
    for i in range(1, 11):
        Тchart_1_10.append(random.uniform((Tmean[i]-25), (Tmean[i]+25)))

    # 11 - 30 мин - Формула Тchart =random((Tmean[i]-10), (Tmean[i]+10))
    Тchart_11_30 = [] # список Тchart 11 - 30 минут
    for i in range(11, 31):
        Тchart_11_30.append(random.uniform((Tmean[i]-10), (Tmean[i]+10)))    

    # 31 - 240 мин - Формула Тchart =random((Tmean[i]-2), (Tmean[i]+2))
    Тchart_31_241 = [] # список Тchart 31 - 240 минут
    for i in range(31, 241):
        Тchart_31_241.append(random.uniform((Tmean[i]-2), (Tmean[i]+2)))    

    # общий список значений Тchart
    Тchart = Тchart_1_10 + Тchart_11_30 + Тchart_31_241


    # Данные для построения температурного графика печи

    # создаём общий массив данных
    furnace_chart = pd.DataFrame({'minutes': minutes, 
                                  'Tmean': Tmean, 
                                  'Tmax': Tmax, 
                                  'Tmin': Tmin, 
                                  'Тchart': Тchart})

    # отбираем нужное количество строк, равное времени проведения испытания
    furnace_chart = furnace_chart.head(fire_limit+1)


    # функция по корректировке входных данных для построения сглаженных линий. на вход спсиок значений по х и y
    def spline_func(x,y):
        # определим x как 200 значений с равным интервалом между минимальным и максимальным значениями исходного x 
        xnew = np.linspace (x. min (), x. max (), 200 ) 

        #определим сплайн
        spl = make_interp_spline (x, y, k=3)
        y_smooth = spl (xnew)

        # на выходе - обновленные данные для построения сглаженных линий 
        return (xnew, y_smooth)


    # Tmax - задаём данные для построения линии на графике
    x_Tmax, y_Tmax = furnace_chart['minutes'], furnace_chart['Tmax']    
    # функция по корректировке входных данных для построения сглаженных линий. на вход спсиок значений по х и y    
    x_Tmax, y_Tmax = spline_func(x_Tmax, y_Tmax)

    # Tmin - задаём данные для построения линии на графике
    x_Tmin, y_Tmin = furnace_chart['minutes'], furnace_chart['Tmin']
    # функция по корректировке входных данных для построения сглаженных линий. на вход спсиок значений по х и y    
    x_Tmin, y_Tmin = spline_func(x_Tmin, y_Tmin)

    # Tmean - задаём данные для построения линии на графике
    x_Tmean, y_Tmean = furnace_chart['minutes'], furnace_chart['Tmean']
    # функция по корректировке входных данных для построения сглаженных линий. на вход спсиок значений по х и y    
    x_Tmean, y_Tmean = spline_func(x_Tmean, y_Tmean)

    # Тchart - задаём данные для построения линии на графике
    x_Тchart, y_Тchart = furnace_chart['minutes'], furnace_chart['Тchart']
    # функция по корректировке входных данных для построения сглаженных линий. на вход спсиок значений по х и y    
    x_Тchart, y_Тchart = spline_func(x_Тchart, y_Тchart)


    # строим график
    
    # размер графика 
    fig, ax = plt.subplots(figsize=(7.9, 4.6))

    # значения по осям x и y 'от' и 'до'
    ax.axis([0,fire_limit, 0,1200])

    # размер шрифта значений на осях
    ax.tick_params(labelsize=8)

    # цвет значений по оси y
    ax.tick_params(axis='y', colors='red')

    # устанавливаем интервал основных делений по х:
    ax.xaxis.set_major_locator(ticker.MultipleLocator(x_axis_pitch_user))

    # устанавливаем интервал основных делений по y:
    ax.yaxis.set_major_locator(ticker.MultipleLocator(50))

    # частота маркеров
    k_markevery = (2, 8)

    # линия - Tmax
    ax.plot(x_Tmax, y_Tmax, 
            label='Максимальный допуск температуры', 
            color='r',
            marker='o',
            markevery=k_markevery, 
            ms=4,
            mec='r',
            mfc='w')

    # линия - Tmin
    ax.plot(x_Tmin, y_Tmin, 
            label='Минимальный допуск температуры', color='b',
            marker='x',
            markevery=k_markevery,
            ms=4,
            mec='b',
            mfc=None)

    # линия - Tmean
    ax.plot(x_Tmean, y_Tmean, 
            label='Температура стандартного пожара', 
            color='black', 
            linestyle='--', 
            linewidth=0.7)

    # линия - Тchart
    ax.plot(x_Тchart, y_Тchart, 
            label='Среднее значение измеренной температуры в печи', 
            color='black')

    # подпись оси х
    plt.xlabel('Время, мин', horizontalalignment='right', x=1.0, size=8)
    # подпись оси y
    plt.ylabel('Температура, °C', horizontalalignment='right', y=1.0, size=8)

    # легенда
    plt.legend(bbox_to_anchor=(0.5,-0.25), loc='lower center', frameon = False, prop={'size': 6}, handlelength=4)

    # добавляем линии основной сетки
    ax.grid()    
    
    # рамка для всего графика
    fig.patch.set_linewidth(1) # толщина
    fig.patch.set_edgecolor('black') # цвет    
    plt.tight_layout()    
    
    # сохраняем график
    plt.savefig(charts_path+'/saved_figure.png', bbox_inches='tight', edgecolor=fig.get_edgecolor())    
    
    # выводим график
    plt.show()

# %% [markdown]
# #### Функция для построения прочих графиков

# %%
# функция для построения графиков (тип графика, кол-во ТП, ТП на стекле) 
def graph_func(g, m, glass):
    
    # присваиваем "рабочей" переменной заданное пользователем значение материала конструкции
    construction_material = construction_material_val
    
    # тип графика
    g = int(g)
   
    # термопары
    thermocouple = m
    
    # ТП на стекле
    glass = glass    

    # список номеров всех ТП
    stringexample = thermocouple
    substring = ['-', ','] 

    if substring[0] in stringexample:
        # если несколько ТП разделены '-'
        thermocouple_num = list(range((int(thermocouple.split('-')[0])), (int(thermocouple.split('-')[1])+1)))

    elif substring[1] in stringexample:
        # если несколько ТП разделены ','
        thermocouple_num = list(map(int, thermocouple.split(',')))    

    else:
        # если одна ТП 
        thermocouple_num = [int(thermocouple)]

    # количество термопар на графике
    n_t = len(thermocouple_num)    

    # список номеров ТП на стекле
    stringexample = glass
    substring = ['-', ',']

    if substring[0] in stringexample:
        # если несколько ТП разделены '-'
        glass_num = list(range((int(glass.split('-')[0])), (int(glass.split('-')[1])+1)))    

    elif substring[1] in stringexample:
        # если несколько ТП разделены ','
        glass_num = list(map(int, glass.split(',')))

    else:
        # если одна ТП
        glass_num = [int(glass)]

    # количество термопар на графике
    n_g = len(glass_num)         
        
    # функция по расчёту температурных значений
    def values_graph_func():
        # задаём процентное соотношение по X и Y для каждого сегмента графика (для стекла берём значения как у металла)   
        if construction_material == 'м' or construction_material == 'с':
            segment1 = (segment1_m)
            segment2 = (segment2_m)
            segment3 = (segment3_m)
            segment4 = (segment4_m)
            segment5 = (segment5_m)  
        elif construction_material == 'д':
            segment1 = (segment1_w)
            segment2 = (segment2_w)
            segment3 = (segment3_w)
            segment4 = (segment4_w)
            segment5 = (segment5_w)  
        elif construction_material == 'п':
            segment1 = (segment1_user) 
            segment2 = (segment2_user) 
            segment3 = (segment3_user) 
            segment4 = (segment4_user) 
            segment5 = (segment5_user)
        
        # список сегментов
        segments = [segment1, segment2, segment3, segment4, segment5]

        # задаём каждому сегменту его % от времени проведения испытаний
        seg_x = [math.ceil(segment[0]*fire_limit) for segment in segments]
        
        # задаём каждому сегменту его % от предельного значения по температуре
        
        # для металлических конструкций (для стекла берём значения как у металла) 
        if construction_material == 'м' or construction_material == 'с' or construction_material == 'п':
            if g == 1:
                seg_y = [math.ceil(segment[1]*(t0+140-25)) for segment in segments]        
            elif g == 2:
                seg_y = [math.ceil(segment[1]*(t0+180-25)) for segment in segments]
            elif g == 3 or g == 4:
                seg_y = [math.ceil(segment[1]*(300-35)) for segment in segments]        
            else:
                pass
            
        # для деревянных конструкций        
        elif construction_material == 'д':            
            if g == 1:    
                seg_y = [math.ceil(segment[1]*90) for segment in segments]
            elif g == 2:
                seg_y = [math.ceil(segment[1]*90) for segment in segments]
            elif g == 3 or g == 4:
                seg_y = [math.ceil(segment[1]*100) for segment in segments]        
            else:
                pass
        else:
            pass
                
        # коэффициент для небольшого разброса линий графика
        
        # для деревянных конструкций        
        if construction_material == 'д':
            k = random.uniform(0.8, 3)         
        # для металлических конструкций (для стекла берём значения как у металла)
        else:
            k = random.uniform(0.8, 1.4)

        # 1 сегмент
        temp1 = sorted([random.uniform(t0, t0+seg_y[0]) 
                        for _ in range(1, seg_x[0])])
        # 2 сегмент
        temp2 = sorted([random.uniform(temp1[-1], t0+seg_y[0]+seg_y[1] * k) 
                        for _ in range(seg_x[0], seg_x[0]+seg_x[1])])
        # 3 сегмент
        temp3 = sorted([random.uniform(temp2[-1], t0+seg_y[0]+seg_y[1]+seg_y[2] * k) 
                        for _ in range(seg_x[0]+seg_x[1], seg_x[0]+seg_x[1]+seg_x[2])])
        # 4 сегмент
        temp4 = sorted([random.uniform(temp3[-1], t0+seg_y[0]+seg_y[1]+seg_y[2]+seg_y[3] * k) 
                        for _ in range(seg_x[0]+seg_x[1]+seg_x[2], seg_x[0]+seg_x[1]+seg_x[2]+seg_x[3])])
        # 5 сегмент
        temp5 = sorted([random.uniform(temp4[-1], t0+seg_y[0]+seg_y[1]+seg_y[2]+seg_y[3]+seg_y[4] * k) 
                        for _ in range(seg_x[0]+seg_x[1]+seg_x[2]+seg_x[3], fire_limit+1+5)])

        #  массив температурных значений (без начальной температуры)
        temp = temp1 + temp2 + temp3 + temp4 + temp5
        return temp 
    
    # температурные значения для 5 термпопар 
    # temp_thermocouple - список температурных значений для каждой термопары ДО сглаживания
    # t - список температурных значений для каждой термопары ПОСЛЕ сглаживания

    # коэф для uniform_filter1d
    k_size = 6

    # ТП 1
    if n_t >= 1:
        if thermocouple_num[0] in glass_num:
            construction_material = 'с'
        else: 
            construction_material = construction_material_val
    else:
        pass
    
    # применяем функцию по расчёту температурных значений
    temp_thermocouple1 = values_graph_func()
    # получение сглаженных температурных значений для графика
    t1 = [t0] + uniform_filter1d(temp_thermocouple1,k_size).tolist()

    # ТП 2
    if n_t >= 2:
        if thermocouple_num[1] in glass_num:
            construction_material = 'с'
        else:
            construction_material = construction_material_val
    else:
        pass

    # применяем функцию по расчёту температурных значений
    temp_thermocouple2 = values_graph_func()
    # получение сглаженных температурных значений для графика
    t2 = [t0] + uniform_filter1d(temp_thermocouple2,k_size).tolist()

    # ТП 3
    if n_t >= 3:
        if thermocouple_num[2] in glass_num:
            construction_material = 'с'
        else:
            construction_material = construction_material_val
    else:
        pass

    # применяем функцию по расчёту температурных значений
    temp_thermocouple3 = values_graph_func()
    # получение сглаженных температурных значений для графика
    t3 = [t0] + uniform_filter1d(temp_thermocouple3,k_size).tolist()

    # ТП 4
    if n_t >= 4:
        if thermocouple_num[3] in glass_num:
            construction_material = 'с'
        else:
            construction_material = construction_material_val
    else:
        pass

    # применяем функцию по расчёту температурных значений
    temp_thermocouple4 = values_graph_func()
    # получение сглаженных температурных значений для графика
    t4 = [t0] + uniform_filter1d(temp_thermocouple4,k_size).tolist()

    # ТП 5
    if n_t >= 5:
        if thermocouple_num[4] in glass_num:
            construction_material = 'с'
        else:
            construction_material = construction_material_val
    else:
        pass

    # применяем функцию по расчёту температурных значений
    temp_thermocouple5 = values_graph_func()
    # получение сглаженных температурных значений для графика
    t5 = [t0] + uniform_filter1d(temp_thermocouple5,k_size).tolist()
    
    # среднее значение температуры
    if n_t == 1:
        t_mean = list(map(lambda x: sum(x) / len(x), zip(temp_thermocouple1)))
    elif n_t == 2:
        t_mean = list(map(lambda x: sum(x) / len(x), zip(temp_thermocouple1, temp_thermocouple2)))
    elif n_t == 3:
        t_mean = list(map(lambda x: sum(x) / len(x), zip(temp_thermocouple1, temp_thermocouple2, 
                                                         temp_thermocouple3)))
    elif n_t == 4:
        t_mean = list(map(lambda x: sum(x) / len(x), zip(temp_thermocouple1, temp_thermocouple2, 
                                                         temp_thermocouple3, temp_thermocouple4)))
    elif n_t >= 5:
        t_mean = list(map(lambda x: sum(x) / len(x), zip(temp_thermocouple1, temp_thermocouple2, 
                                                         temp_thermocouple3, temp_thermocouple4, 
                                                         temp_thermocouple5)))
    else:
        pass

    # сглаживание температурных значений для графика
    t_mean = [t0] + uniform_filter1d(t_mean,k_size).tolist()
    
    # спсиок минут
    minutes = list(range(0, fire_limit+1+5))

    
    # строим график

    # размер графика 
    fig, ax = plt.subplots(figsize=(7.9, 4.6))

    if g == 1 or g == 2:    
        # значения по осям x и y 'от' и 'до'
        ax.axis([0,fire_limit, 0,220])
    elif g == 3:    
        # значения по осям x и y 'от' и 'до'
        ax.axis([0,fire_limit, 0,310])
    elif g == 4:    
        # значения по осям x и y 'от' и 'до'
        ax.axis([0,fire_limit, 0,3600])

    # размер шрифта значений на осях
    ax.tick_params(labelsize=8)

    # цвет значений по оси y
    ax.tick_params(axis='y', colors='red')

    if g == 1 or g == 2:    
        # устанавливаем интервал основных делений по х:
        ax.xaxis.set_major_locator(ticker.MultipleLocator(x_axis_pitch_user))
        # устанавливаем интервал основных делений по y:
        ax.yaxis.set_major_locator(ticker.MultipleLocator(10))
    elif g == 3:    
        # устанавливаем интервал основных делений по х:
        ax.xaxis.set_major_locator(ticker.MultipleLocator(x_axis_pitch_user))
        # устанавливаем интервал основных делений по y:
        ax.yaxis.set_major_locator(ticker.MultipleLocator(20))
    elif g == 4:    
        # устанавливаем интервал основных делений по х:
        ax.xaxis.set_major_locator(ticker.MultipleLocator(x_axis_pitch_user))
        # устанавливаем интервал основных делений по y:
        ax.yaxis.set_major_locator(ticker.MultipleLocator(200))

    # подпись оси х
    plt.xlabel('Время, мин', horizontalalignment='right', x=1.0, size=8)
    
    # подпись оси y
    if g != 4:
        plt.ylabel('Температура, °C', horizontalalignment='right', y=1.0, size=8)
    else:
        plt.ylabel('Тепловой поток, Вт/м\u00B2', horizontalalignment='right', y=1.0, size=8)

    # добавляем линии основной сетки
    ax.grid()

    # коэф для частоты маркеров
    k_markevery = math.ceil(fire_limit/24)

    # исключение для наименования первой термопары, в зависимости от типа графика
    if g != 4:
        label_t1 = f'Термопара {thermocouple_num[0]}'
        t1 = t1
    elif g == 4:
        label_t1 = 'Приёмник теплового потока 1'        
        t1 = uniform_filter1d(sorted([random.uniform(t0, random.uniform(500, 800)) 
                                      for _ in range(0, fire_limit+1+5)]), k_size).tolist()

    # добавим кривые на график
    if n_t >= 1:
        # ТП 1
        t1 = ax.plot(minutes, t1,        # оси "x", "y" 
                         label=label_t1, # подпись линии 
                         linestyle='-',  # стиль линии
                         color='k',      # цвет линии
                         linewidth=0.7,  # толщина линии
                         marker=None,    # тип маркера
                         markevery=None, # частота маркеров
                         ms=None,        # размер маркера
                         mec=None,       # граница маркера
                         mfc=None)       # заливка маркера
    if n_t >= 2:
        # ТП 2
        t2 = ax.plot(minutes, t2, 
                         label=f'Термопара {thermocouple_num[1]}', 
                         linestyle='-.', 
                         color='#ff00ff', 
                         linewidth=0.7, 
                         marker=None, 
                         markevery=None, 
                         ms=None, 
                         mec=None,             
                         mfc=None)
    if n_t >= 3:
        # ТП 3
        t3 = ax.plot(minutes, t3, 
                         label=f'Термопара {thermocouple_num[2]}', 
                         linestyle='-',  
                         color='b',    
                         linewidth=1, 
                         marker='x',  
                         markevery=k_markevery,    
                         ms=3,    
                         mec='k',  
                         mfc=None)
    if n_t >= 4:
        # ТП 4
        t4 = ax.plot(minutes, t4, 
                         label=f'Термопара {thermocouple_num[3]}', 
                         linestyle='--', 
                         color='k',    
                         linewidth=0.9, 
                         marker=None, 
                         markevery=None, 
                         ms=None, 
                         mec=None, 
                         mfc=None)
    if n_t >= 5:
        # ТП 5
        t5 = ax.plot(minutes, t5, 
                         label=f'Термопара {thermocouple_num[4]}', 
                         linestyle='-',  
                         color='r',    
                         linewidth=1, 
                         marker='o',  
                         markevery=k_markevery,    
                         ms=1,    
                         mec='k',  
                         mfc='k')
    if g == 1:
        # среднее значение температуры
        t_mean = ax.plot(minutes, t_mean,                 
                         label='Среднее значение температуры', 
                         linestyle=':',  
                         color='k',    
                         linewidth=0.7, 
                         marker=None,  
                         markevery=None,    
                         ms=None,    
                         mec=None,  
                         mfc=None)

    # добавим горизонтальные линии на график
    if g == 1:
        # 1 линия - Предельное значение (по средней) - t0+140
        line1 = ax.axhline(y=t0 + 140, 
                           label='Предельное значение температуры (по средней)', 
                           linestyle='--',            
                           color='red', 
                           linewidth=1.6)
    if g == 1 or g == 2:
        # 2 линия - Предельное значение (по любой термопаре) - t0+180
        line2 = ax.axhline(y=t0 + 180,
                           label='Предельное значение температуры (по любой термопаре)', 
                           linestyle='-',
                           color='red',
                           linewidth=3,
                           alpha=0.3)
    elif g == 3: 
        # 3 линия - Предельное значение - 300
        line3 = ax.axhline(y=300,
                           label='Предельное значение температуры', 
                           linestyle='-',
                           color='red',
                           linewidth=3,
                           alpha=0.3)        
    if g == 4:
        # 4 линия - Предельное значение теплового потока (по среднему значению) - 3500
        line1 = ax.axhline(y=3500, 
                           label='Предельное значение теплового потока (по среднему значению)', 
                           linestyle='-',
                           color='red',
                           linewidth=3,
                           alpha=0.3)
    
    # легенда
    ax.legend(loc='lower center',          # "угол" расположения легенды
              bbox_to_anchor=(0.0, -0.25,  # поправка к расположению легенды (1 колонка)
                              1.0, -0.25), # поправка к расположению легенды (2 колонка)
              ncol=2,                      # количество колонок легенды
              mode="expand",               # легенда на всю ширину графика
              borderaxespad=0.0,           # зазор между осями и легендой           
              frameon = False,             # рамка легенды
              prop={'size': 6},            # размер шрифта легенды
              handlelength=4)              # длина схематичного изображения "линии" на легенде
    
    # рамка для всего графика
    fig.patch.set_linewidth(1) # толщина
    fig.patch.set_edgecolor('black') # цвет    
    plt.tight_layout()
    
    # сохраняем график
    plt.savefig(charts_path+'/saved_figure.png', bbox_inches='tight', edgecolor=fig.get_edgecolor())    
    
    # выводим график
    plt.show()

# %%
# прописываем путь для сохранения файла с графиками
charts_path = rf'{charts_path}'.replace('\\', '/')

# %% [markdown]
# #### Функция по добавлению графиков в Word

# %%
# функция по добавлению графика в word
def add_chart_func(chart_name):
    
    # добавляем пустой абзац
    p = template.add_paragraph()
    # добавляем пустой прогон
    run = p.add_run()
    # теперь в прогон вставляем график
    run.add_picture(charts_path+'/saved_figure.png', width=Cm(16), height=Cm(10.5))
    # выравниваем картинку посередине страницы
    p.alignment =  WD_ALIGN_PARAGRAPH.CENTER
    
    # добавим подпись к графику
    chart_signature = template.add_paragraph(f'Рисунок {drawing_num}. {chart_name}')
    # выравниваем текст по середине
    chart_signature.alignment = WD_ALIGN_PARAGRAPH.CENTER
    
    # добавляем пустой абзац после графика
    p = template.add_paragraph()

# %% [markdown]
# #### Строим графики

# %%
# 1 печной график
if furnace_total > 1:
    t0 = t1 # задаём температуру окр. среды (начальная температура испытаний) для 1 образца
    furnace_graph_func() # строим печной график  
    add_chart_func('Измерение температуры в печи.'+' Образец №1.') # добавляем график Word
    drawing_num += 1 # дальнейшая нумерация рисунков    
    
elif furnace_total == 1:     
    t0 = t1 # задаём температуру окр. среды (начальная температура испытаний) для 1 образца
    furnace_graph_func() # строим печной график  
    add_chart_func('Измерение температуры в печи.'+' Образцы №№1, 2.') # добавляем график Word
    drawing_num += 1 # дальнейшая нумерация рисунков
else:
    pass    
    
# 2 печной график
if furnace_total >= 2: 
    t0 = t2 # задаём температуру окр. среды (начальная температура испытаний) для 2 образца
    furnace_graph_func() # строим печной график  
    add_chart_func('Измерение температуры в печи.'+' Образец №2.') # добавляем график Word
    drawing_num += 1 # дальнейшая нумерация рисунков
else:
    pass    
    
# 3 печной график
if furnace_total >= 3: 
    t0 = t3 # задаём температуру окр. среды (начальная температура испытаний) для 3 образца
    furnace_graph_func() # строим печной график  
    add_chart_func('Измерение температуры в печи.'+' Образец №3.') # добавляем график Word
    drawing_num += 1 # дальнейшая нумерация рисунков
else:
    pass        
    
# 4 печной график
if furnace_total >= 4: 
    t0 = t4 # задаём температуру окр. среды (начальная температура испытаний) для 4 образца
    furnace_graph_func() # строим печной график  
    add_chart_func('Измерение температуры в печи.'+' Образец №4.') # добавляем график Word
    drawing_num += 1 # дальнейшая нумерация рисунков
else:
    pass

# %%
if test_type != 'S':

    # 1 образец

    t0 = t1

    # применяем функцию для построения графиков и добавления их в Word, если указан тип графиков
    # g - тип графика (1, 2, 3)
    # n - количество термопар (1-5, 6-10, 11-15)
    if graph_1[0] != '0':
        graph_func(graph_1[0], graph_1[1], graph_1[2])
        add_chart_func(graph_1[3]+' Образец №1.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_2[0] != '0':
        graph_func(graph_2[0], graph_2[1], graph_2[2])
        add_chart_func(graph_2[3]+' Образец №1.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_3[0] != '0':
        graph_func(graph_3[0], graph_3[1], graph_3[2])
        add_chart_func(graph_3[3]+' Образец №1.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_4[0] != '0':
        graph_func(graph_4[0], graph_4[1], graph_4[2])
        add_chart_func(graph_4[3]+' Образец №1.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_5[0] != '0':
        graph_func(graph_5[0], graph_5[1], graph_5[2])
        add_chart_func(graph_5[3]+' Образец №1.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_6[0] != '0':
        graph_func(graph_6[0], graph_6[1], graph_6[2])
        add_chart_func(graph_6[3]+' Образец №1.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_7[0] != '0':
        graph_func(graph_7[0], graph_7[1], graph_7[2])
        add_chart_func(graph_7[3]+' Образец №1.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_8[0] != '0':
        graph_func(graph_8[0], graph_8[1], graph_8[2])
        add_chart_func(graph_8[3]+' Образец №1.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_9[0] != '0':
        graph_func(graph_9[0], graph_9[1], graph_9[2])
        add_chart_func(graph_9[3]+' Образец №1.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_10[0] != '0':
        graph_func(graph_10[0], graph_10[1], graph_10[2])
        add_chart_func(graph_10[3]+' Образец №1.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

# %%
if test_type != 'S':

    # 2 образец

    t0 = t2

    # применяем функцию для построения графиков, если указан тип графиков 
    # g - тип графика (1, 2, 3)
    # n - количество термопар (1-5, 6-10, 11-15)
    if graph_1[0] != '0':
        graph_func(graph_1[0], graph_1[1], graph_1[2])
        add_chart_func(graph_1[3]+' Образец №2.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_2[0] != '0':
        graph_func(graph_2[0], graph_2[1], graph_2[2])
        add_chart_func(graph_2[3]+' Образец №2.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_3[0] != '0':
        graph_func(graph_3[0], graph_3[1], graph_3[2])
        add_chart_func(graph_3[3]+' Образец №2.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_4[0] != '0':
        graph_func(graph_4[0], graph_4[1], graph_4[2])
        add_chart_func(graph_4[3]+' Образец №2.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_5[0] != '0':
        graph_func(graph_5[0], graph_5[1], graph_5[2])
        add_chart_func(graph_5[3]+' Образец №2.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_6[0] != '0':
        graph_func(graph_6[0], graph_6[1], graph_6[2])
        add_chart_func(graph_6[3]+' Образец №2.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_7[0] != '0':
        graph_func(graph_7[0], graph_7[1], graph_7[2])
        add_chart_func(graph_7[3]+' Образец №2.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_8[0] != '0':
        graph_func(graph_8[0], graph_8[1], graph_8[2])
        add_chart_func(graph_8[3]+' Образец №2.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_9[0] != '0':
        graph_func(graph_9[0], graph_9[1], graph_9[2])
        add_chart_func(graph_9[3]+' Образец №2.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

    if graph_10[0] != '0':
        graph_func(graph_10[0], graph_10[1], graph_10[2])
        add_chart_func(graph_10[3]+' Образец №2.')
        drawing_num += 1 # дальнейшая нумерация рисунков
    else:
        pass

# %%
# удалим последний сохранённый график из папки, в которую временно сохраняются графики
if os.path.isfile(charts_path+'/saved_figure.png'): 
    os.remove(charts_path+'/saved_figure.png') 
else:
    pass

# %% [markdown]
# ### Таблица - дымогазопроницаемость

# %% [markdown]
# #### Функция

# %%
# исправить в Pandas: SettingWithCopyWarning
pd.options.mode.chained_assignment = None

# функция по составлению таблицы дымогазопроницаемости - smoke and gas permeability table - sagpt
def sagpt_func():
    # поправка для шага в 2 минуты 
    if fire_limit % 2 == 1:
        fire_limit_t = fire_limit + 1
    else:
        fire_limit_t = fire_limit

    # необходимор выделить габариты из sample_characteristics
    overall_dimensions = re.findall(r'\d+', sample_characteristics)[:2]    
    
    # площадь конструкции
    construction_area = int(overall_dimensions[0]) * 0.001 * int(overall_dimensions[1]) * 0.001    

    # переводим из мм в метры и получаем начальное значение F2 / (τ/2)
    F = (int(overall_dimensions[0]) * 0.001 * int(overall_dimensions[1]) * 0.001)**2

    # формула для получения случайного значения "Разность давлений на образце ΔР, Па"
    P = round((70-4) + (random.randrange(1, 8, 1)) + (random.uniform(0, 1)) - 0.5,1)

    # начальное значение коэф. КЭФ
    K = 99
     
    # задаём расход в зависимости от площади
    if 0.6 < construction_area <= 0.9:
        Q = 30 + (random.randint(-1, 2))
    elif 0.9 < construction_area <= 1.2:
        Q = 42 + (random.randint(-1, 2))
    elif 1.2 < construction_area <= 1.5:
        Q = 55 + (random.randint(-1, 2)) 
    elif 1.5 < construction_area <= 1.8:
        Q = 66 + (random.randint(-1, 2)) 
    elif 1.8 < construction_area <= 2.1:
        Q = 80 + (random.randint(-1, 2)) 
    elif 2.1 < construction_area <= 2.4:
        Q = 99 + (random.randint(-1, 2)) 
    elif 2.4 < construction_area <= 2.7:
        Q = 115 + (random.randint(-1, 2)) 
    elif 2.7 < construction_area <= 3.0:
        Q = 126 + (random.randint(-1, 2)) 
    elif 3.0 < construction_area <= 3.3:
        Q = 138 + (random.randint(-1, 2)) 
    elif 3.3 < construction_area <= 3.6:
        Q = 155 + (random.randint(-1, 2)) 
    elif 3.6 < construction_area <= 3.9:
        Q = 170 + (random.randint(-1, 2)) 
    elif 3.9 < construction_area <= 4.2:
        Q = 187 + (random.randint(-1, 2)) 
    elif 4.2 < construction_area <= 4.5:
        Q = 198 + (random.randint(-1, 2)) 
    elif 4.5 < construction_area <= 4.8:
        Q = 209 + (random.randint(-1, 2)) 
    elif 4.8 < construction_area <= 5.1:
        Q = 222 + (random.randint(-1, 2)) 
    elif 5.1 < construction_area <= 5.4:
        Q = 233 + (random.randint(-1, 2)) 
    elif 5.4 < construction_area <= 5.7:
        Q = 244 + (random.randint(-1, 2))  
    elif 5.7 < construction_area <= 6.0:
        Q = 255 + (random.randint(-1, 2))  
    elif 6.0 < construction_area <= 6.3:
        Q = 265 + (random.randint(-1, 2))  
    elif 6.3 < construction_area <= 6.6:
        Q = 280 + (random.randint(-1, 2)) 
    elif 6.6 < construction_area:
        Q = 292 + (random.randint(-1, 2))       
    else:
        pass

    # начальное значение Q
    Q = Q + (random.uniform(0, 1)) * (fire_limit_t / 100 * 10)

        
    # начальное значение Gкл
    G = Q / 3600 * 1.2

    # начальное значение P/G
    P_G = P / G**2

    # начальное значение суммы 'sum'
    sum = P_G

    # начальное значение "Приведённое удельное сопротивление дымогазопроницанию Sуд, м3/кг"
    S = sum * F

    # создаём датафрейм с первой строкой таблицы
    data = {'Время τ, мин': [0],
            'Разность давлений на образце ΔР, Па': P,
            'Q, м\u00B3/ч': Q,
            'Gкл i, кг/с': G,
            'Приведённое удельное сопротивление дымогазопроницанию Sуд, м\u00B3/кг': S,
            'КЭФ': 99,
            'F\u00B2/(τ/2)': F,
            'P_G': P_G,
            'sum': sum
           } 
    df = pd.DataFrame(data)
    

    # список минут с шагом в 2 минуты, начиная со второй минуты испытания
    minutes_list = [i for i in range(2,(fire_limit_t + 1), 2)]

    # список F2 / (τ/2), начиная со второй минуты испытания
    F_list = []
    for i in range(len(minutes_list)):
        F_list.append(((int(overall_dimensions[0]) * 0.001 * int(overall_dimensions[1]) * 0.001)**2) / (minutes_list[i] / 2))

    # список ΔР, начиная со второй минуты испытания
    P_list = []
    for i in range(len(minutes_list)):
        P_list.append(round((70-4) + (random.randrange(1, 8, 1)) + (random.uniform(0, 1)) - 0.5,1))

    # список коэф. КЭФ, начиная со второй минуты испытания
    K_list = []
    for i in minutes_list:
        if i <= 24:
            K_list.append(99)
        elif i == 26:
            K_list.append(100)
        else:
            K_list.append(100.5)

    # список Q, м3/ч, начиная со второй минуты испытания
    Q_list = []
    for i in range(len(minutes_list)):
        Q = Q * K_list[i] / 100 + random.uniform(0, 1) / 2 + 0.2
        if Q < 100:
            Q = round(Q,1)
        else:
            Q = round(Q)
        Q_list.append(Q)

    # список G, начиная со второй минуты испытания
    G_list = []
    for i in range(len(minutes_list)):
        G_list.append(round((Q_list[i] / 3600 * 1.2), 5))

    # список P_G, начиная со второй минуты испытания
    P_G_list = []
    for i in range(len(minutes_list)):
        P_G_list.append(P_list[i] / G_list[i]**2)    

    # список sum, начиная со второй минуты испытания
    sum_list = []
    for i in range(len(minutes_list)):
        sum = sum + P_G_list[i]
        sum_list.append(sum)    

    # список Sуд, начиная со второй минуты испытания
    S_list = []
    for i in range(len(minutes_list)):
        S_list.append(round(sum_list[i] * F_list[i]))


    # создаём общий массив данных
    for i in range(len(minutes_list)):
        df.loc[len(df)] = [minutes_list[i], 
                           P_list[i], 
                           Q_list[i], 
                           G_list[i], 
                           S_list[i], 
                           K_list[i], 
                           F_list[i], 
                           P_G_list[i], 
                           sum_list[i]]


    # оставляем только необходимые столбцы

    df = df[['Время τ, мин',
             'Разность давлений на образце ΔР, Па',
            'Q, м³/ч',
            'Gкл i, кг/с',
            'Приведённое удельное сопротивление дымогазопроницанию Sуд, м³/кг']]


    # приводим столбцы к нужному виду
    df['Время τ, мин'] = df['Время τ, мин'].astype(int)

    df['Q, м³/ч'] = np.round(df['Q, м³/ч'], 1).astype(str)

    for i in range(len(df)):
        if float(df['Q, м³/ч'][i]) >= 100.0:
            df = df.replace(df['Q, м³/ч'][i], 
                            df['Q, м³/ч'][i].split('.')[0])
        else:
            pass

    for i in range(len(df)):
        df['Gкл i, кг/с'][i] = "%.5f" % df['Gкл i, кг/с'][i]     

    df['Приведённое удельное сопротивление дымогазопроницанию Sуд, м³/кг'] = \
    df['Приведённое удельное сопротивление дымогазопроницанию Sуд, м³/кг'].astype(int)
    
    
    # получаем значение 'Приведённое удельное сопротивление дымогазопроницанию Sуд, м³/кг'
    x = df['Приведённое удельное сопротивление дымогазопроницанию Sуд, м³/кг'][len(df)-1]
    
    
    # убераем лишние значения в 'Приведённое удельное сопротивление дымогазопроницанию Sуд, м³/кг'
    for i in range(len(df)-1):
        df = df.replace(df['Приведённое удельное сопротивление дымогазопроницанию Sуд, м³/кг'][i], '') 
        
    # переносим заголовок датафрейма в первую строку
    df = pd.concat([pd.DataFrame([df.columns.values], columns=df.columns), df], ignore_index=True)
    
    # меняем заголовок датафрейма
    df.columns = ['', '', 'Расход газов через образец', '', '']    

    return df, x

# %% [markdown]
# #### Построение таблиц

# %%
# тип испытания, при котором необходима таблица дымогазопроницаемости (1 образец)
if test_type == 'S' and serial_number_1 != '':
    # 1 таблица
    sagpt_table1, sagpt_x1 = sagpt_func()
else:
    pass

# %%
# тип испытания, при котором необходима таблица дымогазопроницаемости (2 образец)
if test_type == 'S' and serial_number_2 != '':
    # 2 таблица
    sagpt_table2, sagpt_x2 = sagpt_func()
else:
    pass

# %%
# тип испытания, при котором необходима таблица дымогазопроницаемости (3 образец)
if test_type == 'S' and serial_number_3 != '':
    # 3 таблица
    sagpt_table3, sagpt_x3 = sagpt_func()
else:
    pass

# %%
# тип испытания, при котором необходима таблица дымогазопроницаемости (4 образец)
if test_type == 'S' and serial_number_4 != '':
    # 4 таблица
    sagpt_table4, sagpt_x4 = sagpt_func()
else:
    pass

# %% [markdown]
# #### Добавление таблиц в Word

# %%
# 1 образец
if test_type == 'S' and serial_number_1 != '':
    #добавим пустой перед таблицей
    p = template.add_paragraph()

    # добавим название таблицы
    # добавляем абзац с текстом
    p = template.add_paragraph(f'Таблица {table_num}. Результаты измерений при определении дымогазопроницаемости. Образец № 1.')
    # убираем интервал после текста
    p.paragraph_format.space_after = Pt(0)
    # добавляем отступ слева
    p.paragraph_format.left_indent = Cm(1.0)

    # добавляем переменную, которой передаём количество строк (shape[0]+1) и столбцов (shape[1]) таблицы
    table = template.add_table(sagpt_table1.shape[0]+1, sagpt_table1.shape[1], style='Table Grid')

    # выравниваем таблицу по центру страницы
    table.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # добавляем строку - заголовок
    for j in range(sagpt_table1.shape[-1]):
        table.cell(0,j).text = sagpt_table1.columns[j]

    # добавляем остальную часть данных
    for i in range(sagpt_table1.shape[0]):
        for j in range(sagpt_table1.shape[-1]):
            table.cell(i+1,j).text = str(sagpt_table1.values[i,j])        

    # зададим ширину столбцам
    def set_col_widths(table):
        widths = (Cm(2.37), Cm(3.27), Cm(2.72), Cm(2.68), Cm(5.84))
        for row in table.rows:
            for idx, width in enumerate(widths):
                row.cells[idx].width = width
    set_col_widths(table)

    # "сшиваем" ячейки в необходимых местах для формирования определённого вида таблицы
    a = table.cell(0, 0)
    b = table.cell(1, 0)
    A = a.merge(b)  

    a = table.cell(0, 1)
    b = table.cell(1, 1)
    A = a.merge(b)  

    a = table.cell(0, 2)
    b = table.cell(0, 3)
    A = a.merge(b)  

    a = table.cell(0, 4)
    b = table.cell(1, 4)
    A = a.merge(b)  

    c = table.cell(2, 4)
    d = table.cell(len(table.rows)-1, 4)
    B = c.merge(d) 

    # добавляем необходимый текст в нужную ячейку
    table.cell(0, 0).text = 'Время τ, мин'
    table.cell(0, 1).text = 'Разность давлений на образце ΔР, Па'
    table.cell(0, 3).text = 'Расход газов через образец'
    table.cell(0, 4).text = 'Приведённое удельное сопротивление дымогазопроницанию Sуд, м³/кг'
    table.cell(2, 4).text = f'{sagpt_x1}'

    # выравниваем текст в ячейках по центру
    for i in range(len(table.rows)):
        for j in range(len(table.columns)):
            cell = table.rows[i].cells[j]
            cell_paragraph = cell.paragraphs[0]
            cell_paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # выравниваем текст во всех колонках по центру
    for i in range(len(table.rows)):
        for j in range(len(table.columns)):
            cell = table.rows[i].cells[j]
            cell.vertical_alignment = WD_ALIGN_VERTICAL.CENTER  
            
    # продолжаем нумерацию таблиц
    table_num += 1

# %%
# 2 образец
if test_type == 'S' and serial_number_2 != '':
    #добавим пустой перед таблицей
    p = template.add_paragraph()

    # добавим название таблицы
    # добавляем абзац с текстом
    p = template.add_paragraph(f'Таблица {table_num}. Результаты измерений при определении дымогазопроницаемости. Образец № 2.')
    # убираем интервал после текста
    p.paragraph_format.space_after = Pt(0)
    # добавляем отступ слева
    p.paragraph_format.left_indent = Cm(1.0)

    # добавляем переменную, которой передаём количество строк (shape[0]+1) и столбцов (shape[1]) таблицы
    table = template.add_table(sagpt_table2.shape[0]+1, sagpt_table2.shape[1], style='Table Grid')

    # выравниваем таблицу по центру страницы
    table.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # добавляем строку - заголовок
    for j in range(sagpt_table2.shape[-1]):
        table.cell(0,j).text = sagpt_table2.columns[j]

    # добавляем остальную часть данных
    for i in range(sagpt_table2.shape[0]):
        for j in range(sagpt_table2.shape[-1]):
            table.cell(i+1,j).text = str(sagpt_table2.values[i,j])        

    # зададим ширину столбцам
    def set_col_widths(table):
        widths = (Cm(2.37), Cm(3.27), Cm(2.72), Cm(2.68), Cm(5.84))
        for row in table.rows:
            for idx, width in enumerate(widths):
                row.cells[idx].width = width
    set_col_widths(table)

    # "сшиваем" ячейки в необходимых местах для формирования определённого вида таблицы
    a = table.cell(0, 0)
    b = table.cell(1, 0)
    A = a.merge(b)  

    a = table.cell(0, 1)
    b = table.cell(1, 1)
    A = a.merge(b)  

    a = table.cell(0, 2)
    b = table.cell(0, 3)
    A = a.merge(b)  

    a = table.cell(0, 4)
    b = table.cell(1, 4)
    A = a.merge(b)  

    c = table.cell(2, 4)
    d = table.cell(len(table.rows)-1, 4)
    B = c.merge(d) 

    # добавляем необходимый текст в нужную ячейку
    table.cell(0, 0).text = 'Время τ, мин'
    table.cell(0, 1).text = 'Разность давлений на образце ΔР, Па'
    table.cell(0, 3).text = 'Расход газов через образец'
    table.cell(0, 4).text = 'Приведённое удельное сопротивление дымогазопроницанию Sуд, м³/кг'
    table.cell(2, 4).text = f'{sagpt_x2}'

    # выравниваем текст в ячейках по центру
    for i in range(len(table.rows)):
        for j in range(len(table.columns)):
            cell = table.rows[i].cells[j]
            cell_paragraph = cell.paragraphs[0]
            cell_paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # выравниваем текст во всех колонках по центру
    for i in range(len(table.rows)):
        for j in range(len(table.columns)):
            cell = table.rows[i].cells[j]
            cell.vertical_alignment = WD_ALIGN_VERTICAL.CENTER
            
    # продолжаем нумерацию таблиц
    table_num += 1

# %%
# 3 образец
if test_type == 'S' and serial_number_3 != '':
    #добавим пустой перед таблицей
    p = template.add_paragraph()

    # добавим название таблицы
    # добавляем абзац с текстом
    p = template.add_paragraph(f'Таблица {table_num}. Результаты измерений при определении дымогазопроницаемости. Образец № 3.')
    # убираем интервал после текста
    p.paragraph_format.space_after = Pt(0)
    # добавляем отступ слева
    p.paragraph_format.left_indent = Cm(1.0)

    # добавляем переменную, которой передаём количество строк (shape[0]+1) и столбцов (shape[1]) таблицы
    table = template.add_table(sagpt_table3.shape[0]+1, sagpt_table3.shape[1], style='Table Grid')

    # выравниваем таблицу по центру страницы
    table.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # добавляем строку - заголовок
    for j in range(sagpt_table3.shape[-1]):
        table.cell(0,j).text = sagpt_table3.columns[j]

    # добавляем остальную часть данных
    for i in range(sagpt_table3.shape[0]):
        for j in range(sagpt_table3.shape[-1]):
            table.cell(i+1,j).text = str(sagpt_table3.values[i,j])        

    # зададим ширину столбцам
    def set_col_widths(table):
        widths = (Cm(2.37), Cm(3.27), Cm(2.72), Cm(2.68), Cm(5.84))
        for row in table.rows:
            for idx, width in enumerate(widths):
                row.cells[idx].width = width
    set_col_widths(table)

    # "сшиваем" ячейки в необходимых местах для формирования определённого вида таблицы
    a = table.cell(0, 0)
    b = table.cell(1, 0)
    A = a.merge(b)  

    a = table.cell(0, 1)
    b = table.cell(1, 1)
    A = a.merge(b)  

    a = table.cell(0, 2)
    b = table.cell(0, 3)
    A = a.merge(b)  

    a = table.cell(0, 4)
    b = table.cell(1, 4)
    A = a.merge(b)  

    c = table.cell(2, 4)
    d = table.cell(len(table.rows)-1, 4)
    B = c.merge(d) 

    # добавляем необходимый текст в нужную ячейку
    table.cell(0, 0).text = 'Время τ, мин'
    table.cell(0, 1).text = 'Разность давлений на образце ΔР, Па'
    table.cell(0, 3).text = 'Расход газов через образец'
    table.cell(0, 4).text = 'Приведённое удельное сопротивление дымогазопроницанию Sуд, м³/кг'
    table.cell(2, 4).text = f'{sagpt_x3}'

    # выравниваем текст в ячейках по центру
    for i in range(len(table.rows)):
        for j in range(len(table.columns)):
            cell = table.rows[i].cells[j]
            cell_paragraph = cell.paragraphs[0]
            cell_paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # выравниваем текст во всех колонках по центру
    for i in range(len(table.rows)):
        for j in range(len(table.columns)):
            cell = table.rows[i].cells[j]
            cell.vertical_alignment = WD_ALIGN_VERTICAL.CENTER
            
    # продолжаем нумерацию таблиц
    table_num += 1

# %%
# 4 образец
if test_type == 'S' and serial_number_4 != '':
    #добавим пустой перед таблицей
    p = template.add_paragraph()

    # добавим название таблицы
    # добавляем абзац с текстом
    p = template.add_paragraph(f'Таблица {table_num}. Результаты измерений при определении дымогазопроницаемости. Образец № 4.')
    # убираем интервал после текста
    p.paragraph_format.space_after = Pt(0)
    # добавляем отступ слева
    p.paragraph_format.left_indent = Cm(1.0)

    # добавляем переменную, которой передаём количество строк (shape[0]+1) и столбцов (shape[1]) таблицы
    table = template.add_table(sagpt_table4.shape[0]+1, sagpt_table4.shape[1], style='Table Grid')

    # выравниваем таблицу по центру страницы
    table.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # добавляем строку - заголовок
    for j in range(sagpt_table4.shape[-1]):
        table.cell(0,j).text = sagpt_table4.columns[j]

    # добавляем остальную часть данных
    for i in range(sagpt_table4.shape[0]):
        for j in range(sagpt_table4.shape[-1]):
            table.cell(i+1,j).text = str(sagpt_table4.values[i,j])        

    # зададим ширину столбцам
    def set_col_widths(table):
        widths = (Cm(2.37), Cm(3.27), Cm(2.72), Cm(2.68), Cm(5.84))
        for row in table.rows:
            for idx, width in enumerate(widths):
                row.cells[idx].width = width
    set_col_widths(table)

    # "сшиваем" ячейки в необходимых местах для формирования определённого вида таблицы
    a = table.cell(0, 0)
    b = table.cell(1, 0)
    A = a.merge(b)  

    a = table.cell(0, 1)
    b = table.cell(1, 1)
    A = a.merge(b)  

    a = table.cell(0, 2)
    b = table.cell(0, 3)
    A = a.merge(b)  

    a = table.cell(0, 4)
    b = table.cell(1, 4)
    A = a.merge(b)  

    c = table.cell(2, 4)
    d = table.cell(len(table.rows)-1, 4)
    B = c.merge(d) 

    # добавляем необходимый текст в нужную ячейку
    table.cell(0, 0).text = 'Время τ, мин'
    table.cell(0, 1).text = 'Разность давлений на образце ΔР, Па'
    table.cell(0, 3).text = 'Расход газов через образец'
    table.cell(0, 4).text = 'Приведённое удельное сопротивление дымогазопроницанию Sуд, м³/кг'
    table.cell(2, 4).text = f'{sagpt_x4}'

    # выравниваем текст в ячейках по центру
    for i in range(len(table.rows)):
        for j in range(len(table.columns)):
            cell = table.rows[i].cells[j]
            cell_paragraph = cell.paragraphs[0]
            cell_paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # выравниваем текст во всех колонках по центру
    for i in range(len(table.rows)):
        for j in range(len(table.columns)):
            cell = table.rows[i].cells[j]
            cell.vertical_alignment = WD_ALIGN_VERTICAL.CENTER
       
    # продолжаем нумерацию таблиц
    table_num += 1

# %% [markdown]
# ### Таблица - поведение образцов

# %%
# список с возможными вариантами поведением образца
sample_behavior_list = ['Образование трещин на обогреваемой поверхности стекла.',         # [0]
                        'Образование трещин на обогреваемой поверхности стекол.',         # [1]
                        'Дымовыделение через замок.',                                     # [2]
                        'Дымовыделение по нижнему притвору.',                             # [3]
                        'Дымовыделение по верхнему притвору.',                            # [4]
                        'Дымовыделение по левому притвору.',                              # [5]
                        'Дымовыделение по правому притвору.',                             # [6]
                        'Дымовыделение по среднему вертикальному притвору.',              # [7]
                        'Дымовыделение по вертикальным притворам верхней части полотна.', # [8]
                        'Дымовыделение по верхнему притвору калитки.',                    # [9]
                        'Дымовыделение по нижнему притвору калитки.',                     # [10]
                        'Дымовыделение по левому притвору калитки.',                      # [11]
                        'Дымовыделение по правому притвору калитки.',                     # [12]
                        'Дымовыделение по верхнему притвору ворот.',                      # [13]
                        'Дымовыделение по нижнему притвору ворот.',                       # [14]
                        'Дымовыделение по среднему вертикальному притвору ворот.',        # [15]
                        'Дымовыделение по левому притвору ворот.',                        # [16]
                        'Дымовыделение по правому притвору ворот.',                       # [17]
                        'Дымовыделение через замок.',                                     # [18]
                        'Стекло стало полностью непрозрачным.',                           # [19]
                        'Стекла стали полностью непрозрачными.',                          # [20]
                        'Прогиб полотна в сторону противоположную огневому воздействию.', # [21] (д)
                        'Прогиб полотна в сторону огневого воздействия.']                 # [22] (м)

# %%
# функция по созданию таблицы "Поведение образца во время проведения испытаний"
def sample_behavior_table_func():

    # создаём датафрейм с первой строкой таблицы "Поведение образца во время проведения испытаний"
    data = {'Время от начала испытания, мин': [0], 'Особенности поведения образца ': ['Начало испытания.']} 
    df = pd.DataFrame(data)

    # если есть стекло
    if glazing == 1:
        df.loc[len(df)] = [random.randint(2,3), sample_behavior_list[0]] # добавляем значение вместе со временем в датафрейм
    # если несколько стекол
    elif glazing == 2:
        df.loc[len(df)] = [random.randint(2,3), sample_behavior_list[1]] # добавляем значение вместе со временем в датафрейм
    # если остекление отсутствует
    else:
        pass


    # поправка на время проведения испытания

    # набор для 15 минут
    if fire_limit == 15:
        # создаём подсписок значений из общего списка всех возмоных значений
        sample_behavior_list_ = random.sample(sample_behavior_list[2:7], 2)
        # добавляем значения вместе со временем в датафрейм
        df.loc[len(df)] = [random.randint(4,7), sample_behavior_list_[0]]
        df.loc[len(df)] = [random.randint(8,10), sample_behavior_list_[1]]

        # если есть стекло
        if glazing == 1:
            df.loc[len(df)] = [random.randint(11,13), sample_behavior_list[19]] # добавляем значение вместе со временем в датафрейм
        # если несколько стекол
        elif glazing == 2:
            df.loc[len(df)] = [random.randint(11,13), sample_behavior_list[20]] # добавляем значение вместе со временем в датафрейм
        # если остекление отсутствует
        else:
            pass    


    # набор для любого другого времени    
    else:

        # дверь 1пол, люк 1пол
        if construction_type in ('дверь 1пол', 'люк 1пол'):
            # создаём подсписок значений из общего списка всех возмоных значений
            sample_behavior_list_ = random.sample(sample_behavior_list[2:7], 3)
            # добавляем значения вместе со временем в датафрейм
            df.loc[len(df)] = [random.randint(4,8), sample_behavior_list_[0]]
            df.loc[len(df)] = [random.randint(9,12), sample_behavior_list_[1]]
            df.loc[len(df)] = [random.randint(13,16), sample_behavior_list_[2]]

        # дверь 2пол, люк 2пол
        elif construction_type in ('дверь 2пол', 'люк 2пол'):
            # создаём подсписок значений из общего списка всех возмоных значений
            sample_behavior_list_ = random.sample(sample_behavior_list[2:9], 4)
            # добавляем значения вместе со временем в датафрейм
            df.loc[len(df)] = [random.randint(4,7), sample_behavior_list_[0]]
            df.loc[len(df)] = [random.randint(8,11), sample_behavior_list_[1]]
            df.loc[len(df)] = [random.randint(12,14), sample_behavior_list_[2]]
            df.loc[len(df)] = [random.randint(15,16), sample_behavior_list_[3]]

        # ворота
        elif construction_type == 'ворота':
            # создаём подсписок значений из общего списка всех возмоных значений
            sample_behavior_list_ = random.sample(sample_behavior_list[13:19], 4)
            # добавляем значения вместе со временем в датафрейм
            df.loc[len(df)] = [random.randint(4,7), sample_behavior_list_[0]]
            df.loc[len(df)] = [random.randint(8,11), sample_behavior_list_[1]]
            df.loc[len(df)] = [random.randint(12,14), sample_behavior_list_[2]]
            df.loc[len(df)] = [random.randint(15,16), sample_behavior_list_[3]]

        # ворота с калиткой
        elif construction_type == 'ворота с калиткой':
            # создаём подсписок значений из общего списка всех возмоных значений
            sample_behavior_list_ = random.sample(sample_behavior_list[9:19], 5)
            # добавляем значения вместе со временем в датафрейм
            df.loc[len(df)] = [random.randint(4,6), sample_behavior_list_[0]]
            df.loc[len(df)] = [random.randint(7,9), sample_behavior_list_[1]]
            df.loc[len(df)] = [random.randint(10,12), sample_behavior_list_[2]]
            df.loc[len(df)] = [random.randint(13,14), sample_behavior_list_[3]]
            df.loc[len(df)] = [random.randint(15,16), sample_behavior_list_[4]]

        # окно
        else:
            pass


        # если есть стекло
        if glazing == 1:
            df.loc[len(df)] = [random.randint(17,20), sample_behavior_list[19]] # добавляем значение вместе со временем в датафрейм
        # если несколько стекол
        elif glazing == 2:
            df.loc[len(df)] = [random.randint(17,20), sample_behavior_list[20]] # добавляем значение вместе со временем в датафрейм
        # если остекление отсутствует
        else:
            pass

        # Прогиб полотна в зависимости от материала конструкции
        if construction_type != 'окно':
            # материал конструкции
            if construction_material_val == 'д':
                # список значений для дерева
                df.loc[len(df)] = [random.randint(21,24), sample_behavior_list[21]]
            else:
                # список значений для металла
                df.loc[len(df)] = [random.randint(21,24), sample_behavior_list[22]]
        else:
            pass


    # конец таблички    
    df.loc[len(df)] = [fire_limit, 'Завершение испытания без достижения предельных состояний по согласованию с заказчиком.']

    return df

# %%
if test_type != 'S':
    
    # первая таблица
    sample_behavior_table = sample_behavior_table_func()

    #добавим пустой перед таблицей
    p = template.add_paragraph()

    # добавим название таблицы
    # добавляем абзац с текстом
    p = template.add_paragraph(f'Таблица {table_num}. Поведение образца во время проведения испытаний. Образец № 1.')
    # убираем интервал после текста
    p.paragraph_format.space_after = Pt(0)
    # добавляем отступ слева
    p.paragraph_format.left_indent = Cm(0.75)

    # добавляем переменную, которой передаём количество строк (shape[0]+1) и столбцов (shape[1]) таблицы
    table = template.add_table(sample_behavior_table.shape[0]+1, sample_behavior_table.shape[1], style='Table Grid')

    # выравниваем таблицу по центру страницы
    table.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # добавляем строку - заголовок
    for j in range(sample_behavior_table.shape[-1]):
        table.cell(0,j).text = sample_behavior_table.columns[j]

    # добавляем остальную часть данных
    for i in range(sample_behavior_table.shape[0]):
        for j in range(sample_behavior_table.shape[-1]):
            table.cell(i+1,j).text = str(sample_behavior_table.values[i,j])        

    # зададим ширину столбцам
    def set_col_widths(table):
        widths = (Cm(3), Cm(14.75))
        for row in table.rows:
            for idx, width in enumerate(widths):
                row.cells[idx].width = width
    set_col_widths(table)

    # выравниваем текст в необходимых ячейках по центру (по высоте)
    def vertical_center(row_idx, col_idx):
        table.cell(row_idx, col_idx).vertical_alignment = WD_ALIGN_VERTICAL.CENTER
    vertical_center(0,0)
    vertical_center(0,1)

    # выравниваем текст 1 ячейки по центру
    cell = table.rows[0].cells[1]
    cell_paragraph = cell.paragraphs[0]
    cell_paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
    
    # продолжаем нумерацию таблиц
    table_num += 1

# %%
if test_type != 'S':
    
    # вторая таблица
    sample_behavior_table = sample_behavior_table_func()

    #добавим пустой перед таблицей
    p = template.add_paragraph()

    # добавим название таблицы
    # добавляем абзац с текстом
    p = template.add_paragraph(f'Таблица {table_num}. Поведение образца во время проведения испытаний. Образец № 2.')
    # убираем интервал после текста
    p.paragraph_format.space_after = Pt(0)
    # добавляем отступ слева
    p.paragraph_format.left_indent = Cm(0.75)

    # добавляем переменную, которой передаём количество строк (shape[0]+1) и столбцов (shape[1]) таблицы
    table = template.add_table(sample_behavior_table.shape[0]+1, sample_behavior_table.shape[1], style='Table Grid')

    # выравниваем таблицу по центру страницы
    table.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # добавляем строку - заголовок
    for j in range(sample_behavior_table.shape[-1]):
        table.cell(0,j).text = sample_behavior_table.columns[j]

    # добавляем остальную часть данных
    for i in range(sample_behavior_table.shape[0]):
        for j in range(sample_behavior_table.shape[-1]):
            table.cell(i+1,j).text = str(sample_behavior_table.values[i,j])        

    # зададим ширину столбцам
    def set_col_widths(table):
        widths = (Cm(3), Cm(14.75))
        for row in table.rows:
            for idx, width in enumerate(widths):
                row.cells[idx].width = width
    set_col_widths(table)

    # выравниваем текст в необходимых ячейках по центру (по высоте)
    def vertical_center(row_idx, col_idx):
        table.cell(row_idx, col_idx).vertical_alignment = WD_ALIGN_VERTICAL.CENTER
    vertical_center(0,0)
    vertical_center(0,1)

    # выравниваем текст 1 ячейки по центру
    cell = table.rows[0].cells[1]
    cell_paragraph = cell.paragraphs[0]
    cell_paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # продолжаем нумерацию таблиц
    table_num += 1

# %% [markdown]
# ### Таблица - сводные результаты испытаний

# %%
#добавим пустой абзац перед таблицей
p = template.add_paragraph()

# добавим название таблицы
# добавляем абзац с текстом
p = template.add_paragraph(f'Таблица {table_num}. Сводные результаты испытаний.')
# убираем интервал после текста
p.paragraph_format.space_after = Pt(0)
# добавляем отступ слева
p.paragraph_format.left_indent = Cm(0.75)

# %%
# формируем и заполняем таблицу 

# таблица для ПИ по EIW
if test_type == 'EIW':
    # добавляем пустую таблицу 11х5 ячейки
    table = template.add_table(rows=11, cols=5)

    # соединяем ячейки, где это необходимо и добавляем в них текст
    table.cell(3, 3).merge(table.cell(3, 4)).text = 'в норме'
    table.cell(1, 3).merge(table.cell(1, 4)).text = 'Фактическое'
    table.cell(0, 2).merge(table.cell(0, 4)).text = 'Значение параметра'
    table.cell(1, 2).merge(table.cell(2, 2)).text = 'по ГОСТ'
    table.cell(0, 1).merge(table.cell(2, 1)).text = 'Наименование контролируемого параметра'
    table.cell(0, 0).merge(table.cell(2, 0)).text = 'ГОСТ'
    table.cell(4, 0).merge(table.cell(4, 2)).text = 'Продолжительность проведения испытаний'
    table.cell(5, 0).merge(table.cell(7, 0)).text = 'ГОСТ Р 53308-2009 п.5.3'
    table.cell(5, 1).merge(table.cell(7, 1)).text = 'Потеря теплоизолирующей способности (I)'

    # добавляем текст в остальные ячейки
    table.cell(3, 0).text = 'ГОСТ 30247.0-94 п.6'
    table.cell(3, 1).text = 'Температурный режим в печи'
    table.cell(3, 2).text = 'T-T\u2080=345lg(8t+1)'
    table.cell(3, 3).text = 'в норме'
    table.cell(2, 3).text = 'Образец № 1'
    table.cell(2, 4).text = 'Образец № 2'
    table.cell(4, 3).text = f'{fire_limit} мин.'
    table.cell(4, 4).text = f'{fire_limit} мин.'
    table.cell(8, 0).text = 'ГОСТ Р 53308-2009 п.5.2'
    table.cell(9, 0).text = 'ГОСТ Р 53308-2009 п.5.4'
    table.cell(10,0).text = 'ГОСТ Р 53308-2009 п. 12'
    table.cell(8, 1).text = 'Потеря целостности (Е)'
    table.cell(9, 1).text = 'Потеря теплоизолирующей способности (W)'
    table.cell(10,1).text = 'Предел огнестойкости'
    table.cell(5, 3).text = 'не наступила'
    table.cell(5, 4).text = 'не наступила'
    table.cell(6, 3).text = 'не наступила'
    table.cell(6, 4).text = 'не наступила'
    table.cell(7, 3).text = 'не наступила'
    table.cell(7, 4).text = 'не наступила'
    table.cell(8, 3).text = 'не наступила'
    table.cell(8, 4).text = 'не наступила'
    table.cell(9, 3).text = 'не наступила'
    table.cell(9, 4).text = 'не наступила'
    table.cell(10,3).text = f'{test_type} {fire_limit}'
    table.cell(10,4).text = f'{test_type} {fire_limit}'

    # разный шифт в одной ячейке
    table.cell(5, 2).paragraphs[0].add_run('Т')
    table.cell(5, 2).paragraphs[0].add_run('ср ').font.size = Pt(7)
    table.cell(5, 2).paragraphs[0].add_run('=T\u2092+140 °C')

    # разный шифт в одной ячейке
    table.cell(6, 2).paragraphs[0].add_run('Т')
    table.cell(6, 2).paragraphs[0].add_run('n ').font.size = Pt(7)
    table.cell(6, 2).paragraphs[0].add_run('=T\u2092+180 °C')

    # разный шифт в одной ячейке
    table.cell(7, 2).paragraphs[0].add_run('Т')
    table.cell(7, 2).paragraphs[0].add_run('n ').font.size = Pt(7)
    table.cell(7, 2).paragraphs[0].add_run('=300 °C')

    # форматирование таблицы

    # отображаем сетку таблицы
    table.style = 'Table Grid'

    # выравниваем таблицу по центру страницы
    table.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # зададим ширину столбцам
    widths = (Cm(4.5), Cm(5.0), Cm(2.98), Cm(2.5), Cm(2.5))
    for row in table.rows:
        for idx, width in enumerate(widths):
            row.cells[idx].width = width

    # выравниваем текст во всех колонках, кроме первой и второй по центру
    for i in range(len(table.rows)):
        for j in range(2,(len(table.columns))):
            table.rows[i].cells[j].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER 

    # выравниваем текст 0 строки, 0 колонки по центру
    table.rows[0].cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

    # выравниваем текст 0 строки, 1 колонки по центру
    table.rows[0].cells[1].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER  

    # выравниваем текст 4 строки, 0 колонки по левому краю
    table.rows[4].cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT  

    # выравниваем текст заголовка по центру, по высоте  
    for i in range(0, 3):
        for j in range(len(table.columns)):
            table.rows[i].cells[j].vertical_alignment = WD_ALIGN_VERTICAL.CENTER

    # делаем шрифт заголовка жирным
    for i in range(0, 3):
        for j in range(len(table.columns)):
            table.rows[i].cells[j].paragraphs[0].runs[0].font.bold = True    
            
            
# таблица для ПИ по EI
elif test_type == 'EI':
    # добавляем пустую таблицу 10х5 ячейки
    table = template.add_table(rows=10, cols=5)

    # соединяем ячейки, где это необходимо и добавляем в них текст
    table.cell(3, 3).merge(table.cell(3, 4)).text = 'в норме'
    table.cell(1, 3).merge(table.cell(1, 4)).text = 'Фактическое'
    table.cell(0, 2).merge(table.cell(0, 4)).text = 'Значение параметра'
    table.cell(1, 2).merge(table.cell(2, 2)).text = 'по ГОСТ'
    table.cell(0, 1).merge(table.cell(2, 1)).text = 'Наименование контролируемого параметра'
    table.cell(0, 0).merge(table.cell(2, 0)).text = 'ГОСТ'
    table.cell(4, 0).merge(table.cell(4, 2)).text = 'Продолжительность проведения испытаний'
    table.cell(5, 0).merge(table.cell(7, 0)).text = 'ГОСТ Р 53307-2009 п.5.1.2'
    table.cell(5, 1).merge(table.cell(7, 1)).text = 'Потеря теплоизолирующей способности (I)'

    # добавляем текст в остальные ячейки
    table.cell(3, 0).text = 'ГОСТ 30247.0-94 п.6'
    table.cell(3, 1).text = 'Температурный режим в печи'
    table.cell(3, 2).text = 'T-T\u2080=345lg(8t+1)'
    table.cell(3, 3).text = 'в норме'
    table.cell(2, 3).text = 'Образец № 1'
    table.cell(2, 4).text = 'Образец № 2'
    table.cell(4, 3).text = f'{fire_limit} мин.'
    table.cell(4, 4).text = f'{fire_limit} мин.'
    table.cell(8, 0).text = 'ГОСТ Р 53307-2009 п.5.1.1'
    table.cell(9, 0).text = 'ГОСТ 30247.0-94'
    table.cell(8, 1).text = 'Потеря целостности (Е)'
    table.cell(9, 1).text = 'Предел огнестойкости'
    table.cell(5, 3).text = 'не наступила'
    table.cell(5, 4).text = 'не наступила'
    table.cell(6, 3).text = 'не наступила'
    table.cell(6, 4).text = 'не наступила'
    table.cell(7, 3).text = 'не наступила'
    table.cell(7, 4).text = 'не наступила'
    table.cell(8, 3).text = 'не наступила'
    table.cell(8, 4).text = 'не наступила'
    table.cell(9,3).text = f'{test_type} {fire_limit}'
    table.cell(9,4).text = f'{test_type} {fire_limit}'

    # разный шифт в одной ячейке
    table.cell(5, 2).paragraphs[0].add_run('Т')
    table.cell(5, 2).paragraphs[0].add_run('ср ').font.size = Pt(7)
    table.cell(5, 2).paragraphs[0].add_run('=T\u2092+140 °C')

    # разный шифт в одной ячейке
    table.cell(6, 2).paragraphs[0].add_run('Т')
    table.cell(6, 2).paragraphs[0].add_run('n ').font.size = Pt(7)
    table.cell(6, 2).paragraphs[0].add_run('=T\u2092+180 °C')

    # разный шифт в одной ячейке
    table.cell(7, 2).paragraphs[0].add_run('Т')
    table.cell(7, 2).paragraphs[0].add_run('n ').font.size = Pt(7)
    table.cell(7, 2).paragraphs[0].add_run('=300 °C')

    # форматирование таблицы

    # отображаем сетку таблицы
    table.style = 'Table Grid'

    # выравниваем таблицу по центру страницы
    table.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # зададим ширину столбцам
    widths = (Cm(4.5), Cm(5.0), Cm(2.98), Cm(2.5), Cm(2.5))
    for row in table.rows:
        for idx, width in enumerate(widths):
            row.cells[idx].width = width

    # выравниваем текст во всех колонках, кроме первой и второй по центру
    for i in range(len(table.rows)):
        for j in range(2,(len(table.columns))):
            table.rows[i].cells[j].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER 

    # выравниваем текст 0 строки, 0 колонки по центру
    table.rows[0].cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

    # выравниваем текст 0 строки, 1 колонки по центру
    table.rows[0].cells[1].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER  

    # выравниваем текст 4 строки, 0 колонки по левому краю
    table.rows[4].cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT  

    # выравниваем текст заголовка по центру, по высоте  
    for i in range(0, 3):
        for j in range(len(table.columns)):
            table.rows[i].cells[j].vertical_alignment = WD_ALIGN_VERTICAL.CENTER

    # делаем шрифт заголовка жирным
    for i in range(0, 3):
        for j in range(len(table.columns)):
            table.rows[i].cells[j].paragraphs[0].runs[0].font.bold = True 
            
    
# таблица для ПИ по E
elif test_type == 'E':
    # добавляем пустую таблицу 7х5 ячейки
    table = template.add_table(rows=7, cols=5)

    # соединяем ячейки, где это необходимо и добавляем в них текст
    table.cell(3, 3).merge(table.cell(3, 4)).text = 'в норме'
    table.cell(1, 3).merge(table.cell(1, 4)).text = 'Фактическое'
    table.cell(0, 2).merge(table.cell(0, 4)).text = 'Значение параметра'
    table.cell(1, 2).merge(table.cell(2, 2)).text = 'по ГОСТ'
    table.cell(0, 1).merge(table.cell(2, 1)).text = 'Наименование контролируемого параметра'
    table.cell(0, 0).merge(table.cell(2, 0)).text = 'ГОСТ'
    table.cell(4, 0).merge(table.cell(4, 2)).text = 'Продолжительность проведения испытаний'

    # добавляем текст в остальные ячейки
    table.cell(3, 0).text = 'ГОСТ 30247.0-94 п.6'
    table.cell(3, 1).text = 'Температурный режим в печи'
    table.cell(3, 2).text = 'T-T\u2080=345lg(8t+1)'
    table.cell(3, 3).text = 'в норме'
    table.cell(2, 3).text = 'Образец № 1'
    table.cell(2, 4).text = 'Образец № 2'
    table.cell(4, 3).text = f'{fire_limit} мин.'
    table.cell(4, 4).text = f'{fire_limit} мин.'
    table.cell(5, 0).text = 'ГОСТ Р 53308-2009 п.5.2'
    table.cell(6, 0).text = 'ГОСТ Р 53308-2009 п. 12'
    table.cell(5, 1).text = 'Потеря целостности (Е)'
    table.cell(6, 1).text = 'Предел огнестойкости'
    table.cell(5, 3).text = 'не наступила'
    table.cell(5, 4).text = 'не наступила'
    table.cell(6,3).text = f'{test_type} {fire_limit}'
    table.cell(6,4).text = f'{test_type} {fire_limit}'    

    # форматирование таблицы

    # отображаем сетку таблицы
    table.style = 'Table Grid'

    # выравниваем таблицу по центру страницы
    table.alignment = WD_ALIGN_PARAGRAPH.CENTER

    # зададим ширину столбцам
    widths = (Cm(4.5), Cm(5.0), Cm(2.98), Cm(2.5), Cm(2.5))
    for row in table.rows:
        for idx, width in enumerate(widths):
            row.cells[idx].width = width

    # выравниваем текст во всех колонках, кроме первой и второй по центру
    for i in range(len(table.rows)):
        for j in range(2,(len(table.columns))):
            table.rows[i].cells[j].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER 

    # выравниваем текст 0 строки, 0 колонки по центру
    table.rows[0].cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

    # выравниваем текст 0 строки, 1 колонки по центру
    table.rows[0].cells[1].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER  

    # выравниваем текст 4 строки, 0 колонки по левому краю
    table.rows[4].cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT  

    # выравниваем текст заголовка по центру, по высоте  
    for i in range(0, 3):
        for j in range(len(table.columns)):
            table.rows[i].cells[j].vertical_alignment = WD_ALIGN_VERTICAL.CENTER

    # делаем шрифт заголовка жирным
    for i in range(0, 3):
        for j in range(len(table.columns)):
            table.rows[i].cells[j].paragraphs[0].runs[0].font.bold = True            
    
    
else:
    # таблица для ПИ по S (2 обр.)
    if serial_number_3 == '':
        # добавляем пустую таблицу 8х5 ячейки
        table = template.add_table(rows=8, cols=5)

        # соединяем ячейки, где это необходимо и добавляем в них текст
        table.cell(3, 3).merge(table.cell(3, 4)).text = 'в норме'
        table.cell(1, 3).merge(table.cell(1, 4)).text = 'Фактическое'
        table.cell(0, 2).merge(table.cell(0, 4)).text = 'Значение параметра'
        table.cell(1, 2).merge(table.cell(2, 2)).text = 'по ГОСТ'
        table.cell(0, 1).merge(table.cell(2, 1)).text = 'Наименование контролируемого параметра'
        table.cell(0, 0).merge(table.cell(2, 0)).text = 'ГОСТ'
        table.cell(5, 0).merge(table.cell(5, 2)).text = 'Продолжительность проведения испытаний'

        # добавляем текст в остальные ячейки
        table.cell(3, 0).text = 'ГОСТ 30247.0-94'
        table.cell(3, 1).text = 'Температурный режим в печи'
        table.cell(3, 2).text = 'T-T\u2080=345lg(8t+1)'
        table.cell(3, 3).text = 'в норме'
        table.cell(2, 3).text = 'Образец № 1'
        table.cell(2, 4).text = 'Образец № 2'
        table.cell(4, 0).text = 'ГОСТ Р 53303-2009'
        table.cell(4, 1).text = 'Перепад давления на образце'
        table.cell(4, 2).text = '70 Па±10%'
        table.cell(4, 3).text = '70 Па±10%'
        table.cell(4, 4).text = '70 Па±10%'
        table.cell(5, 3).text = f'{fire_limit} мин.'
        table.cell(5, 4).text = f'{fire_limit} мин.'
        table.cell(6, 0).text = 'ГОСТ Р 53303-2009'
        table.cell(6, 1).text = 'Удельное сопротивление дымогазопроницанию'
        table.cell(6, 2).text = 'не менее 1,96·10\u2075, м\u00B3/кг'
        table.cell(6, 3).text = 'более 1,96·10\u2075, м\u00B3/кг'
        table.cell(6, 4).text = 'более 1,96·10\u2075, м\u00B3/кг'
        table.cell(7, 0).text = 'ГОСТ Р 53303-2009'
        table.cell(7, 1).text = 'Предел огнестойкости'
        table.cell(7, 3).text = f'{test_type} {fire_limit}'
        table.cell(7, 4).text = f'{test_type} {fire_limit}'

        # форматирование таблицы

        # отображаем сетку таблицы
        table.style = 'Table Grid'

        # выравниваем таблицу по центру страницы
        table.alignment = WD_ALIGN_PARAGRAPH.CENTER

        # зададим ширину столбцам
        widths = (Cm(4.5), Cm(5.0), Cm(2.98), Cm(2.5), Cm(2.5))
        for row in table.rows:
            for idx, width in enumerate(widths):
                row.cells[idx].width = width

        # выравниваем текст во всех колонках, кроме первой и второй по центру
        for i in range(len(table.rows)):
            for j in range(2,(len(table.columns))):
                table.rows[i].cells[j].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER 

        # выравниваем текст 0 строки, 0 колонки по центру
        table.rows[0].cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

        # выравниваем текст 0 строки, 1 колонки по центру
        table.rows[0].cells[1].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER  

        # выравниваем текст 5 строки, 0 колонки по левому краю
        table.rows[5].cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT  

        # выравниваем текст заголовка по центру, по высоте  
        for i in range(0, 3):
            for j in range(len(table.columns)):
                table.rows[i].cells[j].vertical_alignment = WD_ALIGN_VERTICAL.CENTER

        # делаем шрифт заголовка жирным
        for i in range(0, 3):
            for j in range(len(table.columns)):
                table.rows[i].cells[j].paragraphs[0].runs[0].font.bold = True            

    else:
        # таблица для ПИ по S (4 обр.)

        # добавляем пустую таблицу 8х7 ячейки
        table = template.add_table(rows=8, cols=7)

        # соединяем ячейки, где это необходимо и добавляем в них текст
        table.cell(3, 3).merge(table.cell(3, 6)).text = 'в норме'
        table.cell(1, 3).merge(table.cell(1, 6)).text = 'Фактическое'
        table.cell(0, 2).merge(table.cell(0, 6)).text = 'Значение параметра'
        table.cell(1, 2).merge(table.cell(2, 2)).text = 'по ГОСТ'
        table.cell(0, 1).merge(table.cell(2, 1)).text = 'Наименование контролируемого параметра'
        table.cell(0, 0).merge(table.cell(2, 0)).text = 'ГОСТ'
        table.cell(5, 0).merge(table.cell(5, 2)).text = 'Продолжительность проведения испытаний'

        # добавляем текст в остальные ячейки
        table.cell(3, 0).text = 'ГОСТ 30247.0-94'
        table.cell(3, 1).text = 'Температурный режим в печи'
        table.cell(3, 2).text = 'T-T\u2080=345lg(8t+1)'
        table.cell(3, 3).text = 'в норме'
        table.cell(2, 3).text = 'Образец № 1'
        table.cell(2, 4).text = 'Образец № 2'
        table.cell(2, 5).text = 'Образец № 3'
        table.cell(2, 6).text = 'Образец № 4'
        table.cell(4, 0).text = 'ГОСТ Р 53303-2009'
        table.cell(4, 1).text = 'Перепад давления на образце'
        table.cell(4, 2).text = '70 Па±10%'
        table.cell(4, 3).text = '70 Па±10%'
        table.cell(4, 4).text = '70 Па±10%'
        table.cell(4, 5).text = '70 Па±10%'
        table.cell(4, 6).text = '70 Па±10%'
        table.cell(5, 3).text = f'{fire_limit} мин.'
        table.cell(5, 4).text = f'{fire_limit} мин.'
        table.cell(5, 5).text = f'{fire_limit} мин.'
        table.cell(5, 6).text = f'{fire_limit} мин.'
        table.cell(6, 0).text = 'ГОСТ Р 53303-2009'
        table.cell(6, 1).text = 'Удельное сопротивление дымогазо-проницанию'
        table.cell(6, 2).text = 'не менее 1,96·10\u2075, \nм\u00B3/кг'
        table.cell(6, 3).text = 'более 1,96·10\u2075, м\u00B3/кг'
        table.cell(6, 4).text = 'более 1,96·10\u2075, м\u00B3/кг'
        table.cell(6, 5).text = 'более 1,96·10\u2075, м\u00B3/кг'
        table.cell(6, 6).text = 'более 1,96·10\u2075, м\u00B3/кг'
        table.cell(7, 0).text = 'ГОСТ Р 53303-2009'
        table.cell(7, 1).text = 'Предел огнестойкости'
        table.cell(7, 3).text = f'{test_type} {fire_limit}'
        table.cell(7, 4).text = f'{test_type} {fire_limit}'
        table.cell(7, 5).text = f'{test_type} {fire_limit}'
        table.cell(7, 6).text = f'{test_type} {fire_limit}' 

        # форматирование таблицы

        # отображаем сетку таблицы
        table.style = 'Table Grid'

        # выравниваем таблицу по центру страницы
        table.alignment = WD_ALIGN_PARAGRAPH.CENTER

        # зададим ширину столбцам
        widths = (Cm(2.09), Cm(1.97), Cm(2.94), Cm(2.45), Cm(2.45), Cm(2.45), Cm(2.45))
        for row in table.rows:
            for idx, width in enumerate(widths):
                row.cells[idx].width = width

        # выравниваем текст во всех колонках, кроме первой и второй по центру
        for i in range(len(table.rows)):
            for j in range(2,(len(table.columns))):
                table.rows[i].cells[j].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER 

        # выравниваем текст 0 строки, 0 колонки по центру
        table.rows[0].cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

        # выравниваем текст 0 строки, 1 колонки по центру
        table.rows[0].cells[1].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER  

        # выравниваем текст 5 строки, 0 колонки по левому краю
        table.rows[5].cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT  

        # выравниваем текст заголовка по центру, по высоте  
        for i in range(0, 3):
            for j in range(len(table.columns)):
                table.rows[i].cells[j].vertical_alignment = WD_ALIGN_VERTICAL.CENTER

        # делаем шрифт заголовка жирным
        for i in range(0, 3):
            for j in range(len(table.columns)):
                table.rows[i].cells[j].paragraphs[0].runs[0].font.bold = True

# %% [markdown]
# ### Завершающий текстовик

# %%
# функция по добавлению заголовка
def add_run_head(fail_name, text):
    # абзац
    p = fail_name.add_paragraph()
    # выравнивание по центру
    p.alignment = WD_ALIGN_PARAGRAPH.CENTER
    # вставка текста 
    p.add_run(text).font.bold = True

# %%
# функция по добавлению текста
def add_run_text(fail_name, text):
    # абзац
    p = fail_name.add_paragraph()
    # отступ слева
    p.paragraph_format.left_indent = Cm(0.25)
    # отступ справа
    p.paragraph_format.right_indent = Cm(0.25)
    # красная строка
    p.paragraph_format.first_line_indent = Cm(1.25)
    # межстрочный интервал
    p.paragraph_format.line_spacing = 1.0
    # выравнивание текста по ширине
    p.paragraph_format.alignment = WD_ALIGN_PARAGRAPH.JUSTIFY
    # вставка текста 
    run = p.add_run(text)

# %%
# срок действия протокола испытаний 
if test_type == 'EI':
    validity_period_test_report = '3 года'
else:
    validity_period_test_report = '5 лет'

# %%
# добавляем и форматируем текст
p = template.add_paragraph() # пустой абзац
add_run_head(template, '11. Дополнения, отклонения или исключения из метода')
p = template.add_paragraph() # пустой абзац
add_run_text(template, 'Дополнения, отклонения или исключения из метода отсутствуют.')
p = template.add_paragraph() # пустой абзац
add_run_head(template, '12. Результаты, полученные от внешних поставщиков')
p = template.add_paragraph() # пустой абзац
add_run_text(template, 'Результаты, полученные от внешних поставщиков, отсутствуют.')
p = template.add_paragraph() # пустой абзац
add_run_head(template, '13. Заключение о соответствии')
p = template.add_paragraph() # пустой абзац
add_run_text(template, 'Для данного протокола испытаний нет требований нормативных документов и требований заказчика о выдаче заключения о соответствии.')
p = template.add_paragraph() # пустой абзац
add_run_text(template, 'Испытания провел:')
p = template.add_paragraph() # пустой абзац
add_run_text(template, f'Инженер-испытатель ____________________ {test_engineer}')
p = template.add_paragraph() # пустой абзац
add_run_head(template, '14. Дополнительная информация')
p = template.add_paragraph() # пустой абзац
add_run_text(template, '1. Настоящий протокол не является сертификатом соответствия (пожарной безопасности).')
add_run_text(template, '2. Полученные результаты и выводы, содержащиеся в протоколе, относятся только к конкретному (ым) образцу (ам) и не отражают качество партии продукции, из которой взят (ы) данный (ые) образец (цы), а также качество всей выпускаемой продукции данного вида.')
add_run_text(template, '3. Если специально не оговорено, то настоящий протокол предназначен только для использования органом по сертификации.')
add_run_text(template, '4. Отдельные страницы с изложением результатов испытаний не могут быть использованы отдельно без полного текста протокола испытаний.')
add_run_text(template, f'5. Срок действия протокола испытаний – {validity_period_test_report}.')
add_run_text(template, '6. Протокол испытаний распространяется только на предоставленный заказчиком образец, прошедший испытания.')
add_run_text(template, f'7. Воспроизведение протокола и (или) результатов испытаний (измерений) не в полном объеме допускается только с письменного разрешения ИЛ {testing_laboratory}.')

p = template.add_paragraph() # пустой абзац
p = template.add_paragraph() # пустой абзац

# абзац
p = template.add_paragraph()
# отступ слева
p.paragraph_format.left_indent = Cm(0.25)
# отступ справа
p.paragraph_format.right_indent = Cm(0.25)
# межстрочный интервал
p.paragraph_format.line_spacing = 1.0
# выравнивание текста по ширине
p.paragraph_format.alignment = WD_ALIGN_PARAGRAPH.RIGHT
# вставка текста 
run = p.add_run('Дата выдачи протокола испытаний: ________________________')

# %% [markdown]
# ## Приложения

# %%
# разрыв страницы
template.add_page_break()

# %%
# добавляем и форматируем текст
p = template.add_paragraph() # пустой абзац
# добавляем текст
add_run_head(template, 'Приложение 1')

# %% [markdown]
# ### Чертёж

# %%
# путь к PDF файлу 
path_pdf = rf'{path_pdf}\{referral_for_testing.split("-")[0]}'.replace('\\', '/')

# имя файла, который располагается в выше указанной папке
doc_name_pdf = f'/{construction_type} чертеж'

# расширение файла
extension_pdf = '.pdf'

# %%
# конвертируем PDF в JPEG
images = convert_from_path(path_pdf+doc_name_pdf+extension_pdf)
 
for i in range(len(images)):
    # сохраняем страницы из PDF
    images[i].save(path_pdf +'/page'+ str(i) +'.jpg', 'JPEG')
        
    # Добавляем пустой абзац в Word файл
    p = template.add_paragraph()
    # Добавляем пустой прогон
    run = p.add_run()
    # теперь в прогон вставляем изображение
    run.add_picture(path_pdf +'/page'+ str(i) +'.jpg', width=Cm(17))
    # выравниваем изображение посередине страницы
    p.alignment =  WD_ALIGN_PARAGRAPH.CENTER
    
    # пока не дошли до последнего листа PDF файла
    if i != (len(images)-1):
             # добавляем разрыв страницы
             template.add_page_break()
             # добавляем пустой абзац
             p = template.add_paragraph()
    else:
             pass
             
    # удалим сохранённый JPEG файл из папки, в которую временно его сохраняли
    if os.path.isfile(path_pdf +'/page'+ str(i) +'.jpg'):
        os.remove(path_pdf +'/page'+ str(i) +'.jpg') 
    else:
        pass

# %% [markdown]
# ### Фото

# %%
# путь к jpg файлу 
path_foto = rf'{path_foto}\{referral_for_testing.split("-")[0]}'.replace('\\', '/')

# имя файла, который располагается в выше указанной папке
doc_name_foto = f'/{construction_type} фото'

# расширение файла
extension_foto = '.jpg'

# %%
# добавление фото в зависимости от типа ПИ
if test_type == 'E' or test_type == 'EIW':
    
    # разрыв страницы
    template.add_page_break()
    # добавляем пустой абзац    
    p = template.add_paragraph()
    
    # добавляем пустой абзац
    p = template.add_paragraph()
    # добавляем пустой прогон
    run = p.add_run()
    # теперь в прогон вставляем изображение
    run.add_picture(path_foto + doc_name_foto + extension_foto, width=Cm(9))
    # выравниваем изображение посередине страницы
    p.alignment =  WD_ALIGN_PARAGRAPH.CENTER
    
    # добавляем и форматируем текст
    p = template.add_paragraph() # пустой абзац
    # добавляем текст
    p = template.add_paragraph()
    # выравнивание по центру
    p.alignment = WD_ALIGN_PARAGRAPH.CENTER
    # вставка текста 
    p.add_run('Фото образца')
else:
    pass

# %% [markdown]
# ### АО

# %%
# путь к PDF файлу 
path_act_of_sampling = rf'{path_act_of_sampling}\{referral_for_testing.split("-")[0]}'.replace('\\', '/')

# имя файла, который располагается в выше указанной папке
doc_name_act_of_sampling = f'/{referral_for_testing.split("-")[0]} АО'

# расширение файла
extension_act_of_sampling = '.pdf'

# %%
# добавление АО в зависимости от типа ПИ
if test_type == 'E' or test_type == 'EIW':
    
    # разрыв страницы
    template.add_page_break()
    # добавляем пустой абзац    
    p = template.add_paragraph()    

    # конвертируем PDF в JPEG
    images = convert_from_path(path_act_of_sampling+doc_name_act_of_sampling+extension_act_of_sampling)

    for i in range(len(images)):
        # сохраняем страницы из PDF
        images[i].save(path_act_of_sampling +'/page'+ str(i) +'.jpg', 'JPEG')

        # Добавляем пустой абзац в Word файл
        p = template.add_paragraph()
        # Добавляем пустой прогон
        run = p.add_run()
        # теперь в прогон вставляем изображение
        run.add_picture(path_act_of_sampling +'/page'+ str(i) +'.jpg', width=Cm(17))
        # выравниваем изображение посередине страницы
        p.alignment =  WD_ALIGN_PARAGRAPH.CENTER

        # пока не дошли до последнего листа PDF файла
        if i != (len(images)-1):
                 # добавляем разрыв страницы
                 template.add_page_break()
                 # добавляем пустой абзац
                 p = template.add_paragraph()
        else:
                 pass

        # удалим сохранённый JPEG файл из папки, в которую временно его сохраняли
        if os.path.isfile(path_act_of_sampling +'/page'+ str(i) +'.jpg'):
            os.remove(path_act_of_sampling +'/page'+ str(i) +'.jpg') 
        else:
            pass
else:
    pass

# %% [markdown]
# ### Конец протокола испытаний

# %%
# добавляем пустой абзац    
p = template.add_paragraph()  

# добавляем текст
p = template.add_paragraph()
# выравнивание по центру
p.alignment = WD_ALIGN_PARAGRAPH.CENTER
# вставка текста 
p.add_run('--------------------------------------------- конец протокола испытаний -----------------------------------------')

# %% [markdown]
# ## Создаём файлы первичных документов

# %%
# создаём файлы под первичные документы
primary_file_1 = ''
primary_file_2 = ''
primary_file_3 = ''
primary_file_4 = ''

# 1 файл если 2 образца испытывались одновременно
if furnace1 == furnace2 and test_dates1 == test_dates2:
    primary_file_1 = docx.Document()
    
# 4 файла если ПИ по S на 4 образца    
elif test_type == 'S' and test_dates3 != '':
    primary_file_1 = docx.Document()
    primary_file_2 = docx.Document()
    primary_file_3 = docx.Document()
    primary_file_4 = docx.Document()
    
# 2 файла во всех остальных случаях    
else:
    primary_file_1 = docx.Document()
    primary_file_2 = docx.Document()

# %%
# меняем размер листа в созданном файле (первичные документы) с Letter (по умолчанию) на А4
# для образца №1

# доступ к первой секции:
section = primary_file_1.sections[0]

# высота листа в сантиметрах
section.page_height = Cm(29.7)
# ширина листа в сантиметрах
section.page_width = Cm(21.0)

# левое поле в миллиметрах
section.left_margin = Mm(20.4)
# правое поле в миллиметрах
section.right_margin = Mm(10)

# верхнее поле в миллиметрах
section.top_margin = Mm(15)
# нижнее поле в миллиметрах
section.bottom_margin = Mm(10)

# отступ от верхнего края страницы до 
# верхнего края верхнего колонтитула
section.header_distance = Mm(10)
# отступ от нижнего края страницы до 
# нижнего края нижнего колонтитула
section.footer_distance = Mm(10)

# %%
# меняем размер листа в созданном файле (первичные документы) с Letter (по умолчанию) на А4
# для образца №2

if primary_file_2 != '':
    # доступ к первой секции:
    section = primary_file_2.sections[0]

    # высота листа в сантиметрах
    section.page_height = Cm(29.7)
    # ширина листа в сантиметрах
    section.page_width = Cm(21.0)

    # левое поле в миллиметрах
    section.left_margin = Mm(20.4)
    # правое поле в миллиметрах
    section.right_margin = Mm(10)

    # верхнее поле в миллиметрах
    section.top_margin = Mm(15)
    # нижнее поле в миллиметрах
    section.bottom_margin = Mm(10)

    # отступ от верхнего края страницы до 
    # верхнего края верхнего колонтитула
    section.header_distance = Mm(10)
    # отступ от нижнего края страницы до 
    # нижнего края нижнего колонтитула
    section.footer_distance = Mm(10)

# %%
# меняем размер листа в созданном файле (первичные документы) с Letter (по умолчанию) на А4
# для образца №3 (ПИ по S)

if primary_file_3 != '': 
    # доступ к первой секции:
    section = primary_file_3.sections[0]

    # высота листа в сантиметрах
    section.page_height = Cm(29.7)
    # ширина листа в сантиметрах
    section.page_width = Cm(21.0)

    # левое поле в миллиметрах
    section.left_margin = Mm(20.4)
    # правое поле в миллиметрах
    section.right_margin = Mm(10)

    # верхнее поле в миллиметрах
    section.top_margin = Mm(15)
    # нижнее поле в миллиметрах
    section.bottom_margin = Mm(10)

    # отступ от верхнего края страницы до 
    # верхнего края верхнего колонтитула
    section.header_distance = Mm(10)
    # отступ от нижнего края страницы до 
    # нижнего края нижнего колонтитула
    section.footer_distance = Mm(10)

# %%
# меняем размер листа в созданном файле (первичные документы) с Letter (по умолчанию) на А4
# для образца №4 (ПИ по S)

if primary_file_4 != '':
    # доступ к первой секции:
    section = primary_file_4.sections[0]

    # высота листа в сантиметрах
    section.page_height = Cm(29.7)
    # ширина листа в сантиметрах
    section.page_width = Cm(21.0)

    # левое поле в миллиметрах
    section.left_margin = Mm(20.4)
    # правое поле в миллиметрах
    section.right_margin = Mm(10)

    # верхнее поле в миллиметрах
    section.top_margin = Mm(15)
    # нижнее поле в миллиметрах
    section.bottom_margin = Mm(10)

    # отступ от верхнего края страницы до 
    # верхнего края верхнего колонтитула
    section.header_distance = Mm(10)
    # отступ от нижнего края страницы до 
    # нижнего края нижнего колонтитула
    section.footer_distance = Mm(10)

# %% [markdown]
# ### Оформление первичного файла

# %% [markdown]
# #### Верхний колонтитул

# %%
# последний элемент шифра первичной записи
last_element_cipher = '-01'

# %%
# доступ к верхнему колонтитулу
header = primary_file_1.sections[0].header.paragraphs[0]

# добавляем верхний колонтитул

# название шрифта по умолчанию
header.style.font.name = 'Times New Roman'
# размер шрифта по умолчанию
header.style.font.size = Pt(12)
# жирный шрифт
header.style.font.bold = True
# текст колонтитула
header.add_run('ПЕРВИЧНЫЕ ЗАПИСИ К ИСПЫТАНИЯМ ПО НАПРАВЛЕНИЮ № ' + referral_for_testing + last_element_cipher)
# выравниваем колонтитул по центру
header.alignment = WD_ALIGN_PARAGRAPH.CENTER

# %% [markdown]
# ## Сохраняем готовый ПИ и первичку к нему

# %%
# создаём новый путь для сохранения файла (прописываем папку "Folder")
new_path = rf'D:\Денис\ПОЖАРка\Протоколы\{referral_for_testing.split("-")[0]}'.replace('\\', '/')

# %%
# создаём папку
if not os.path.exists(new_path):
    os.makedirs(new_path)

# %%
# название/имя изготовителя для названия готового ПИ
if manufactur_type == 'Индивидуальный предприниматель':
    # формируем название для ИП
    ready_prot_manufactur = 'ИП ' + manufactur_name.split()[0] 
else:
    # выделим название между кавычками
    ready_prot_manufactur = manufactur_name[manufactur_name.find('«')+1 : manufactur_name.find('»')]

# %%
# новое имя файла шаблона (имя готового протокола)
ready_prot = f'/з{referral_for_testing.split("-")[0]}-СТР-{year} {construction_type} {ready_prot_manufactur} {test_type} {fire_limit}'

# %%
# сохраняем готовый протокол
template.save(new_path+ready_prot+extension)

# %%
# новые имена первичных документов
# ready_primary_file_1 = '/ready_primary_file_1_name'
# if primary_file_2 != '':
#     ready_primary_file_2 = '/ready_primary_file_2_name'    
# if primary_file_3 != '': 
#     ready_primary_file_3 = '/ready_primary_file_3_name'
# if primary_file_4 != '':    
#     ready_primary_file_4 = '/ready_primary_file_4_name'

# %%
# сохраняем первичные документы
# primary_file_1.save(new_path+ready_primary_file_1+extension)
# if primary_file_2 != '':
#     primary_file_2.save(new_path+ready_primary_file_2+extension)
# if primary_file_3 != '':
#     primary_file_3.save(new_path+ready_primary_file_3+extension)
# if primary_file_4 != '':       
#     primary_file_4.save(new_path+ready_primary_file_4+extension)
